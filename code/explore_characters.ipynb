# %% [markdown]
# # Visualize data on an interactive map
#
# This notebook uses `lonboard` for interactive visualisation of data.

# %%
import geopandas as gpd
import numpy as np
import lonboard
from core.utils import used_keys
from lonboard.colormap import apply_continuous_cmap
import matplotlib as mpl
from mapclassify import classify
from sidecar import Sidecar

# %% [markdown]
# Define data path

# %%
chars_dir = "/data/uscuni-ulce/processed_data/chars/"

# %% [markdown]
# Define region

# %%
country = 'fr_sp_nl_be'

# %%
region_hulls = gpd.read_parquet('/data/uscuni-ulce/' + "regions/" + f"{country}_regions_hull.parquet")

# %%
region_hulls
# Out:
#                                               convex_hull
# labels
# 153563  POLYGON ((1561900 1019000, 1561500 1019200, 15...
# 153635  POLYGON ((1602000 1102800, 1602000 1103200, 16...
# 153755  POLYGON ((1694200 1032400, 1646700 1032500, 16...
# 153834  POLYGON ((1708000 1011300, 1698500 1011500, 16...
# 153898  POLYGON ((1707700 1037200, 1707900 1039400, 17...
# ...                                                   ...
# 534115  POLYGON ((4164800 2843200, 4146900 2851600, 41...
# 534412  POLYGON ((4203400 2086900, 4201600 2117000, 42...
# 534524  POLYGON ((4258700 2026300, 4245100 2032800, 42...
# 535987  POLYGON ((4277300 2161300, 4216000 2161400, 42...
# 536022  POLYGON ((4276900 2103000, 4275400 2103600, 42...
#
# [715 rows x 1 columns]

# %%
m = region_hulls.explore()
region_hulls.loc[[157023]].explore(m=m, color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f462cdc6839247aaba18e684dd552b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f462cdc6839247aaba18e684dd552b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f462cdc6839247aaba18e684dd552b9 = L.map(
#                 &quot;map_0f462cdc6839247aaba18e684dd552b9&quot;,
#                 {
#                     center: [40.56860107245831, -4.2958596524958255],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0f462cdc6839247aaba18e684dd552b9);
#
#
#
#
#
#             var tile_layer_e476411b3c6bf61176a0befeb63cad58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e476411b3c6bf61176a0befeb63cad58.addTo(map_0f462cdc6839247aaba18e684dd552b9);
#
#
#             map_0f462cdc6839247aaba18e684dd552b9.fitBounds(
#                 [[27.63953635130573, -18.14948756521726], [53.49766579361089, 9.55776826022561]],
#                 {}
#             );
#
#
#         function geo_json_44c12791ab1a9b568660a72595a5f811_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_44c12791ab1a9b568660a72595a5f811_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_44c12791ab1a9b568660a72595a5f811_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_44c12791ab1a9b568660a72595a5f811_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_44c12791ab1a9b568660a72595a5f811_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_44c12791ab1a9b568660a72595a5f811.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_44c12791ab1a9b568660a72595a5f811_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_44c12791ab1a9b568660a72595a5f811 = L.geoJson(null, {
#                 onEachFeature: geo_json_44c12791ab1a9b568660a72595a5f811_onEachFeature,
#
#                 style: geo_json_44c12791ab1a9b568660a72595a5f811_styler,
#                 pointToLayer: geo_json_44c12791ab1a9b568660a72595a5f811_pointToLayer,
#         });
#
#         function geo_json_44c12791ab1a9b568660a72595a5f811_add (data) {
#             geo_json_44c12791ab1a9b568660a72595a5f811
#                 .addData(data);
#         }
#             geo_json_44c12791ab1a9b568660a72595a5f811_add({&quot;bbox&quot;: [-18.14948756521726, 27.63953635130573, 9.55776826022561, 53.49766579361089], &quot;features&quot;: [{&quot;bbox&quot;: [-18.14948756521726, 27.63953635130573, -17.822289486161544, 28.8466391042424

# %%
region = 523438

# %% [markdown]
# ## Buildings
# Load building data and ensure the geometries are all valid Polygons.

# %%
buildings = (
    gpd.read_parquet(f"{chars_dir}buildings_chars_{region}.parquet")
    # .to_crs(4326)
    .reset_index()
)

# %%
buildings
# Out:
#          index  hauteur date_d_apparition beginning   end currentUse  \
# 0            0      7.1              None      None  None       None
# 1            1     10.9              None      None  None       None
# 2            2      2.9        1900-01-01      None  None       None
# 3            3      7.8              None      None  None       None
# 4            4      2.8              None      None  None       None
# ...        ...      ...               ...       ...   ...        ...
# 509339  509339      4.1              None      None  None       None
# 509340  509340      5.7              None      None  None       None
# 509341  509341      NaN              None      None  None       None
# 509342  509342      6.8              None      None  None       None
# 509343  509343      5.4              None      None  None       None
#
#         floor_area  longest_ridge_line_height  year_of_construction  \
# 0              NaN                        NaN                   NaN
# 1              NaN                        NaN                   NaN
# 2              NaN                        NaN                   NaN
# 3              NaN                        NaN                   NaN
# 4              NaN                        NaN                   NaN
# ...            ...                        ...                   ...
# 509339         NaN                        NaN                   NaN
# 509340         NaN                        NaN                   NaN
# 509341         NaN                        NaN                   NaN
# 509342         NaN                        NaN                   NaN
# 509343         NaN                        NaN                   NaN
#
#                    x  ...     mibFR    mibSCo    ltcBuA     mtbAli     mtbNDi  \
# 0       4.074289e+06  ...  3.534709  3.534709  0.714286  13.600839  24.118625
# 1       4.089195e+06  ...  4.032426  4.032426  1.000000   9.473168  26.608234
# 2       4.094213e+06  ...  3.429879  3.429879  0.800000   5.508635   9.249453
# 3       4.094202e+06  ...  3.429879  3.429879  0.625000   7.659844  15.103698
# 4       4.065497e+06  ...  1.588395  1.588395  0.800000  15.359300  12.923100
# ...              ...  ...       ...       ...       ...        ...        ...
# 509339  4.060535e+06  ...  2.292415  2.292415  0.833333   4.365382  58.931527
# 509340  4.060650e+06  ...  3.464946  3.464946  1.000000   6.595432  57.555612
# 509341  4.060423e+06  ...  1.008172  1.008172  0.800000   2.756030  27.481861
# 509342  4.076046e+06  ...  7.644595  7.644595  0.500000   0.803418   7.907881
# 509343  4.076048e+06  ...  7.644595  7.644595  0.444444   1.629514  21.572230
#
#            ltbIBD     stbCeA      nID     stbSAl   nodeID
# 0       25.571227   3.588619   7588.0  36.901057  10875.0
# 1       44.808716   0.906213  25143.0   0.780502  26425.0
# 2       25.848839   0.111944   4754.0  13.514299   6300.0
# 3       22.557499   1.013223   4753.0  15.576274   6300.0
# 4       51.876631  23.053677   8642.0  19.486388  12414.0
# ...           ...        ...      ...        ...      ...
# 509339  54.332907   4.881730   2789.0   4.050940   3977.0
# 509340  47.561499  21.806536   2789.0   5.093401   3977.0
# 509341  49.969019   1.997571   2789.0  14.009507   3977.0
# 509342  14.622119  13.491768    490.0   5.019403    688.0
# 509343  15.233175   1.252830    490.0   8.202156    688.0
#
# [509344 rows x 45 columns]

# %%
# buildings = (
#     gpd.read_parquet(f"{chars_dir}buildings_chars_{region}.parquet")
#     # .to_crs(4326)
#     .reset_index()
# )

# buildings.geometry = buildings.make_valid()

# buildings = buildings[buildings.geom_type.str.contains("Polygon")]

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.PolygonLayer.from_geopandas(buildings, opacity=0.3)
# Out:
# /home/martin/dev/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/lonboard/_geoarrow/ops/reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# CPU times: user 2.37 s, sys: 89 ms, total: 2.46 s
# Wall time: 2.46 s

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="buildings")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
buildings.columns
# Out:
# Index(['index', 'gml_id', 'description', 'beginLifespanVersion',
#        'conditionOfConstruction', 'localId', 'namespace', 'versionId',
#        'referenceGeometry', 'horizontalGeometryEstimatedAccuracy', 'x', 'y',
#        'id', 'iid', 'geometry', 'ssbCCo', 'ssbCor', 'ssbSqu', 'ssbCCM',
#        'ssbCCD', 'sdbAre', 'sdbPer', 'sdbCoA', 'ssbERI', 'ssbElo', 'stbOri',
#        'mtbSWR', 'libNCo', 'ldbPWL', 'mibCou', 'mibLen', 'mibAre', 'mibElo',
#        'mibERI', 'mibCCo', 'mibLAL', 'mibFR', 'mibSCo', 'ltcBuA', 'mtbAli',
#        'mtbNDi', 'ltbIBD', 'stbCeA', 'nID', 'stbSAl', 'nodeID'],
#       dtype='object')

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
# buildings.explore()

# %%
column = "mtbSWR"
used_keys[column]
# Out:
# 'shared walls ratio of buildings'

# %%
classifier = classify(buildings[column], "quantiles", k=50)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_fill_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])
# Out:
# /home/martin/dev/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/mapclassify/classifiers.py:1760: UserWarning: Not enough unique values in array to form 50 classes. Setting k to 31.
#   self.bins = quantile(y, k=k)

# %%
buildings[column].describe().iloc[1:]
# Out:
# mean    0.698909
# std     0.189620
# min     0.038621
# 25%     0.569519
# 50%     0.718208
# 75%     0.852572
# max     0.999996
# Name: mibElo, dtype: float64

# %% [markdown]
# ## Tessellation

# %% [markdown]
# Load tessellation data and ensure the geometries are all valid Polygons.

# %%
tess = gpd.read_parquet(f"{chars_dir}tessellations_chars_{region}.parquet").to_crs(4326)

tess.geometry = tess.make_valid()

tess = tess[tess.geom_type.str.contains("Polygon")]

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.SolidPolygonLayer.from_geopandas(tess, opacity=0.2)
# Out:
# CPU times: user 4.89 s, sys: 341 ms, total: 5.23 s
# Wall time: 5.24 s

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="tess")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
tess.columns
# Out:
# Index(['enclosure_index', 'geometry', 'stcOri', 'sdcLAL', 'sdcAre', 'sscCCo',
#        'sscERI', 'mtcWNe', 'mdcAre', 'ltcWRB', 'sicCAR', 'barea', 'micBAD',
#        'licBAD', 'stcSAl', 'nID', 'nodeID'],
#       dtype='object')

# %%
column = "barea"
used_keys[column]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 column = 'barea'
# ----> 2 used_keys[column]
#
# KeyError: 'barea'

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
classifier = classify(tess[column], "quantiles", k=40)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_fill_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])

# %% [markdown]
# ## Enclosures

# %% [markdown]
# Load data and ensure the geometries are all valid Polygons.

# %%
enc = gpd.read_parquet(f"{chars_dir}enclosures_chars_{region}.parquet").to_crs(4326)

enc.geometry = enc.make_valid()

enc = enc[enc.geom_type.str.contains("Polygon")]

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.SolidPolygonLayer.from_geopandas(enc, opacity=0.3)
# Out:
# CPU times: user 168 ms, sys: 31.9 ms, total: 200 ms
# Wall time: 200 ms

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="enclosures")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
enc.columns
# Out:
# Index(['eID', 'geometry', 'ldkAre', 'ldkPer', 'lskCCo', 'lskERI', 'lskCWA',
#        'ltkOri', 'ltkWNB', 'likWCe', 'likWBB'],
#       dtype='object')

# %%
column = "ldkPer"
used_keys[column]
# Out:
# 'perimeter of enclosure'

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
classifier = classify(enc[column], "quantiles", k=20)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_fill_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])

# %% [markdown]
# ## Streets

# %% [markdown]
# Load data and ensure the geometries are all valid Polygons.

# %%
streets = gpd.read_parquet(f"{chars_dir}streets_chars_{region}.parquet")

streets.geometry = streets.make_valid()

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.PathLayer.from_geopandas(streets.to_crs(4326), width_min_pixels=1)
# Out:
# CPU times: user 154 ms, sys: 11.9 ms, total: 166 ms
# Wall time: 165 ms

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="streets")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
assert np.allclose(streets["sdsLen"], streets.geometry.length)

if "mm_len" in streets.columns:
    assert np.allclose(streets["mm_len"], streets.geometry.length)

# %%
streets.columns
# Out:
# Index(['geometry', '_status', 'mm_len', 'cdsbool', 'node_start', 'node_end',
#        'sdsLen', 'sssLin', 'ldsMSL', 'sdsAre', 'ldsRea', 'ldsAre', 'sisBpM',
#        'misBAD', 'sdsSPW', 'sdsSPO', 'sdsSWD', 'nID'],
#       dtype='object')

# %%
streets[
    [
        "sdsLen",
        "sssLin",
        "ldsMSL",
        "sdsAre",
        "ldsRea",
        "ldsAre",
        "sisBpM",
        "sdsSPW",
        "sdsSPO",
        "sdsSWD",
    ]
].describe()
# Out:
#              sdsLen        sssLin        ldsMSL        sdsAre        ldsRea  \
# count  24155.000000  24155.000000  24155.000000  1.968500e+04  24155.000000
# mean     386.031895      0.957977    399.593607  5.395904e+04    264.258456
# std      629.662917      0.099379    349.484916  9.218028e+04    175.471539
# min        1.779955      0.000000     22.997029  2.226503e-01      0.000000
# 25%       98.983143      0.970070    169.476379  8.441501e+03    147.000000
# 50%      193.610800      0.997328    250.932766  2.240300e+04    242.000000
# 75%      377.847408      0.999998    504.787106  5.820301e+04    354.000000
# max    16951.254801      1.000000   6126.390497  1.758182e+06   1377.000000
#
#              ldsAre        sisBpM        sdsSPW        sdsSPO        sdsSWD
# count  2.245400e+04  19046.000000  24155.000000  24155.000000  17632.000000
# mean   9.260281e+05      0.063553     36.597900      0.821258      3.913480
# std    9.230841e+05      0.052849     11.300294      0.183244      1.956093
# min    3.801642e+03      0.000167      0.000000      0.050000      0.000000
# 25%    3.116659e+05      0.025527     26.756167      0.687500      2.555375
# 50%    6.098273e+05      0.052691     37.182577      0.869919      4.062591
# 75%    1.195124e+06      0.089664     50.000000      1.000000      5.386908
# max    8.037908e+06      1.846862     50.000000      1.000000     11.008117

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
column = "ldsAre"
used_keys[column]
# Out:
# 'reached total ETC area by local street network'

# %%
streets[column] = streets[column].fillna(0)

# %%
classifier = classify(streets[column].astype(int), "quantiles", k=50)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])

# %% [markdown]
# ## Nodes

# %% [markdown]
# Load data and ensure the geometries are all valid Polygons.

# %%
nodes = gpd.read_parquet(f"{chars_dir}nodes_chars_{region}.parquet").to_crs(4326)

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.ScatterplotLayer.from_geopandas(nodes, radius_min_pixels=2)
# Out:
# CPU times: user 33.8 ms, sys: 2.97 ms, total: 36.8 ms
# Wall time: 36.5 ms

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="nodes")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.Positron)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
nodes.columns
# Out:
# Index(['x', 'y', 'mtdDeg', 'lcdMes', 'linP3W', 'linP4W', 'linPDE', 'lcnClo',
#        'lddNDe', 'linWID', 'ldsCDL', 'xcnSCl', 'mtdMDi', 'nodeID', 'geometry',
#        'midBAD', 'sddAre', 'midRea', 'midAre'],
#       dtype='object')

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
nodes[
    [
        "mtdDeg",
        "lcdMes",
        "linP3W",
        "linP4W",
        "linPDE",
        "lcnClo",
        "lddNDe",
        "linWID",
        "ldsCDL",
        "xcnSCl",
        "mtdMDi",
        "nodeID",
        "geometry",
        "sddAre",
        "midRea",
        "midAre",
    ]
].describe()
# Out:
#              mtdDeg        lcdMes        linP3W        linP4W        linPDE  \
# count  19496.000000  19496.000000  19496.000000  19496.000000  19496.000000
# mean       2.477944      0.085284      0.682505      0.104283      0.212255
# std        1.014198      0.054032      0.118264      0.083171      0.110212
# min        1.000000     -1.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.047059      0.622951      0.045455      0.142857
# 50%        3.000000      0.081081      0.695652      0.090909      0.200000
# 75%        3.000000      0.117647      0.760000      0.146341      0.266667
# max        5.000000      0.352941      1.000000      0.550000      1.000000
#
#              lcnClo        lddNDe        linWID        ldsCDL        xcnSCl  \
# count  1.949600e+04  19496.000000  19496.000000  19496.000000  19496.000000
# mean   1.887256e-06      0.003526      0.005831    882.309517      0.021187
# std    1.405456e-06      0.002425      0.003555   1289.245276      0.047371
# min    0.000000e+00      0.000286      0.000000      0.000000      0.000000
# 25%    7.424187e-07      0.001678      0.002700    229.506759      0.000000
# 50%    1.530668e-06      0.003297      0.005482    500.392489      0.000000
# 75%    2.713025e-06      0.004740      0.008229    993.203161      0.000000
# max    9.021213e-06      0.062490      0.048315  26019.573144      0.500000
#
#              mtdMDi       nodeID        sddAre        midRea        midAre
# count  19496.000000  19496.00000  1.711600e+04  19496.000000  1.765900e+04
# mean     386.081412   9747.50000  6.205794e+04     44.577247  1.552534e+05
# std      518.177763   5628.15476  9.149249e+04     41.710329  1.992186e+05
# min        3.099139      0.00000  6.428662e+00      0.000000  2.219230e+02
# 25%      133.671630   4873.75000  1.330871e+04     14.000000  3.685127e+04
# 50%      210.929432   9747.50000  3.054813e+04     35.000000  8.467917e+04
# 75%      395.362400  14621.25000  7.022078e+04     63.000000  1.880395e+05
# max    16951.254801  19495.00000  1.280031e+06    457.000000  2.196893e+06

# %%
column = "mtdMDi"
used_keys[column]
# Out:
# 'mean distance to neighbouring nodes of street network'

# %%
classifier = classify(nodes[column], "quantiles", k=20)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_fill_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])

# %% [markdown]
# ## Visualize merged data

# %%
import pandas as pd

primary = pd.read_parquet(chars_dir + f"primary_chars_{region}.parquet")

# %%
tess = gpd.read_parquet(f"{chars_dir}tessellations_chars_{region}.parquet").to_crs(4326)
tess.geometry = tess.make_valid()
tess = tess[tess.geom_type.str.contains("Polygon")]
tess = tess[["enclosure_index", "geometry"]]

# %%
tess = tess.join(primary)

# %%
tess
# Out:
#        enclosure_index                                           geometry  \
# 0                 4292  POLYGON ((6.02685 47.87079, 6.02688 47.87084, ...
# 1                 4292  POLYGON ((6.02785 47.87357, 6.02789 47.87356, ...
# 2                 4292  POLYGON ((6.02715 47.87263, 6.0272 47.87265, 6...
# 3                 4292  POLYGON ((6.02748 47.8715, 6.0272 47.87141, 6....
# 4                 4292  POLYGON ((6.02671 47.87077, 6.02668 47.87077, ...
# ...                ...                                                ...
# 25078             3615  POLYGON ((2.64609 42.46739, 2.64627 42.46746, ...
# 25079             3615  POLYGON ((2.64609 42.46739, 2.64602 42.46744, ...
# 25080             3615  POLYGON ((2.64591 42.4675, 2.64589 42.46751, 2...
# 25081             3651  POLYGON ((2.64168 42.4683, 2.64167 42.46829, 2...
# 25082             3651  POLYGON ((2.63915 42.46813, 2.63905 42.46825, ...
#
#            sdbAre     sdbPer  sdbCoA    ssbCCo  ssbCor     ssbSqu    ssbERI  \
# 0        5.211977   9.615898     0.0  0.516584       4   1.786527  0.997946
# 1      104.209279  40.852077     0.0  0.629445       4   1.071267  0.999771
# 2       50.782876  30.273110     0.0  0.500592       4   0.922463  0.999261
# 3       13.823494  15.052444     0.0  0.594648       4   2.344267  0.997836
# 4      129.923899  45.885153     0.0  0.617143       4   0.340736  0.999808
# ...           ...        ...     ...       ...     ...        ...       ...
# 25078   71.751467  33.902475     0.0  0.632969       4   0.324528  1.000032
# 25079   89.244424  37.788165     0.0  0.632787       4   1.068803  1.002729
# 25080  108.038520  42.487980     0.0  0.580735       4   0.436655  0.999709
# 25081  145.836191  59.538635     0.0  0.367755      10   0.815958  0.874408
# 25082  180.632876  65.946471     0.0  0.370499      14  11.272266  0.891443
#
#          ssbElo  ...    mibElo    mibERI    mibCCo     mibLAL     mibFR  \
# 0      0.529904  ...  0.557318  1.014509  0.551741   3.784041  0.605716
# 1      0.957660  ...  0.651697  1.005446  0.587735  18.624055  3.109076
# 2      0.498341  ...  0.651697  1.005446  0.587735  18.624055  3.109076
# 3      0.754407  ...  0.765952  1.008661  0.614764   5.640245  0.979567
# 4      0.800433  ...  0.803507  1.003479  0.623756  16.572175  2.892592
# ...         ...  ...       ...       ...       ...        ...       ...
# 25078  0.931890  ...  0.198499  0.922816  0.205281  53.392635  3.677282
# 25079  0.862392  ...  0.198499  0.922816  0.205281  53.392635  3.677282
# 25080  0.660232  ...  0.198499  0.922816  0.205281  53.392635  3.677282
# 25081  0.456723  ...  0.461974  0.882824  0.376112  22.670134  2.528546
# 25082  0.423857  ...  0.428476  0.899341  0.377985  25.114783  2.819656
#
#          mibSCo     micBAD      licBAD      misBAD      midBAD
# 0      0.605716  47.986063  123.897282  476.535688  476.535688
# 1      3.109076  35.618158   39.326087  476.535688  476.535688
# 2      3.109076  37.103967  123.377611  476.535688  476.535688
# 3      0.979567  44.698739  118.787262  476.535688  476.535688
# 4      2.892592  98.249864  122.672534  476.535688  476.535688
# ...         ...        ...         ...         ...         ...
# 25078  3.677282  60.409994   82.414342   98.908209   98.908209
# 25079  3.677282  55.973632   83.733350   98.908209   98.908209
# 25080  3.677282  67.063675   81.179534   98.908209   98.908209
# 25081  2.528546  24.604972   24.604972   98.908209   98.908209
# 25082  2.819656  24.604972   24.604972   98.908209   98.908209
#
# [25083 rows x 78 columns]

# %% [markdown]
# Create a lonboard layer

# %%
# %%time
layer = lonboard.SolidPolygonLayer.from_geopandas(tess, opacity=0.2)
# Out:
# CPU times: user 167 ms, sys: 16.3 ms, total: 183 ms
# Wall time: 184 ms

# %% [markdown]
# Create a Sidecar view (assumes JupyterLab) for more comfortable experience.

# %%
sc = Sidecar(title="tess")

# %% [markdown]
# Create a Map object

# %%
m = lonboard.Map(layer)

# %% [markdown]
# Display map within the sidecar plugin

# %%
with sc:
    display(m)

# %% [markdown]
# List avaialable columns

# %%
tess.columns
# Out:
# Index(['enclosure_index', 'geometry', 'sdbAre', 'sdbPer', 'sdbCoA', 'ssbCCo',
#        'ssbCor', 'ssbSqu', 'ssbERI', 'ssbElo', 'ssbCCM', 'ssbCCD', 'stbOri',
#        'mtbSWR', 'libNCo', 'ldbPWL', 'ltcBuA', 'mtbAli', 'mtbNDi', 'ltbIBD',
#        'stbCeA', 'stbSAl', 'sdsLen', 'sssLin', 'ldsMSL', 'ldsRea', 'ldsAre',
#        'sisBpM', 'sdsSPW', 'sdsSPO', 'sdsSWD', 'mtdDeg', 'lcdMes', 'linP3W',
#        'linP4W', 'linPDE', 'lcnClo', 'lddNDe', 'linWID', 'ldsCDL', 'xcnSCl',
#        'mtdMDi', 'sddAre', 'midRea', 'midAre', 'stcOri', 'sdcLAL', 'sdcAre',
#        'sscCCo', 'sscERI', 'mtcWNe', 'mdcAre', 'ltcWRB', 'sicCAR', 'stcSAl',
#        'ldkAre', 'ldkPer', 'lskCCo', 'lskERI', 'lskCWA', 'ltkOri', 'ltkWNB',
#        'likWBB', 'sdsAre', 'likWCe', 'mibCou', 'mibAre', 'mibLen', 'mibElo',
#        'mibERI', 'mibCCo', 'mibLAL', 'mibFR', 'mibSCo', 'micBAD', 'licBAD',
#        'misBAD', 'midBAD'],
#       dtype='object')

# %%
graph_dir = "/data/uscuni-ulce/processed_data/neigh_graphs/"
from libpysal.graph import read_parquet

graph = read_parquet(graph_dir + f"tessellation_graph_{region}.parquet")
graph3 = graph.higher_order(k=3, lower_order=True, diagonal=True)

# %%
tess["mibElo3"] = graph3.describe(tess["mibElo"])["median"]

# %%
tess["mibERI3"] = graph3.describe(tess["mibERI"])["median"]

# %%
column = "lskERI"
used_keys[column]
# Out:
# 'equivalent rectangular index of enclosure'

# %%
tess[column].describe()
# Out:
# count    25083.000000
# mean         0.706487
# std          0.259224
# min          0.281331
# 25%          0.502071
# 50%          0.667595
# 75%          0.949421
# max          1.128042
# Name: lskERI, dtype: float64

# %% [markdown]
# Specify a column and pass its values into a choropleth representation within the map.

# %%
classifier = classify(tess[column], "quantiles", k=100)
normalizer = mpl.colors.Normalize(0, classifier.bins.shape[0])
vals = normalizer(classifier.yb)
layer.get_fill_color = apply_continuous_cmap(vals, mpl.colormaps["viridis"])
# Out:
# /home/martin/dev/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/mapclassify/classifiers.py:1760: UserWarning: Not enough unique values in array to form 100 classes. Setting k to 86.
#   self.bins = quantile(y, k=k)

# %%
## ldsAre and sdsAre, ldsRea seperate atleast somewhat apartments and industrial,
# maybe add sdsRea or
# the same stuff except for connected buildings
# or reached unique streets
# mtdMDi has potential, but we have to change it to something like distance to nearest 8 nodes or something
# square clustering does nothing, looks weird on the graph, probably something with grids...
# ldsCDL okish
# linWID oksih
# lddNDe okish
# 'local closeness of street network' suprisingly ok, but not enough variability to do anything
# meshedness bad
# degree useless

# ldbPWL - miht make thigs worse
# street profile is not great for this
# mtbNDi meh
# ltbIBD meh


# midrea and mid area are meh, stds might be more usefull
# cell area, lal not usefull
# mtcWNe not useful
# mdcAre - meh
# ltcWRB - meh

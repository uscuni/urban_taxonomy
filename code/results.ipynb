# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import rioxarray
import xarray as xr
import pandas as pd
import xvec
import dataframe_image as dfi

v = 'v3'

regions = gpd.read_parquet('/data/uscuni-ulce/regions/cadastre_regions_hull.parquet')

# %%
cluster_4_descriptions = {
    1: ("Dense Connected Developments", "In this cluster, buildings frequently share walls forming row-like structures and occupy larger portions of the area. The density of blocks and local street connectivity are moderately high, while inter-building distances remain relatively small. Overall, this configuration yields a dense, tightly arranged environment."),
    2: ("Large Interconnected Blocks", "This cluster is characterized by a high count of connected buildings forming enclosed blocks with courtyards. The covered area ratio is notably high, while street corridors are relatively narrow, resulting in consolidated building formations."),
    3: ("Extensive Courtyard Complexes", "Developments in this cluster exhibit multiple courtyards, numerous connected buildings, and large perimeter walls. Building sizes vary significantly, creating expansive connected areas distinguished by substantial adjacency and courtyard presence."),
    4: ("Massive Connected Aggregations", "This cluster displays very large connected building areas, lengthy perimeter walls, and considerable variability in building sizes. The overall formation covers vast stretches of the built environment with substantial coverage."),
    5: ("Dense Standalone Buildings", "This cluster features a well-connected street layout with a notable proportion of multi-way intersections. Shared walls between buildings are less prevalent, reflecting a pattern of standalone structures within a street network robust network."),
    6: ("Compact Development", "Development in this cluster is characterised by a moderate number of buildings and relatively dense local street connectivity. Shared walls appear regularly, and Inter-building distances are relatively small, suggesting a compact layout."),
    7: ("Cul-de-Sac Layout", "This cluster is distinguished by a significant presence of cul-de-sacs and relatively modest building coverage. Although local node density is moderate, the overall street network is not highly interconnected."),
    8: ("Aligned Winding Streets", "Here, buildings exhibit a consistent alignment along streets of varying width. However, the overall street connectivity is lower than average, leading to a moderately ordered but less connected layout."),
    9: ("Sparse Rural Development", "Developments in this cluster have greater distances between buildings and street nodes. Streets are often wider, and adjacency is comparatively low."),
    10: ("Large Wide-Spaced Complexes", "This cluster is defined by substantial building footprints, relatively wide streets, and significant spacing between structures. Buildings in this cluster stand out for their size as well as their strong compactness, squareness and rectangularity."),
    11: ("Dispersed Linear Development", "This cluster exhibits long street segments, considerable distances between intersections, and minimal shared walls. The result is a dispersed layout with moderate development density, typically forming long linear villages."),
    12: ("Linear Development", "This cluster is characterized by lengthy street segments and higher distances between street intersections, albeit shorter than in the case of Dispersed Linear Development. Buildings are isolated, relatively small and far apart from each other. Overall the total built-up area in the development is low to moderate."),
    13: ("Sparse Open Layout", "Greater distances between buildings, fewer shared walls, and a lower coverage ratio are defining traits of this cluster. Streets remain relatively open, leading to a loosely structured environment. Overall the total built-up area in the development is low."),
    14: ("Sparse Road-Linked Development", "With larger spacing between buildings, fewer shared walls, and moderate to long street segments, this cluster highlights a relatively open pattern. Compared to other sparse development, there are fewer streets relative to the number of buildings, leading to a higher granularity."),
    15: ("Large Utilitarian Development", "This cluster consists of buildings with substantial footprints, wide street profiles, and notable variation in size. The design does not emphasize sunlight exposure, creating broad but less refined configurations, typical for industrial and other service areas."),
    16: ("Extensive Wide-Spaced Developments", "This cluster is marked by large building footprints, broad street profiles, and fewer shared walls. The resulting environment is spacious, with significant open areas between structures, typical for modernist housing."),
}
cluster_4_names = {k:cluster_4_descriptions[k][0] for k in cluster_4_descriptions}
cluster_4_names
# Out:
# {1: 'Dense Connected Developments',
#  2: 'Large Interconnected Blocks',
#  3: 'Extensive Courtyard Complexes',
#  4: 'Massive Connected Aggregations',
#  5: 'Dense Standalone Buildings',
#  6: 'Compact Development',
#  7: 'Cul-de-Sac Layout',
#  8: 'Aligned Winding Streets',
#  9: 'Sparse Rural Development',
#  10: 'Large Wide-Spaced Complexes',
#  11: 'Dispersed Linear Development',
#  12: 'Linear Development',
#  13: 'Sparse Open Layout',
#  14: 'Sparse Road-Linked Development',
#  15: 'Large Utilitarian Development',
#  16: 'Extensive Wide-Spaced Developments'}

# %% [markdown]
# ## 0. Hierarchy & Results

# %% [markdown]
# ## 1. Cluster characteristics

# %%
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')

# %%
results = []
for region_id, region_hull in regions.iterrows():
    
    print(region_id)
    
    # setup regional data
    region_clusters = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{region_id}_{v}.pq', columns=['final_without_noise']).final_without_noise
    # region_clusters = region_clusters.map(cluster_mapping[4].to_dict())
    
    region_data = pd.read_parquet(f'/data/uscuni-ulce/processed_data/chars/primary_chars_{region_id}.parquet')
    region_data = region_data.loc[region_clusters.index] 
    
    region_data['label'] = region_clusters 

    results.append(region_data)

all_data = pd.concat(results, ignore_index=True)
# Out:
# 4
# 10
# 132
# 134
# 286
# 313
# 400
# 523
# 765
# 801
# 832
# 913
# 960
# 1124
# 1154
# 1387
# 1478
# 1515
# 1605
# 1718
# 1736
# 1782
# 1970
# 1981
# 2096
# 2322
# 2350
# 2478
# 2514
# 2625
# 2728
# 2975
# 3039
# 3109
# 3150
# 3221
# 3250
# 3526
# 3610
# 3612
# 3701
# 3705
# 3752
# 3759
# 3981
# 4070
# 4214
# 4215
# 4235
# 4284
# 4356
# 4382
# 4723
# 4805
# 5096
# 5191
# 5246
# 5310
# 5408
# 5427
# 5662
# 5671
# 5766
# 5883
# 6254
# 6529
# 6560
# 6576
# 6741
# 6749
# 6811
# 6873
# 6996
# 7068
# 7094
# 7280
# 7485
# 7528
# 7534
# 7681
# 7688
# 7712
# 7727
# 7805
# 7914
# 7937
# 7963
# 8046
# 8216
# 8238
# 8256
# 8265
# 8345
# 8374
# 8396
# 8592
# 8707
# 8731
# 8757
# 8759
# 8813
# 9016
# 9064
# 9074
# 9150
# 9169
# 9194
# 9284
# 9824
# 9924
# 9954
# 9972
# 10019
# 10086
# 10095
# 10124
# 10179
# 10222
# 10263
# 10277
# 10455
# 10510
# 10511
# 10563
# 10579
# 10602
# 10666
# 10794
# 10847
# 10908
# 10926
# 10970
# 11002
# 11019
# 11057
# 11141
# 11210
# 11256
# 11261
# 11305
# 11309
# 11311
# 11318
# 11367
# 11444
# 11455
# 11471
# 11667
# 11678
# 11735
# 11757
# 11799
# 11877
# 11905
# 12027
# 12084
# 12100
# 12115
# 12154
# 12191
# 12381
# 12440
# 12483
# 12552
# 12667
# 12707
# 12755
# 12756
# 12844
# 12919
# 12965
# 13076
# 13137
# 13172
# 124904
# 125016
# 125141
# 125667
# 126588
# 127101
# 127183
# 127626
# 128286
# 129032
# 129104
# 129395
# 129730
# 130341
# 130658
# 131130
# 131395
# 131786
# 131824
# 132225
# 133057
# 133100
# 133948
# 134023
# 134189
# 134454
# 134755
# 134905
# 135687
# 136169
# 136533
# 137469
# 137537
# 137636
# 137863
# 138804
# 139096
# 139621
# 139674
# 139764
# 140420
# 141272
# 141366
# 142100
# 143701
# 145906
# 146285
# 147112
# 147634
# 148018
# 148085
# 149997
# 150044
# 151676
# 152081
# 152511

# %%
# remap to cut
all_data['label'] = all_data['label'].map(cluster_mapping[4].to_dict())

# %%
region_data['label'].unique
# Out:
# <bound method Series.unique of 0        59
# 1        88
# 2        59
# 3        59
# 4        59
#          ..
# 69454    88
# 69455    92
# 69456    83
# 69457    83
# 69458    88
# Name: label, Length: 69459, dtype: int64>

# %%
## doesnt include indicator var, since that is a morphotope variable...
cluster_centres = all_data.groupby('label').mean()

# %%
f = {
    k: "{:.2f}" for k in cluster_centres.columns.values
}

cluster_centres.style.format(f).background_gradient(axis=0, cmap="BuGn")
# Out:
# <style type="text/css">
# #T_2f15f_row0_col0, #T_2f15f_row0_col42, #T_2f15f_row0_col73, #T_2f15f_row4_col61, #T_2f15f_row5_col22, #T_2f15f_row6_col24, #T_2f15f_row7_col0, #T_2f15f_row8_col36, #T_2f15f_row8_col75, #T_2f15f_row9_col62, #T_2f15f_row9_col69, #T_2f15f_row10_col0, #T_2f15f_row10_col59, #T_2f15f_row11_col0, #T_2f15f_row11_col9, #T_2f15f_row12_col73, #T_2f15f_row13_col0, #T_2f15f_row13_col32, #T_2f15f_row13_col74, #T_2f15f_row13_col75, #T_2f15f_row14_col13, #T_2f15f_row14_col63, #T_2f15f_row14_col65, #T_2f15f_row15_col13 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_2f15f_row0_col1, #T_2f15f_row0_col63, #T_2f15f_row1_col0, #T_2f15f_row4_col22, #T_2f15f_row7_col1, #T_2f15f_row8_col11, #T_2f15f_row8_col32, #T_2f15f_row11_col36, #T_2f15f_row11_col59, #T_2f15f_row13_col1, #T_2f15f_row15_col72 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_2f15f_row0_col2, #T_2f15f_row0_col12, #T_2f15f_row0_col13, #T_2f15f_row0_col40, #T_2f15f_row0_col45, #T_2f15f_row0_col49, #T_2f15f_row0_col61, #T_2f15f_row0_col65, #T_2f15f_row0_col72, #T_2f15f_row0_col74, #T_2f15f_row0_col75, #T_2f15f_row1_col24, #T_2f15f_row1_col49, #T_2f15f_row1_col64, #T_2f15f_row4_col0, #T_2f15f_row4_col73, #T_2f15f_row4_col75, #T_2f15f_row5_col20, #T_2f15f_row5_col39, #T_2f15f_row5_col45, #T_2f15f_row5_col53, #T_2f15f_row5_col63, #T_2f15f_row5_col70, #T_2f15f_row5_col71, #T_2f15f_row5_col73, #T_2f15f_row6_col1, #T_2f15f_row6_col8, #T_2f15f_row6_col42, #T_2f15f_row6_col63, #T_2f15f_row6_col73, #T_2f15f_row7_col63, #T_2f15f_row7_col69, #T_2f15f_row7_col72, #T_2f15f_row7_col73, #T_2f15f_row7_col74, #T_2f15f_row7_col75, #T_2f15f_row8_col35, #T_2f15f_row8_col70, #T_2f15f_row8_col71, #T_2f15f_row8_col72, #T_2f15f_row8_col73, #T_2f15f_row9_col12, #T_2f15f_row9_col13, #T_2f15f_row9_col34, #T_2f15f_row9_col65, #T_2f15f_row10_col70, #T_2f15f_row10_col71, #T_2f15f_row10_col74, #T_2f15f_row10_col75, #T_2f15f_row11_col5, #T_2f15f_row11_col70, #T_2f15f_row11_col71, #T_2f15f_row11_col74, #T_2f15f_row11_col75, #T_2f15f_row12_col2, #T_2f15f_row12_col72, #T_2f15f_row13_col70, #T_2f15f_row13_col71, #T_2f15f_row13_col72, #T_2f15f_row13_col73, #T_2f15f_row14_col12, #T_2f15f_row14_col64, #T_2f15f_row15_col63, #T_2f15f_row15_col65 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_2f15f_row0_col3, #T_2f15f_row13_col46, #T_2f15f_row14_col15, #T_2f15f_row15_col34, #T_2f15f_row15_col59 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_2f15f_row0_col4, #T_2f15f_row3_col36, #T_2f15f_row3_col40, #T_2f15f_row6_col46, #T_2f15f_row7_col6, #T_2f15f_row9_col41 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_2f15f_row0_col5, #T_2f15f_row1_col14, #T_2f15f_row4_col24, #T_2f15f_row4_col37, #T_2f15f_row4_col42, #T_2f15f_row4_col49, #T_2f15f_row5_col37, #T_2f15f_row6_col9, #T_2f15f_row6_col20, #T_2f15f_row6_col39, #T_2f15f_row7_col5, #T_2f15f_row7_col53, #T_2f15f_row10_col10, #T_2f15f_row12_col0, #T_2f15f_row13_col9, #T_2f15f_row14_col69, #T_2f15f_row15_col5 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_2f15f_row0_col6, #T_2f15f_row10_col3, #T_2f15f_row12_col49, #T_2f15f_row14_col51 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_2f15f_row0_col7, #T_2f15f_row2_col30, #T_2f15f_row14_col49 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_2f15f_row0_col8, #T_2f15f_row0_col37, #T_2f15f_row0_col70, #T_2f15f_row0_col71, #T_2f15f_row1_col2, #T_2f15f_row1_col13, #T_2f15f_row1_col65, #T_2f15f_row2_col2, #T_2f15f_row2_col50, #T_2f15f_row4_col9, #T_2f15f_row5_col54, #T_2f15f_row6_col41, #T_2f15f_row6_col49, #T_2f15f_row6_col53, #T_2f15f_row7_col61, #T_2f15f_row9_col9, #T_2f15f_row10_col1, #T_2f15f_row10_col38, #T_2f15f_row11_col1, #T_2f15f_row12_col25, #T_2f15f_row13_col53, #T_2f15f_row14_col2, #T_2f15f_row15_col2 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_2f15f_row0_col9, #T_2f15f_row1_col5, #T_2f15f_row1_col69, #T_2f15f_row7_col42, #T_2f15f_row7_col49, #T_2f15f_row9_col35, #T_2f15f_row10_col60 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_2f15f_row0_col10, #T_2f15f_row4_col27, #T_2f15f_row4_col58, #T_2f15f_row5_col68, #T_2f15f_row6_col27, #T_2f15f_row6_col62, #T_2f15f_row9_col22, #T_2f15f_row14_col8, #T_2f15f_row15_col43 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_2f15f_row0_col11, #T_2f15f_row11_col29 {
#   background-color: #36a164;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col14, #T_2f15f_row2_col66, #T_2f15f_row5_col4, #T_2f15f_row6_col4, #T_2f15f_row12_col6, #T_2f15f_row14_col1 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_2f15f_row0_col15, #T_2f15f_row2_col53, #T_2f15f_row2_col68, #T_2f15f_row13_col11, #T_2f15f_row13_col62 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_2f15f_row0_col16, #T_2f15f_row0_col46, #T_2f15f_row3_col15, #T_2f15f_row3_col41, #T_2f15f_row9_col36, #T_2f15f_row9_col70, #T_2f15f_row9_col71, #T_2f15f_row12_col1, #T_2f15f_row12_col9, #T_2f15f_row13_col30, #T_2f15f_row13_col60, #T_2f15f_row14_col50, #T_2f15f_row15_col61, #T_2f15f_row15_col70, #T_2f15f_row15_col71 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_2f15f_row0_col17, #T_2f15f_row2_col24, #T_2f15f_row2_col42, #T_2f15f_row11_col8, #T_2f15f_row11_col11, #T_2f15f_row12_col34 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_2f15f_row0_col18, #T_2f15f_row12_col48, #T_2f15f_row13_col38 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_2f15f_row0_col19, #T_2f15f_row7_col30, #T_2f15f_row14_col39 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_2f15f_row0_col20, #T_2f15f_row0_col24, #T_2f15f_row0_col39, #T_2f15f_row1_col72, #T_2f15f_row3_col62, #T_2f15f_row4_col5, #T_2f15f_row4_col40, #T_2f15f_row7_col32, #T_2f15f_row8_col74, #T_2f15f_row12_col32, #T_2f15f_row12_col74, #T_2f15f_row12_col75 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_2f15f_row0_col21, #T_2f15f_row3_col72, #T_2f15f_row4_col55 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col22, #T_2f15f_row0_col44, #T_2f15f_row0_col53, #T_2f15f_row0_col69, #T_2f15f_row1_col74, #T_2f15f_row1_col75, #T_2f15f_row3_col50, #T_2f15f_row4_col1, #T_2f15f_row4_col19, #T_2f15f_row4_col53, #T_2f15f_row5_col5, #T_2f15f_row5_col44, #T_2f15f_row6_col5, #T_2f15f_row6_col40, #T_2f15f_row6_col61, #T_2f15f_row7_col70, #T_2f15f_row7_col71, #T_2f15f_row8_col0, #T_2f15f_row8_col9, #T_2f15f_row8_col59, #T_2f15f_row12_col5, #T_2f15f_row12_col70, #T_2f15f_row12_col71, #T_2f15f_row13_col5 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_2f15f_row0_col23, #T_2f15f_row2_col20, #T_2f15f_row9_col74, #T_2f15f_row12_col42, #T_2f15f_row14_col34 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_2f15f_row0_col25, #T_2f15f_row3_col38 {
#   background-color: #43af78;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col26, #T_2f15f_row2_col52, #T_2f15f_row8_col57, #T_2f15f_row13_col42 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_2f15f_row0_col27, #T_2f15f_row0_col41, #T_2f15f_row2_col40, #T_2f15f_row3_col48, #T_2f15f_row5_col19, #T_2f15f_row6_col57, #T_2f15f_row10_col32, #T_2f15f_row11_col15, #T_2f15f_row11_col25, #T_2f15f_row11_col49, #T_2f15f_row13_col36, #T_2f15f_row13_col40, #T_2f15f_row13_col50, #T_2f15f_row14_col59, #T_2f15f_row15_col11, #T_2f15f_row15_col57 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_2f15f_row0_col28, #T_2f15f_row4_col59, #T_2f15f_row15_col31 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col29, #T_2f15f_row11_col33, #T_2f15f_row15_col21 {
#   background-color: #2f9a59;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col30, #T_2f15f_row5_col66, #T_2f15f_row9_col21 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col31, #T_2f15f_row2_col55, #T_2f15f_row9_col44, #T_2f15f_row13_col21 {
#   background-color: #3aa66a;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col32, #T_2f15f_row12_col10 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_2f15f_row0_col33, #T_2f15f_row4_col6, #T_2f15f_row13_col3, #T_2f15f_row15_col1, #T_2f15f_row15_col49 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_2f15f_row0_col34 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_2f15f_row0_col35, #T_2f15

# %%
from core.utils import used_keys
new_keys = used_keys.copy()
new_keys['limLPS'] = 'building structure optimised for sunlight'

# %% [markdown]
# #### get a subset of differentiating variables

# %%
linkage_matrix = np.load(f'/data/uscuni-ulce/processed_data/clusters/kmeans_linkage_{v}.npy')
regional_ward_morphotopes_data = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_input_data_{v}.pq')

# %%
from scipy.cluster.hierarchy import fcluster
final_cutoff = 1/4 -0.00001
clusters = fcluster(linkage_matrix, t=final_cutoff, criterion='distance')
final_clusters = pd.Series(clusters, regional_ward_morphotopes_data.index)

cinput_data = regional_ward_morphotopes_data.groupby(final_clusters).median()
total_median = regional_ward_morphotopes_data.median()


results = []
for i, row_data in cinput_data.iterrows():
    diffs = row_data - total_median
    top_diffs = ((diffs) ** 2).sort_values().iloc[-10:]
    top_diffs = diffs.loc[top_diffs.index].sort_values(ascending=False)
    results.append(top_diffs.index.values)

col_subset = np.unique(results)
col_subset.shape
# Out:
# (52,)

# %%
col_keys = new_keys.copy()
to_drop = ['stcSAl','stbOri','stcOri','stbCeA', 
               'ldkAre', 'ldkPer', 'lskCCo', 'lskERI',
               'lskCWA', 'ltkOri', 'ltkWNB', 'likWBB', 'likWCe',
              'licBAD',
              'misBAD',
               'ssbCCM',
               'ssbCCD'
              ]

for k in to_drop:
    col_keys.pop(k, None)

# %% [markdown]
# #### plot tables

# %%
cluster_centres['limLPS'] = [2.0] * 9 + [-4.8, 2, 2, 2, 2, -4.8, 2]
table_data = cluster_centres.loc[:, cluster_centres.columns[cluster_centres.columns.isin(list(col_keys.keys()))]]
table_data.columns = [col_keys[k] for k in table_data.columns]
table_data.index = table_data.index.map(cluster_4_names).values

# %%
cols1 = table_data.columns[:table_data.columns.shape[0] // 2]
cols2 = table_data.columns[table_data.columns.shape[0] // 2:]

# %%
table = table_data.loc[:, cols1]
f = {
    k: "{:.2f}" for k in table_data.columns.values
}
table = table.loc[['Dense Connected Developments', 'Large Interconnected Blocks',
       'Dense Standalone Buildings', 'Compact Development',
       'Cul-de-Sac Layout', 'Aligned Winding Streets',
       'Sparse Rural Development',
       'Dispersed Linear Development', 'Linear Development',
       'Sparse Open Layout', 'Sparse Road-Linked Development',
       'Large Utilitarian Development', 'Extensive Wide-Spaced Developments']].style.format(f).background_gradient(axis=0, cmap="BuGn")
table
# Out:
# <style type="text/css">
# #T_8e41e_row0_col0, #T_8e41e_row4_col18, #T_8e41e_row5_col0, #T_8e41e_row5_col2, #T_8e41e_row9_col8, #T_8e41e_row10_col0 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_8e41e_row0_col1, #T_8e41e_row3_col19, #T_8e41e_row4_col17, #T_8e41e_row9_col0, #T_8e41e_row9_col26, #T_8e41e_row10_col1 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_8e41e_row0_col2 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_8e41e_row0_col3, #T_8e41e_row8_col25 {
#   background-color: #45b07b;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col4, #T_8e41e_row11_col24 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_8e41e_row0_col5, #T_8e41e_row7_col27, #T_8e41e_row11_col25 {
#   background-color: #7ccbb4;
#   color: #000000;
# }
# #T_8e41e_row0_col6, #T_8e41e_row5_col21 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col7, #T_8e41e_row11_col4 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col8, #T_8e41e_row2_col26 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col9, #T_8e41e_row2_col2, #T_8e41e_row2_col18, #T_8e41e_row6_col5, #T_8e41e_row6_col28 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_8e41e_row0_col10 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_8e41e_row0_col11 {
#   background-color: #aadfd3;
#   color: #000000;
# }
# #T_8e41e_row0_col12 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_8e41e_row0_col13, #T_8e41e_row10_col26 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_8e41e_row0_col14 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_8e41e_row0_col15, #T_8e41e_row4_col5, #T_8e41e_row4_col13, #T_8e41e_row11_col28 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_8e41e_row0_col16, #T_8e41e_row0_col20, #T_8e41e_row4_col2, #T_8e41e_row5_col28, #T_8e41e_row6_col10, #T_8e41e_row9_col28, #T_8e41e_row10_col10 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_8e41e_row0_col17 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_8e41e_row0_col18, #T_8e41e_row2_col0, #T_8e41e_row3_col10, #T_8e41e_row4_col1, #T_8e41e_row6_col2, #T_8e41e_row9_col10, #T_8e41e_row11_col9, #T_8e41e_row12_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_8e41e_row0_col19, #T_8e41e_row5_col18 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_8e41e_row0_col21, #T_8e41e_row1_col5, #T_8e41e_row1_col8, #T_8e41e_row1_col9, #T_8e41e_row1_col10, #T_8e41e_row1_col17, #T_8e41e_row1_col25, #T_8e41e_row1_col26, #T_8e41e_row1_col28, #T_8e41e_row2_col7, #T_8e41e_row3_col27, #T_8e41e_row4_col3, #T_8e41e_row4_col7, #T_8e41e_row4_col29, #T_8e41e_row5_col24, #T_8e41e_row6_col11, #T_8e41e_row6_col13, #T_8e41e_row6_col14, #T_8e41e_row6_col15, #T_8e41e_row6_col22, #T_8e41e_row6_col23, #T_8e41e_row7_col6, #T_8e41e_row7_col16, #T_8e41e_row7_col18, #T_8e41e_row7_col19, #T_8e41e_row7_col20, #T_8e41e_row9_col12, #T_8e41e_row10_col24, #T_8e41e_row11_col0, #T_8e41e_row11_col22, #T_8e41e_row12_col1, #T_8e41e_row12_col2, #T_8e41e_row12_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col22, #T_8e41e_row9_col1 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_8e41e_row0_col23, #T_8e41e_row7_col28, #T_8e41e_row11_col21, #T_8e41e_row12_col8 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_8e41e_row0_col24, #T_8e41e_row2_col6 {
#   background-color: #3aa66a;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col25 {
#   background-color: #3da96f;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col26, #T_8e41e_row8_col7 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col27 {
#   background-color: #39a569;
#   color: #f1f1f1;
# }
# #T_8e41e_row0_col28 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_8e41e_row0_col29, #T_8e41e_row5_col8 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_8e41e_row1_col0 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_8e41e_row1_col1, #T_8e41e_row5_col5, #T_8e41e_row6_col19, #T_8e41e_row10_col18 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_8e41e_row1_col2, #T_8e41e_row3_col7 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_8e41e_row1_col3 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_8e41e_row1_col4, #T_8e41e_row6_col16, #T_8e41e_row7_col25 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_8e41e_row1_col6, #T_8e41e_row1_col11, #T_8e41e_row1_col13, #T_8e41e_row1_col14, #T_8e41e_row1_col15, #T_8e41e_row1_col16, #T_8e41e_row1_col18, #T_8e41e_row1_col22, #T_8e41e_row1_col23, #T_8e41e_row1_col24, #T_8e41e_row1_col29, #T_8e41e_row2_col9, #T_8e41e_row2_col10, #T_8e41e_row3_col0, #T_8e41e_row3_col1, #T_8e41e_row3_col9, #T_8e41e_row3_col20, #T_8e41e_row4_col9, #T_8e41e_row4_col19, #T_8e41e_row4_col25, #T_8e41e_row4_col26, #T_8e41e_row4_col27, #T_8e41e_row4_col28, #T_8e41e_row6_col8, #T_8e41e_row6_col9, #T_8e41e_row6_col17, #T_8e41e_row6_col21, #T_8e41e_row7_col2, #T_8e41e_row7_col4, #T_8e41e_row7_col5, #T_8e41e_row7_col9, #T_8e41e_row7_col12, #T_8e41e_row8_col2, #T_8e41e_row8_col9, #T_8e41e_row9_col9, #T_8e41e_row10_col9, #T_8e41e_row12_col3, #T_8e41e_row12_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_8e41e_row1_col7, #T_8e41e_row9_col6 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_8e41e_row1_col12 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_8e41e_row1_col19 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_8e41e_row1_col20, #T_8e41e_row3_col2, #T_8e41e_row3_col16, #T_8e41e_row4_col10, #T_8e41e_row5_col9, #T_8e41e_row7_col10, #T_8e41e_row8_col10, #T_8e41e_row9_col19 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_8e41e_row1_col21, #T_8e41e_row7_col22, #T_8e41e_row10_col11 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_8e41e_row1_col27, #T_8e41e_row3_col29, #T_8e41e_row8_col17 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_8e41e_row2_col1, #T_8e41e_row8_col5 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_8e41e_row2_col3, #T_8e41e_row6_col20 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col4, #T_8e41e_row2_col23, #T_8e41e_row4_col23, #T_8e41e_row12_col5 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_8e41e_row2_col5 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_8e41e_row2_col8, #T_8e41e_row7_col1, #T_8e41e_row12_col20 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_8e41e_row2_col11 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col12, #T_8e41e_row2_col29, #T_8e41e_row6_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_8e41e_row2_col13, #T_8e41e_row9_col5 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_8e41e_row2_col14 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_8e41e_row2_col15, #T_8e41e_row2_col20, #T_8e41e_row4_col16, #T_8e41e_row5_col17, #T_8e41e_row7_col8, #T_8e41e_row10_col2 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_8e41e_row2_col16, #T_8e41e_row12_col19 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_8e41e_row2_col17, #T_8e41e_row12_col14 {
#   background-color: #2e9756;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col19, #T_8e41e_row10_col4 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_8e41e_row2_col21, #T_8e41e_row6_col29 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col22, #T_8e41e_row10_col14 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_8e41e_row2_col24 {
#   background-color: #5bbc96;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col25, #T_8e41e_row9_col14, #T_8e41e_row12_col11 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col27, #T_8e41e_row12_col0 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_8e41e_row2_col28 {
#   background-color: #35a063;
#   color: #f1f1f1;
# }
# #T_8e41e_row3_col3, #T_8e41e_row6_col27 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_8e41e_row3_col4 {
#   background-color: #ade0d4;
#   color: #000000;
# }
# #T_8e41e_row3_col5 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_8e41e_row3_col6, #T_8e41e_row8_col16, #T_8e41e_row12_col23 {
#   background-color: #309b5b;
#   color: #f1f1f1;
# }
# #T_8e41e_row3_col8, #T_8e41e_row11_col3, #T_8e41e_row12_col28 {
#   background-color: #82ceb8;
#   color: #000000;
# }
# #T_8e41e_row3_col11 {
#   background-c

# %%
await dfi.export_async(table, '../data/features1.png')

# %%
table = table_data.loc[:, cols2]
f = {
    k: "{:.2f}" for k in table_data.columns.values
}
table2 = table.loc[['Dense Connected Developments', 'Large Interconnected Blocks',
       'Dense Standalone Buildings', 'Compact Development',
       'Cul-de-Sac Layout', 'Aligned Winding Streets',
       'Sparse Rural Development',
       'Dispersed Linear Development', 'Linear Development',
       'Sparse Open Layout', 'Sparse Road-Linked Development',
       'Large Utilitarian Development', 'Extensive Wide-Spaced Developments']].style.format(f).background_gradient(axis=0, cmap="BuGn")
table2
# Out:
# <style type="text/css">
# #T_ab238_row0_col0, #T_ab238_row0_col1, #T_ab238_row10_col23 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col2 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col3, #T_ab238_row7_col4, #T_ab238_row12_col18 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_ab238_row0_col4 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col5, #T_ab238_row2_col28, #T_ab238_row3_col20, #T_ab238_row10_col19 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_ab238_row0_col6, #T_ab238_row0_col10, #T_ab238_row3_col5, #T_ab238_row3_col10, #T_ab238_row3_col17, #T_ab238_row3_col19, #T_ab238_row3_col27, #T_ab238_row4_col8, #T_ab238_row4_col24, #T_ab238_row4_col25, #T_ab238_row4_col26, #T_ab238_row4_col28, #T_ab238_row7_col18, #T_ab238_row7_col20, #T_ab238_row8_col18, #T_ab238_row8_col19, #T_ab238_row8_col20, #T_ab238_row8_col27, #T_ab238_row9_col7, #T_ab238_row9_col18, #T_ab238_row12_col7 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_ab238_row0_col7 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_ab238_row0_col8, #T_ab238_row0_col14, #T_ab238_row0_col17, #T_ab238_row2_col18, #T_ab238_row4_col27, #T_ab238_row6_col2, #T_ab238_row6_col19, #T_ab238_row6_col20, #T_ab238_row7_col28, #T_ab238_row9_col20, #T_ab238_row10_col20 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_ab238_row0_col9, #T_ab238_row1_col14, #T_ab238_row2_col6, #T_ab238_row2_col17, #T_ab238_row2_col27, #T_ab238_row3_col9, #T_ab238_row4_col18, #T_ab238_row6_col1, #T_ab238_row6_col24, #T_ab238_row7_col24, #T_ab238_row8_col24, #T_ab238_row9_col19, #T_ab238_row10_col18 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_ab238_row0_col11, #T_ab238_row1_col3, #T_ab238_row1_col5, #T_ab238_row1_col6, #T_ab238_row1_col8, #T_ab238_row1_col9, #T_ab238_row1_col10, #T_ab238_row1_col17, #T_ab238_row1_col22, #T_ab238_row1_col23, #T_ab238_row2_col19, #T_ab238_row2_col20, #T_ab238_row2_col24, #T_ab238_row2_col25, #T_ab238_row2_col26, #T_ab238_row3_col6, #T_ab238_row3_col8, #T_ab238_row3_col14, #T_ab238_row3_col28, #T_ab238_row4_col4, #T_ab238_row4_col7, #T_ab238_row4_col19, #T_ab238_row4_col20, #T_ab238_row6_col0, #T_ab238_row6_col13, #T_ab238_row6_col15, #T_ab238_row6_col16, #T_ab238_row6_col18, #T_ab238_row7_col1, #T_ab238_row7_col2, #T_ab238_row7_col19, #T_ab238_row7_col27, #T_ab238_row11_col12, #T_ab238_row11_col29, #T_ab238_row12_col21 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_ab238_row0_col12, #T_ab238_row10_col2 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_ab238_row0_col13, #T_ab238_row2_col22 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col15, #T_ab238_row3_col23, #T_ab238_row6_col3 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col16, #T_ab238_row8_col6 {
#   background-color: #40ad75;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col18, #T_ab238_row4_col16, #T_ab238_row9_col17 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_ab238_row0_col19, #T_ab238_row1_col7, #T_ab238_row4_col3, #T_ab238_row5_col12 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_ab238_row0_col20, #T_ab238_row4_col9, #T_ab238_row12_col13 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_ab238_row0_col21 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_ab238_row0_col22 {
#   background-color: #4ab381;
#   color: #f1f1f1;
# }
# #T_ab238_row0_col23 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_ab238_row0_col24, #T_ab238_row10_col17 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_ab238_row0_col25, #T_ab238_row0_col26, #T_ab238_row10_col6 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_ab238_row0_col27, #T_ab238_row3_col25, #T_ab238_row3_col26, #T_ab238_row4_col17, #T_ab238_row5_col28, #T_ab238_row8_col2 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_ab238_row0_col28, #T_ab238_row2_col3, #T_ab238_row2_col8, #T_ab238_row3_col3, #T_ab238_row3_col24, #T_ab238_row4_col5, #T_ab238_row5_col19, #T_ab238_row5_col20, #T_ab238_row5_col27, #T_ab238_row7_col25, #T_ab238_row7_col26, #T_ab238_row8_col25, #T_ab238_row8_col26, #T_ab238_row9_col24, #T_ab238_row10_col27 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_ab238_row0_col29, #T_ab238_row1_col0, #T_ab238_row1_col1, #T_ab238_row1_col2, #T_ab238_row1_col13, #T_ab238_row1_col15, #T_ab238_row1_col16, #T_ab238_row1_col18, #T_ab238_row1_col19, #T_ab238_row1_col20, #T_ab238_row1_col24, #T_ab238_row1_col29, #T_ab238_row2_col4, #T_ab238_row2_col12, #T_ab238_row2_col21, #T_ab238_row2_col23, #T_ab238_row2_col29, #T_ab238_row3_col29, #T_ab238_row4_col29, #T_ab238_row5_col29, #T_ab238_row6_col9, #T_ab238_row6_col10, #T_ab238_row6_col22, #T_ab238_row6_col29, #T_ab238_row7_col3, #T_ab238_row7_col5, #T_ab238_row7_col6, #T_ab238_row7_col7, #T_ab238_row7_col8, #T_ab238_row7_col11, #T_ab238_row7_col17, #T_ab238_row7_col29, #T_ab238_row8_col29, #T_ab238_row9_col29, #T_ab238_row10_col29, #T_ab238_row11_col14, #T_ab238_row11_col25, #T_ab238_row11_col26, #T_ab238_row11_col27, #T_ab238_row11_col28, #T_ab238_row12_col29 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ab238_row1_col4, #T_ab238_row3_col21 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_ab238_row1_col11, #T_ab238_row3_col15 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_ab238_row1_col12, #T_ab238_row11_col4 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_ab238_row1_col21, #T_ab238_row4_col15, #T_ab238_row5_col16, #T_ab238_row10_col13 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_ab238_row1_col25, #T_ab238_row1_col26, #T_ab238_row2_col0 {
#   background-color: #3ca86d;
#   color: #f1f1f1;
# }
# #T_ab238_row1_col27, #T_ab238_row2_col9, #T_ab238_row4_col10, #T_ab238_row4_col14, #T_ab238_row5_col5, #T_ab238_row8_col4, #T_ab238_row9_col25, #T_ab238_row9_col26 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_ab238_row1_col28, #T_ab238_row9_col0 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_ab238_row2_col1 {
#   background-color: #2b9452;
#   color: #f1f1f1;
# }
# #T_ab238_row2_col2 {
#   background-color: #2f9858;
#   color: #f1f1f1;
# }
# #T_ab238_row2_col5, #T_ab238_row4_col6, #T_ab238_row6_col27, #T_ab238_row8_col28, #T_ab238_row10_col24, #T_ab238_row11_col15 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_ab238_row2_col7, #T_ab238_row12_col5 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_ab238_row2_col10, #T_ab238_row3_col18, #T_ab238_row5_col18, #T_ab238_row6_col28, #T_ab238_row8_col1, #T_ab238_row9_col27, #T_ab238_row10_col25, #T_ab238_row10_col26, #T_ab238_row10_col28, #T_ab238_row11_col7 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_ab238_row2_col11, #T_ab238_row4_col23, #T_ab238_row6_col8, #T_ab238_row10_col22 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_ab238_row2_col13, #T_ab238_row4_col2 {
#   background-color: #3eaa70;
#   color: #f1f1f1;
# }
# #T_ab238_row2_col14, #T_ab238_row7_col0, #T_ab238_row11_col18, #T_ab238_row12_col15 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_ab238_row2_col15 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_ab238_row2_col16, #T_ab238_row9_col5 {
#   background-color: #bfe7de;
#   color: #000000;
# }
# #T_ab238_row3_col0 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_ab238_row3_col1 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_ab238_row3_col2 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_ab238_row3_col4, #T_ab238_row8_col5 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_ab238_row3_col7, #T_ab238_row5_col7, #T_ab238_row6_col4, #T_ab238_row8_col15 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_ab238_row3_col11 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_ab238_row3_col12 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_ab238_row3_col13, #T_ab238_row6_col5, #T_ab238_row7_col12 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_ab238_row3_col16, #T_ab238_row10_col11 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_ab238_row3_col22, #T_ab238_row11_col22 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_ab238_row4_col0 {
#   background-color: #62c0

# %%
await dfi.export_async(table2, '../data/features2.png')

# %% [markdown]
# cul-de-sac vs aligned - smaller buildings, more buildings, more local cul-de-sacs, less square, more distance to neighbouring nodes of street network, less differences in building area
#
# sparse open layout vs sparse road-linked - larger buildings, larger ETCs, larger deviation in building shapes and area
#
# extended linear development vs linear  - longer streets with more intersections,  more ETCS.
#
# rural vs linear development - large distance between neighbouring buildings, wider and more open streets
#
#
# two changes:
# change dispersed to extended
# maybe change aligned winding and cul-de-sac to urbanised aligned and urbanised cul-de-sac.

# %%
selected_cols = ['area of building', 'courtyard area of building', 'shared walls ratio of buildings',
                 'street alignment of building',
                 'mean distance between neighbouring buildings', 'alignment of neighbouring buildings',
                 'buildings per meter of street segment',

                 'length of street segment', 'width of street profile', 'linearity of street segment',
                 'local proportion of cul-de-sacs of street network', 'node degree of junction',
                 'square clustering of street network', 'mean distance to neighbouring nodes of street network', 
                 
                 'area of ETC', 'perimeter-weighted neighbours of ETC', 
                 
                 'connected buildings count', 'connected buildings facade ratio', 'deviation of building area in tess. neighbourhood']
table = table_data.loc[:, selected_cols]
f = {
    k: "{:.2f}" for k in table_data.columns.values
}
table.loc[['Dense Connected Developments', 'Large Interconnected Blocks',
       'Dense Standalone Buildings', 'Compact Development',
       'Cul-de-Sac Layout', 'Aligned Winding Streets',
       'Sparse Rural Development',
       'Dispersed Linear Development', 'Linear Development',
       'Sparse Open Layout', 'Sparse Road-Linked Development',
       'Large Utilitarian Development', 'Extensive Wide-Spaced Developments']].style.format(f).background_gradient(axis=0, cmap="BuGn")
# Out:
# <style type="text/css">
# #T_fff15_row0_col0, #T_fff15_row2_col14, #T_fff15_row3_col16, #T_fff15_row5_col0, #T_fff15_row5_col1, #T_fff15_row5_col16, #T_fff15_row9_col2, #T_fff15_row9_col18, #T_fff15_row10_col0, #T_fff15_row10_col17 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_fff15_row0_col1, #T_fff15_row9_col15, #T_fff15_row10_col12 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_fff15_row0_col2 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_fff15_row0_col3, #T_fff15_row4_col4 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_fff15_row0_col4 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_fff15_row0_col5 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_fff15_row0_col6, #T_fff15_row1_col2, #T_fff15_row1_col9, #T_fff15_row1_col11, #T_fff15_row1_col15, #T_fff15_row1_col16, #T_fff15_row2_col12, #T_fff15_row4_col10, #T_fff15_row6_col3, #T_fff15_row6_col4, #T_fff15_row6_col8, #T_fff15_row6_col14, #T_fff15_row7_col7, #T_fff15_row7_col13, #T_fff15_row9_col5, #T_fff15_row11_col0, #T_fff15_row11_col8, #T_fff15_row11_col17, #T_fff15_row11_col18, #T_fff15_row12_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_fff15_row0_col7, #T_fff15_row0_col13, #T_fff15_row4_col1 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_fff15_row0_col8, #T_fff15_row8_col15, #T_fff15_row12_col12 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_fff15_row0_col9 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_fff15_row0_col10, #T_fff15_row5_col2 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_fff15_row0_col11 {
#   background-color: #3da96f;
#   color: #f1f1f1;
# }
# #T_fff15_row0_col12 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_fff15_row0_col14, #T_fff15_row3_col1, #T_fff15_row3_col7, #T_fff15_row3_col13, #T_fff15_row3_col14, #T_fff15_row3_col18, #T_fff15_row4_col17, #T_fff15_row7_col16, #T_fff15_row8_col16, #T_fff15_row8_col18, #T_fff15_row9_col16 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_fff15_row0_col15 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_fff15_row0_col16 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_fff15_row0_col17 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_fff15_row0_col18, #T_fff15_row2_col1, #T_fff15_row3_col17 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_fff15_row1_col0, #T_fff15_row12_col15 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_fff15_row1_col1 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_fff15_row1_col3, #T_fff15_row1_col4, #T_fff15_row1_col7, #T_fff15_row1_col8, #T_fff15_row1_col10, #T_fff15_row1_col13, #T_fff15_row1_col14, #T_fff15_row2_col17, #T_fff15_row3_col0, #T_fff15_row4_col11, #T_fff15_row4_col12, #T_fff15_row6_col2, #T_fff15_row6_col6, #T_fff15_row6_col9, #T_fff15_row6_col15, #T_fff15_row6_col16, #T_fff15_row7_col1, #T_fff15_row7_col5, #T_fff15_row7_col18, #T_fff15_row8_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_fff15_row1_col5 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_fff15_row1_col6, #T_fff15_row7_col8 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_fff15_row1_col12, #T_fff15_row9_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_fff15_row1_col17 {
#   background-color: #3ca86d;
#   color: #f1f1f1;
# }
# #T_fff15_row1_col18, #T_fff15_row4_col14, #T_fff15_row5_col13, #T_fff15_row8_col12, #T_fff15_row9_col17 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_fff15_row2_col0, #T_fff15_row2_col18, #T_fff15_row4_col16, #T_fff15_row6_col1, #T_fff15_row10_col16 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_fff15_row2_col2 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_fff15_row2_col3, #T_fff15_row4_col7, #T_fff15_row4_col13, #T_fff15_row5_col9, #T_fff15_row5_col18, #T_fff15_row7_col2, #T_fff15_row7_col17, #T_fff15_row8_col17, #T_fff15_row10_col1, #T_fff15_row10_col18 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_fff15_row2_col4 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_fff15_row2_col5, #T_fff15_row2_col10 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_fff15_row2_col6, #T_fff15_row6_col10 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_fff15_row2_col7, #T_fff15_row2_col13, #T_fff15_row6_col18 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_fff15_row2_col8 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_fff15_row2_col9 {
#   background-color: #2e9756;
#   color: #f1f1f1;
# }
# #T_fff15_row2_col11 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_fff15_row2_col15 {
#   background-color: #3eaa70;
#   color: #f1f1f1;
# }
# #T_fff15_row2_col16, #T_fff15_row4_col0, #T_fff15_row4_col18 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_fff15_row3_col2 {
#   background-color: #82ceb8;
#   color: #000000;
# }
# #T_fff15_row3_col3, #T_fff15_row8_col5 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_fff15_row3_col4 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_fff15_row3_col5 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_fff15_row3_col6 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_fff15_row3_col8 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_fff15_row3_col9, #T_fff15_row9_col11, #T_fff15_row12_col18 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_fff15_row3_col10, #T_fff15_row8_col9 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_fff15_row3_col11 {
#   background-color: #44af79;
#   color: #f1f1f1;
# }
# #T_fff15_row3_col12, #T_fff15_row4_col6, #T_fff15_row8_col13 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_fff15_row3_col15, #T_fff15_row6_col13 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_fff15_row4_col2, #T_fff15_row12_col9 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_fff15_row4_col3 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_fff15_row4_col5, #T_fff15_row12_col5 {
#   background-color: #41ae77;
#   color: #f1f1f1;
# }
# #T_fff15_row4_col8 {
#   background-color: #7fcdb6;
#   color: #000000;
# }
# #T_fff15_row4_col9, #T_fff15_row9_col0 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_fff15_row4_col15, #T_fff15_row8_col11 {
#   background-color: #45b07b;
#   color: #f1f1f1;
# }
# #T_fff15_row5_col3 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_fff15_row5_col4 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_fff15_row5_col5 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_fff15_row5_col6 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_fff15_row5_col7, #T_fff15_row5_col17 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_fff15_row5_col8 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_fff15_row5_col10 {
#   background-color: #40ad75;
#   color: #f1f1f1;
# }
# #T_fff15_row5_col11 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_fff15_row5_col12 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_fff15_row5_col14, #T_fff15_row10_col2 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_fff15_row5_col15 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_fff15_row6_col0 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_fff15_row6_col5, #T_fff15_row11_col5 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_fff15_row6_col7, #T_fff15_row7_col11 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_fff15_row6_col11 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_fff15_row6_col12 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_fff15_row6_col17, #T_fff15_row8_col2 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_fff15_row7_col0, #T_fff15_row7_col12, #T_fff15_row8_col0, #T_fff15_row12_col16 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_fff15_row7_col3 {
#   background-color: #2b9452;
#   color: #f1f1f1;
# }
# #T_fff15_row7_col4 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_fff15_row7_col6 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_fff15_row7_col9 {
#   background-color: #70c6ac;
#   color: #000000;
# }
# #T_fff15_row7_col10 {
#   background-color: #38a367;
#   color: #f1f1f1;
# }
# #T_fff15_row7_col14 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_fff15_row7_col15 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_fff15_row8_col3 {

# %%
del all_data
del results

# %% [markdown]
# ## 2. Corrine LandCover

# %%
# !wget https://copernicus-fme.eea.europa.eu/clmsdatadownload/results/146146.zip

# %%
# !mv 146146.zip /data/uscuni-ulce/validation/

# %%
corrine = gpd.read_file('/data/uscuni-ulce/validation/Results/u2018_clc2018_v2020_20u1_geoPackage/DATA/U2018_CLC2018_V2020_20u1.gpkg')
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'U2018_CLC2018_V2020_20u1.gpkg': 'U2018_CLC2018_V2020_20u1' (default), 'U2018_CLC2018_V2020_20u1_FR_REU', 'U2018_CLC2018_V2020_20u1_FR_GLP', 'U2018_CLC2018_V2020_20u1_FR_GUF', 'U2018_CLC2018_V2020_20u1_FR_MTQ', 'U2018_CLC2018_V2020_20u1_FR_MYT'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
# %%time
results = []
for region_id, region_hull in regions.iterrows():
    print(region_id)
    # setup regional data
    buildings = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{region_id}_{v}.pq')
    regional_corrine = corrine[corrine.intersects(region_hull.convex_hull)].explode()

    ## spatially join buildings and corrine areas
    inp, res = buildings.centroid.sindex.query(regional_corrine.geometry, predicate='intersects')
    assert (pd.Series(res).value_counts() == 1).all()
    buildings['Code_18'] = ''
    buildings.iloc[res, -1] = regional_corrine.iloc[inp, 0]
    
    results.append(buildings)
# Out:
# 4
# 10
# 132
# 134
# 286
# 313
# 400
# 523
# 765
# 801
# 832
# 913
# 960
# 1124
# 1154
# 1387
# 1478
# 1515
# 1605
# 1718
# 1736
# 1782
# 1970
# 1981
# 2096
# 2322
# 2350
# 2478
# 2514
# 2625
# 2728
# 2975
# 3039
# 3109
# 3150
# 3221
# 3250
# 3526
# 3610
# 3612
# 3701
# 3705
# 3752
# 3759
# 3981
# 4070
# 4214
# 4215
# 4235
# 4284
# 4356
# 4382
# 4723
# 4805
# 5096
# 5191
# 5246
# 5310
# 5408
# 5427
# 5662
# 5671
# 5766
# 5883
# 6254
# 6529
# 6560
# 6576
# 6741
# 6749
# 6811
# 6873
# 6996
# 7068
# 7094
# 7280
# 7485
# 7528
# 7534
# 7681
# 7688
# 7712
# 7727
# 7805
# 7914
# 7937
# 7963
# 8046
# 8216
# 8238
# 8256
# 8265
# 8345
# 8374
# 8396
# 8592
# 8707
# 8731
# 8757
# 8759
# 8813
# 9016
# 9064
# 9074
# 9150
# 9169
# 9194
# 9284
# 9824
# 9924
# 9954
# 9972
# 10019
# 10086
# 10095
# 10124
# 10179
# 10222
# 10263
# 10277
# 10455
# 10510
# 10511
# 10563
# 10579
# 10602
# 10666
# 110657
# 110691
# 110906
# 110908
# 111555
# 111689
# 111911
# 112253
# 112437
# 112696
# 112843
# 112949
# 113068
# 113301
# 114014
# 114180
# 114311
# 114591
# 114680
# 114822
# 115151
# 115595
# 115950
# 116316
# 116523
# 116801
# 116866
# 117182
# 117638
# 117720
# 118096
# 118747
# 119562
# 119609
# 120057
# 120193
# 120545
# 120961
# 120982
# 121071
# 121143
# 123228
# 123690
# 123904
# 123941
# 124160
# 124904
# 125016
# 125141
# 125667
# 126588
# 127101
# 127183
# 127626
# 128286
# 129032
# 129104
# 129395
# 129730
# 130341
# 130658
# 131130
# 131395
# 131786
# 131824
# 132225
# 133057
# 133100
# 133948
# 134023
# 134189
# 134454
# 134755
# 134905
# 135687
# 136169
# 136533
# 137469
# 137537
# 137636
# 137863
# 138804
# 139096
# 139621
# 139674
# 139764
# 140420
# 141272
# 141366
# 142100
# 143701
# 145906
# 146285
# 147112
# 147634
# 148018
# 148085
# 149997
# 150044
# 151676
# 152081
# 152511

# %%
# %%time
all_data = pd.concat(results, ignore_index=True)
# Out:
# CPU times: user 15.3 s, sys: 5.21 s, total: 20.5 s
# Wall time: 20.4 s

# %%
# %%time
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')
all_data['map_label'] = all_data['final_without_noise'].map(cluster_mapping[4].to_dict())
# Out:
# CPU times: user 285 ms, sys: 174 ms, total: 459 ms
# Wall time: 465 ms

# %%
corrine_legend = {
    "111": "Continuous urban fabric",
    "112": "Discontinuous urban fabric",
    "121": "Industrial or commercial units",
    "122": "Road and rail networks and associated land",
    "123": "Port areas",
    "124": "Airports",
    "131": "Mineral extraction sites",
    "132": "Dump sites",
    "133": "Construction sites",
    "141": "Green urban areas",
    "142": "Sport and leisure facilities",
    "211": "Non-irrigated arable land",
    "212": "Permanently irrigated land",
    "213": "Rice fields",
    "221": "Vineyards",
    "222": "Fruit trees and berry plantations",
    "223": "Olive groves",
    "231": "Pastures",
    "241": "Annual crops associated with permanent crops",
    "242": "Complex cultivation patterns",
    "243": "Land principally occupied by agriculture, with significant areas of natural vegetation",
    "244": "Agro-forestry areas"
}

# %%
himoc_corrine_cross_tab = pd.crosstab(all_data.map_label, all_data.Code_18, normalize='index')

# drop non-urban columns
relevant_corrine_columns = himoc_corrine_cross_tab.columns[himoc_corrine_cross_tab.columns.str.startswith('1') | himoc_corrine_cross_tab.columns.str.startswith('2')]
himoc_corrine_cross_tab = himoc_corrine_cross_tab.loc[:, relevant_corrine_columns]

# map keys to names
himoc_corrine_cross_tab.index = himoc_corrine_cross_tab.index.map(cluster_4_names).values
himoc_corrine_cross_tab.columns = himoc_corrine_cross_tab.columns.map(corrine_legend).values

# %%
# focus only on relative classes
himoc_corrine_cross_tab = himoc_corrine_cross_tab[['Continuous urban fabric', 'Discontinuous urban fabric', 'Industrial or commercial units', 'Non-irrigated arable land', 
                         'Pastures', 'Complex cultivation patterns', 'Land principally occupied by agriculture, with significant areas of natural vegetation']]

# %%
f = {
    k: "{:.2f}" for k in himoc_corrine_cross_tab.columns.values
}
styled_table = himoc_corrine_cross_tab.style.format(f).background_gradient(axis=1, cmap="BuGn")
styled_table
# Out:
# <style type="text/css">
# #T_5462c_row0_col0, #T_5462c_row11_col6 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_5462c_row0_col1, #T_5462c_row1_col1, #T_5462c_row2_col2, #T_5462c_row3_col2, #T_5462c_row4_col1, #T_5462c_row5_col1, #T_5462c_row6_col1, #T_5462c_row7_col1, #T_5462c_row8_col3, #T_5462c_row9_col2, #T_5462c_row10_col1, #T_5462c_row11_col1, #T_5462c_row12_col1, #T_5462c_row13_col1, #T_5462c_row14_col2, #T_5462c_row15_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5462c_row0_col2, #T_5462c_row10_col6, #T_5462c_row13_col6 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_5462c_row0_col3, #T_5462c_row4_col2, #T_5462c_row6_col2 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_5462c_row0_col4, #T_5462c_row5_col3, #T_5462c_row5_col4 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_5462c_row0_col5, #T_5462c_row0_col6, #T_5462c_row1_col5, #T_5462c_row1_col6, #T_5462c_row2_col0, #T_5462c_row2_col1, #T_5462c_row2_col3, #T_5462c_row2_col4, #T_5462c_row2_col5, #T_5462c_row2_col6, #T_5462c_row3_col0, #T_5462c_row3_col4, #T_5462c_row3_col5, #T_5462c_row3_col6, #T_5462c_row4_col6, #T_5462c_row5_col5, #T_5462c_row5_col6, #T_5462c_row6_col0, #T_5462c_row7_col0, #T_5462c_row7_col5, #T_5462c_row7_col6, #T_5462c_row8_col0, #T_5462c_row9_col0, #T_5462c_row9_col1, #T_5462c_row9_col5, #T_5462c_row9_col6, #T_5462c_row10_col0, #T_5462c_row11_col0, #T_5462c_row12_col0, #T_5462c_row13_col0, #T_5462c_row14_col0, #T_5462c_row14_col6, #T_5462c_row15_col5, #T_5462c_row15_col6 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_5462c_row1_col0 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_5462c_row1_col2, #T_5462c_row6_col4 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_5462c_row1_col3, #T_5462c_row1_col4, #T_5462c_row3_col3, #T_5462c_row4_col0, #T_5462c_row4_col3, #T_5462c_row4_col4, #T_5462c_row4_col5, #T_5462c_row5_col2, #T_5462c_row6_col5, #T_5462c_row6_col6, #T_5462c_row9_col3, #T_5462c_row9_col4, #T_5462c_row10_col2, #T_5462c_row14_col5, #T_5462c_row15_col0, #T_5462c_row15_col4 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_5462c_row3_col1 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_5462c_row5_col0, #T_5462c_row11_col2 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_5462c_row6_col3, #T_5462c_row8_col2, #T_5462c_row10_col4 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_5462c_row7_col2 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_5462c_row7_col3 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_5462c_row7_col4 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_5462c_row8_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_5462c_row8_col4 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_5462c_row8_col5 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_5462c_row8_col6 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_5462c_row10_col3 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_5462c_row10_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_5462c_row11_col3, #T_5462c_row13_col3 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_5462c_row11_col4 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_5462c_row11_col5 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_5462c_row12_col2, #T_5462c_row14_col4 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_5462c_row12_col3 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_5462c_row12_col4 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_5462c_row12_col5 {
#   background-color: #d0ede9;
#   color: #000000;
# }
# #T_5462c_row12_col6 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_5462c_row13_col2, #T_5462c_row15_col3 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_5462c_row13_col4 {
#   background-color: #a5ddd0;
#   color: #000000;
# }
# #T_5462c_row13_col5 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_5462c_row14_col1 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_5462c_row14_col3 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_5462c_row15_col2 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# </style>
# <table id="T_5462c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5462c_level0_col0" class="col_heading level0 col0" >Continuous urban fabric</th>
#       <th id="T_5462c_level0_col1" class="col_heading level0 col1" >Discontinuous urban fabric</th>
#       <th id="T_5462c_level0_col2" class="col_heading level0 col2" >Industrial or commercial units</th>
#       <th id="T_5462c_level0_col3" class="col_heading level0 col3" >Non-irrigated arable land</th>
#       <th id="T_5462c_level0_col4" class="col_heading level0 col4" >Pastures</th>
#       <th id="T_5462c_level0_col5" class="col_heading level0 col5" >Complex cultivation patterns</th>
#       <th id="T_5462c_level0_col6" class="col_heading level0 col6" >Land principally occupied by agriculture, with significant areas of natural vegetation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5462c_level0_row0" class="row_heading level0 row0" >Dense Connected Developments</th>
#       <td id="T_5462c_row0_col0" class="data row0 col0" >0.07</td>
#       <td id="T_5462c_row0_col1" class="data row0 col1" >0.85</td>
#       <td id="T_5462c_row0_col2" class="data row0 col2" >0.04</td>
#       <td id="T_5462c_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_5462c_row0_col4" class="data row0 col4" >0.02</td>
#       <td id="T_5462c_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_5462c_row0_col6" class="data row0 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5462c_level0_row1" class="row_heading level0 row1" >Large Interconnected Blocks</th>
#       <td id="T_5462c_row1_col0" class="data row1 col0" >0.47</td>
#       <td id="T_5462c_row1_col1" class="data row1 col1" >0.48</td>
#       <td id="T_5462c_row1_col2" class="data row1 col2" >0.04</td>
#       <td id="T_5462c_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_5462c_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_5462c_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_5462c_row1_col6" class="data row1 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5462c_level0_row2" class="row_heading level0 row2" >Extensive Courtyard Complexes</th>
#       <td id="T_5462c_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_5462c_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_5462c_row2_col2" class="data row2 col2" >0.99</td>
#       <td id="T_5462c_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_5462c_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_5462c_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_5462c_row2_col6" class="data row2 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5462c_level0_row3" class="row_heading level0 row3" >Massive Connected Aggregations</th>
#       <td id="T_5462c_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_5462c_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_5462c_row3_col2" class="data row3 col2" >0.53</td>
#       <td id="T_5462c_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_5462c_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_5462c_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_5462c_row3_col6" class="data row3 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5462c_level0_row4" class="row_heading level0 row4" >Dense Standalone Buildings</th>
#       <td id="T_5462c_row4_col0" class="data row4 col0" >0.01</td>
#       <td id="T_5462c_row4_col1" class="data row4 col1" >0.92</td>
#       <td id="T_5462c_row4_col2" class="data row4 col2" >0.01</td>
#       <td id="T_5462c_row4_col3" class="data row4 col3" >0.01</td>
#       <td id="T_5462c_row4_col4" class="data row4 col4" >0.01</td>
#       <td id="T_5462c_row4_col5" class="data row4 col5" >0.01</td>
#       <td id="T_5462c_row4_col6" class="data row4 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5462c_level0_row5" class="row_heading level0 row5" >Compact Development</th>
#       <td id="T_5462c_ro

# %%
await dfi.export_async(styled_table, '../data/corine.png', dpi=300)

# %% [markdown]
# 1. The clusters broadly follow the higher level patterns that are described by the corrine land cover classification
#     - the Large Utilitarian Development	, Massive Connected Aggregations, Extensive Courtyard Complexes	, Large Wide-Spaced Complexes are mostly industrial units.
#     - Large Interconnected Blocks	is the most urban cluster and half of it is contiguous urban fabric
#     - Other types of clusters mostly fall within the Discontinuous urban fabric	cluster, which is expected
#     - The sparse development captures some aggriculture and developed land patterns
# 2. We split the classes into different sub classes, providing more information
#    - Discontinuous urban fabric is split into various classes based on the density, street characteristics and overall distances between buildings.
#    - Similarly for the less developed clusters such as Linear Development, Sparse Road-Linked Development, Sparse Rural Development	 which contain lots of villages.

# %% [markdown]
# ## 3. Urban atlas

# %%
# !wget https://copernicus-fme.eea.europa.eu/clmsdatadownload/results/145772.zip

# %%
# !mv 145772.zip /data/uscuni-ulce/validation/

# %% [markdown]
# ### Generate data

# %%
from glob import glob

furl = '/data/uscuni-ulce/validation/Results/'
files = glob(furl + 'AT*') + glob(furl + 'CZ*') + glob(furl + 'SK*') + glob(furl + 'PL*') + glob(furl + 'DE*') + glob(furl + 'LT*')
files
# Out:
# ['/data/uscuni-ulce/validation/Results/AT003L3_LINZ_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/AT005L3_INNSBRUCK_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/AT004L3_SALZBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/AT001L3_WIEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/AT002L3_GRAZ_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/AT006L2_KLAGENFURT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ004L2_PLZEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ001L2_PRAHA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ011L2_ZLIN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ014L2_JIHLAVA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ013L2_KARLOVY_VARY_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ016L2_MOST_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ003L2_OSTRAVA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ009L2_HRADEC_KRALOVE_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ008L2_CESKE_BUDEJOVICE_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ002L2_BRNO_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ007L2_LIBEREC_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ005L2_USTI_NAD_LABEM_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ010L2_PARDUBICE_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ006L2_OLOMOUC_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/CZ018L2_CHOMUTOV_JIRKOV_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK005L1_PRESOV_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK004L1_NITRA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK008L1_TRENCIN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK007L1_TRNAVA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK003L1_BANSKA_BYSTRICA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK001L1_BRATISLAVA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK002L1_KOSICE_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/SK006L1_ZILINA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL511L2_WALBRZYCH_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL032L1_PIOTRKOW_TRYBUNALSKI_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL042L1_CHELM_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL051L1_TCZEW_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL037L1_GNIEZNO_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/PL017L2_GORZOW_WIELKOPOLSKI_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/P
URG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE537L1_REUTLINGEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE072L1_FRIEDRICHSHAFEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE009L2_DRESDEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE055L0_NEUMUNSTER_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE013L1_HANNOVER_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE520L1_OLDENBURG_OLDENBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE540L2_SIEGEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE026L1_TRIER_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE040L1_SAARBRUCKEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE004L1_KOLN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE011L1_DUSSELDORF_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE061L1_ASCHAFFENBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE002L1_HAMBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE082L0_DESSAU_ROSSLAU_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE032L1_ERFURT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE539L1_COTTBUS_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE045L1_ISERLOHN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE057L1_GIESSEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE547L2_JENA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE083L1_BRAUNSCHWEIG_SALZGITTER_WOLFSBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE074L1_GORLITZ_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE021L1_GOTTINGEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE549L1_BOCHOLT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE508L0_KREFELD_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE071L1_STRALSUND_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE067L1_LANDSHUT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE077L1_SCHWEINFURT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE058L1_LUNEBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE048L1_WILHELMSHAVEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE516L0_SOLINGEN_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE052L1_FLENSBURG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE078L1_GREIFSWALD_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE025L1_DARMSTADT_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE065L1_FULDA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE008L2_LEIPZIG_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/DE035L1_KARLSRUHE_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT001L1_VILNIUS_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT501L0_KLAIPEDA_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT004L0_ALYTUS_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT002L1_KAUNAS_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT003L1_PANEVEZYS_UA2018_v013.zip',
#  '/data/uscuni-ulce/validation/Results/LT502L0_SIAULIAI_UA2018_v013.zip']

# %%
# %%time

# read the boundaries of the available functinal areas

urban_atlast_regions = []

for f in files:
    zipname = f.split('/')[-1][:-4]
    gpkg_path = f + '!' + zipname + "/Data/" + zipname + '.gpkg'

    data = gpd.read_file(gpkg_path, layer=zipname[:-5] + '_Boundary')
    data['filepath'] = gpkg_path
    urban_atlast_regions.append(data)

urban_atlast_regions = pd.concat(urban_atlast_regions, ignore_index=True)

# %%
urban_atlast_regions.iloc[-30:]

# %%
# %%time

results = []

for _, row in urban_atlast_regions.iterrows():

    print(row.fua_name)
    
    # read all buildings data that intersects with the urban atlast fua
    buildings_data = []
    region_intersections = regions[regions.intersects(row['geometry'])]
    for region_id in region_intersections.index:
        buildings = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{region_id}_{v}.pq')
        buildings_within_fua = buildings.centroid.within(row['geometry'])
        buildings_data.append(buildings[buildings_within_fua])
    buildings_data = pd.concat(buildings_data, ignore_index=True)

    # read urban atlast data
    urban_atlas_data = gpd.read_file(row['filepath'])

    ## spatially join buildings and urban atlas areas
    inp, res = buildings_data.centroid.sindex.query(urban_atlas_data.geometry, predicate='intersects')
    buildings_data['class_2018'] = ''
    buildings_data.iloc[res, -1] = urban_atlas_data.iloc[inp, 4]
    buildings_data['fua_name'] = row.fua_name

    results.append(buildings_data)

# %%
# %%time
all_data = pd.concat(results)

# %%
# all_data.to_parquet('../data/urban_atlast_validation.pq')

# %% [markdown]
# ### Generate table

# %%
all_data = gpd.read_parquet('../data/urban_atlast_validation.pq')

# %%
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')

# %%
all_data['map_label'] = all_data['final_without_noise'].map(cluster_mapping[4].to_dict())

# %%
himoc_urbanatlas_tab = pd.crosstab(all_data.map_label, all_data.class_2018, normalize='index')
himoc_urbanatlas_tab.index = himoc_urbanatlas_tab.index.map(cluster_4_names).values

# %%
himoc_urbanatlas_tab.columns
# Out:
# Index(['', 'Airports', 'Arable land (annual crops)',
#        'Complex and mixed cultivation patterns', 'Construction sites',
#        'Continuous urban fabric (S.L. : > 80%)',
#        'Discontinuous dense urban fabric (S.L. : 50% -  80%)',
#        'Discontinuous low density urban fabric (S.L. : 10% - 30%)',
#        'Discontinuous medium density urban fabric (S.L. : 30% - 50%)',
#        'Discontinuous very low density urban fabric (S.L. : < 10%)',
#        'Fast transit roads and associated land', 'Forests',
#        'Green urban areas',
#        'Herbaceous vegetation associations (natural grassland, moors...)',
#        'Industrial, commercial, public, military and private units',
#        'Isolated structures', 'Land without current use',
#        'Mineral extraction and dump sites',
#        'Open spaces with little or no vegetation (beaches, dunes, bare rocks, glaciers)',
#        'Other roads and associated land', 'Pastures',
#        'Permanent crops (vineyards, fruit trees, olive groves)', 'Port areas',
#        'Railways and associated land', 'Sports and leisure facilities',
#        'Water', 'Wetlands'],
#       dtype='object', name='class_2018')

# %%
selected_cols = ['Continuous urban fabric (S.L. : > 80%)',
       'Discontinuous dense urban fabric (S.L. : 50% -  80%)',
       'Discontinuous low density urban fabric (S.L. : 10% - 30%)',
       'Discontinuous medium density urban fabric (S.L. : 30% - 50%)',
       'Discontinuous very low density urban fabric (S.L. : < 10%)',
       'Industrial, commercial, public, military and private units',
        'Isolated structures']

# %%
styled_df = himoc_urbanatlas_tab[selected_cols]
f = {
    k: "{:.2f}" for k in styled_df.columns.values
}
styled_df = styled_df.style.format(f).background_gradient(axis=1, cmap="BuGn")
styled_df
# Out:
# <style type="text/css">
# #T_6715a_row0_col0 {
#   background-color: #309b5b;
#   color: #f1f1f1;
# }
# #T_6715a_row0_col1, #T_6715a_row1_col0, #T_6715a_row2_col5, #T_6715a_row3_col5, #T_6715a_row4_col1, #T_6715a_row5_col1, #T_6715a_row6_col1, #T_6715a_row7_col1, #T_6715a_row8_col6, #T_6715a_row9_col5, #T_6715a_row10_col1, #T_6715a_row11_col1, #T_6715a_row12_col1, #T_6715a_row13_col1, #T_6715a_row14_col5, #T_6715a_row15_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6715a_row0_col2 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_6715a_row0_col3 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_6715a_row0_col4, #T_6715a_row0_col6, #T_6715a_row1_col2, #T_6715a_row1_col4, #T_6715a_row1_col6, #T_6715a_row2_col0, #T_6715a_row2_col1, #T_6715a_row2_col2, #T_6715a_row2_col3, #T_6715a_row2_col4, #T_6715a_row2_col6, #T_6715a_row3_col0, #T_6715a_row3_col1, #T_6715a_row3_col2, #T_6715a_row3_col3, #T_6715a_row3_col4, #T_6715a_row3_col6, #T_6715a_row4_col6, #T_6715a_row5_col6, #T_6715a_row6_col6, #T_6715a_row7_col4, #T_6715a_row7_col6, #T_6715a_row8_col0, #T_6715a_row9_col0, #T_6715a_row9_col2, #T_6715a_row9_col4, #T_6715a_row10_col6, #T_6715a_row11_col4, #T_6715a_row12_col0, #T_6715a_row12_col4, #T_6715a_row13_col0, #T_6715a_row14_col4, #T_6715a_row15_col4 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_6715a_row0_col5, #T_6715a_row13_col6 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_6715a_row1_col1 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_6715a_row1_col3, #T_6715a_row6_col4, #T_6715a_row10_col5 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_6715a_row1_col5 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_6715a_row4_col0 {
#   background-color: #85cfbb;
#   color: #000000;
# }
# #T_6715a_row4_col2, #T_6715a_row15_col3 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_6715a_row4_col3 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_6715a_row4_col4, #T_6715a_row11_col0, #T_6715a_row14_col2, #T_6715a_row14_col6, #T_6715a_row15_col2 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_6715a_row4_col5, #T_6715a_row6_col5 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_6715a_row5_col0 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_6715a_row5_col2, #T_6715a_row11_col6 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_6715a_row5_col3 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_6715a_row5_col4, #T_6715a_row9_col1, #T_6715a_row9_col3, #T_6715a_row9_col6, #T_6715a_row10_col0, #T_6715a_row15_col6 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_6715a_row5_col5 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_6715a_row6_col0 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_6715a_row6_col2 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_6715a_row6_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_6715a_row7_col0 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_6715a_row7_col2, #T_6715a_row8_col5 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_6715a_row7_col3 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_6715a_row7_col5 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_6715a_row8_col1, #T_6715a_row10_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_6715a_row8_col2 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_6715a_row8_col3 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_6715a_row8_col4 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_6715a_row10_col2 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_6715a_row10_col4 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_6715a_row11_col2 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_6715a_row11_col3 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_6715a_row11_col5 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_6715a_row12_col2 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_6715a_row12_col3 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_6715a_row12_col5 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_6715a_row12_col6 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_6715a_row13_col2 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_6715a_row13_col3 {
#   background-color: #2f9858;
#   color: #f1f1f1;
# }
# #T_6715a_row13_col4 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_6715a_row13_col5 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_6715a_row14_col0, #T_6715a_row14_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_6715a_row14_col1 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_6715a_row15_col0 {
#   background-color: #5bbc96;
#   color: #f1f1f1;
# }
# #T_6715a_row15_col1 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# </style>
# <table id="T_6715a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >class_2018</th>
#       <th id="T_6715a_level0_col0" class="col_heading level0 col0" >Continuous urban fabric (S.L. : > 80%)</th>
#       <th id="T_6715a_level0_col1" class="col_heading level0 col1" >Discontinuous dense urban fabric (S.L. : 50% -  80%)</th>
#       <th id="T_6715a_level0_col2" class="col_heading level0 col2" >Discontinuous low density urban fabric (S.L. : 10% - 30%)</th>
#       <th id="T_6715a_level0_col3" class="col_heading level0 col3" >Discontinuous medium density urban fabric (S.L. : 30% - 50%)</th>
#       <th id="T_6715a_level0_col4" class="col_heading level0 col4" >Discontinuous very low density urban fabric (S.L. : < 10%)</th>
#       <th id="T_6715a_level0_col5" class="col_heading level0 col5" >Industrial, commercial, public, military and private units</th>
#       <th id="T_6715a_level0_col6" class="col_heading level0 col6" >Isolated structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6715a_level0_row0" class="row_heading level0 row0" >Dense Connected Developments</th>
#       <td id="T_6715a_row0_col0" class="data row0 col0" >0.32</td>
#       <td id="T_6715a_row0_col1" class="data row0 col1" >0.47</td>
#       <td id="T_6715a_row0_col2" class="data row0 col2" >0.01</td>
#       <td id="T_6715a_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_6715a_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_6715a_row0_col5" class="data row0 col5" >0.08</td>
#       <td id="T_6715a_row0_col6" class="data row0 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6715a_level0_row1" class="row_heading level0 row1" >Large Interconnected Blocks</th>
#       <td id="T_6715a_row1_col0" class="data row1 col0" >0.71</td>
#       <td id="T_6715a_row1_col1" class="data row1 col1" >0.17</td>
#       <td id="T_6715a_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_6715a_row1_col3" class="data row1 col3" >0.02</td>
#       <td id="T_6715a_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_6715a_row1_col5" class="data row1 col5" >0.08</td>
#       <td id="T_6715a_row1_col6" class="data row1 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6715a_level0_row2" class="row_heading level0 row2" >Extensive Courtyard Complexes</th>
#       <td id="T_6715a_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_6715a_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_6715a_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_6715a_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_6715a_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_6715a_row2_col5" class="data row2 col5" >0.98</td>
#       <td id="T_6715a_row2_col6" class="data row2 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6715a_level0_row3" class="row_heading level0 row3" >Massive Connected Aggregations</th>
#       <td id="T_6715a_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_6715a_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_6715a_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_6715a_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_6715a_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_6715a_row3_col5" class="data row3 col5" >0.59</td>
#       <td id="T_6715a_row3_col6" class="data row3 col6" >0.00</td>

# %% [markdown]
# 1. The Large Interconnected Blocks	is mainly continuous urban fabric reflecting the fact that they are mainly many interconnected buildings.
# 2. Dense connected developments is split between continugus and discontiguous because they are buildings with more space between them...
# 3. Sparse rural is reflected in the standalone structyres and lower density spread,
# 4. Large Utilitarian Development, Extensive Courtyard Complexes	, Massive Connected Aggregations, Large Wide-Spaced Complexes	is reflected in the large number of industrial
# 5. The disperesed and road linked clusters are more discontinous low and median density
#
#
# Overall these relationships highlight that our clusters extend the available classifications, note that each of our clusters can be arbitralily broken down into subclusters based on the hierarchy.

# %%
await dfi.export_async(styled_df, '../data/urban_atlas.png', dpi=300)

# %% [markdown]
# ## 4. LCZ

# %%
# !wget https://zenodo.org/records/8419340/files/lcz_filter_v3.tif?download=1

# %%
# !mv lcz_filter_v3.tif /data/uscuni-ulce/validation/

# %%
furl = "/data/uscuni-ulce/validation/lcz_filter_v3.tif"

# %%
lczs = rioxarray.open_rasterio(furl).squeeze()

# %%
lczs
# Out:
# <xarray.DataArray (y: 155995, x: 389620)> Size: 61GB
# [60778771900 values with dtype=uint8]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3MB -170.0 -170.0 -170.0 ... 180.0 180.0 180.0
#   * y            (y) float64 1MB 80.04 80.04 80.04 ... -60.09 -60.09 -60.09
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     _FillValue:     0
#     scale_factor:   1.0
#     add_offset:     0.0

# %% [markdown]
# #### Prague plot to verify spatial join

# %%
# %%time

results = []

for region_id in regions.index:

    if region_id != 69333: continue
    
    print(region_id)
    buildings = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{region_id}_{v}.pq')

    # setup geometry list to burn into the raster
    buildings['num_index'] = np.arange(1, buildings.shape[0] + 1)
    buildings['geometry'] = buildings.representative_point()
    building_utm = buildings.to_crs(lczs.rio.crs)
    minx, miny, maxx, maxy = building_utm.total_bounds


    # read only the region part of the raster data
    region_lczs = rioxarray.open_rasterio(
        filename=furl, 
        chunks='auto', 
        parse_coordinates=True,
        masked=True
    ).rio.clip_box(minx, miny, maxx, maxy)

    # extract building classification from lcz raster
    aggregated_iterative = region_lczs.xvec.extract_points(
        building_utm.geometry,
        x_coords="x",
        y_coords="y",
    )

    # append to the building dataframe and store in the  results array
    res = aggregated_iterative.to_pandas()
    res = gpd.GeoDataFrame(res.T.reset_index(), crs=building_utm.crs)
    res.columns = ['geometry', 'label']
    building_utm['lcz'] = res['label'].values
    results.append(building_utm)

all_data = pd.concat(results, ignore_index=True)
# Out:
# 69333
# CPU times: user 2.2 s, sys: 426 ms, total: 2.62 s
# Wall time: 2.59 s

# %%
import lonboard
from sidecar import Sidecar
from core.cluster_validation import get_color

v = 'v3'
final_clusters = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/final_clusters_{v}.pq')[0]
from core.cluster_validation import get_color
final_colors = pd.DataFrame(get_color(final_clusters.values), final_clusters.values).drop_duplicates()
final_colors.loc[-1] = [255,255,255]

etcs = all_data.copy()
etcs['geometry'] = all_data.to_crs(epsg=3035).buffer(10).to_crs(epsg=4326)

import lonboard
layer = lonboard.SolidPolygonLayer.from_geopandas(etcs, opacity=.7)

from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
with sc:
    display(m)

# %%
from core.cluster_validation import get_color
layer.get_fill_color = final_colors.loc[etcs.lcz].values.astype('uint8')

# %%
region_lczs.plot(levels=[1,2,3,4,5,6,7,8,9,18], cmap="tab10")

# %% [markdown]
# #### Generate spatial join

# %%
# %%time

results = []

for region_id in regions.index:
    
    print(region_id)
    buildings = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{region_id}_{v}.pq')

    # setup geometry list to burn into the raster
    buildings['num_index'] = np.arange(1, buildings.shape[0] + 1)
    buildings['geometry'] = buildings.representative_point()
    building_utm = buildings.to_crs(lczs.rio.crs)
    minx, miny, maxx, maxy = building_utm.total_bounds


    # read only the region part of the raster data
    region_lczs = rioxarray.open_rasterio(
        filename=furl, 
        chunks='auto', 
        parse_coordinates=True,
        masked=True
    ).rio.clip_box(minx, miny, maxx, maxy)

    # extract building classification from lcz raster
    aggregated_iterative = region_lczs.xvec.extract_points(
        building_utm.geometry,
        x_coords="x",
        y_coords="y",
    )

    # append to the building dataframe and store in the  results array
    res = aggregated_iterative.to_pandas()
    res = gpd.GeoDataFrame(res.T.reset_index(), crs=building_utm.crs)
    res.columns = ['geometry', 'label']
    building_utm['lcz'] = res['label'].values
    results.append(building_utm)
# Out:
# 4
# 10
# 132
# 134
# 286
# 313
# 400
# 523
# 765
# 801
# 832
# 913
# 960
# 1124
# 1154
# 1387
# 1478
# 1515
# 1605
# 1718
# 1736
# 1782
# 1970
# 1981
# 2096
# 2322
# 2350
# 2478
# 2514
# 2625
# 2728
# 2975
# 3039
# 3109
# 3150
# 3221
# 3250
# 3526
# 3610
# 3612
# 3701
# 3705
# 3752
# 3759
# 3981
# 4070
# 4214
# 4215
# 4235
# 4284
# 4356
# 4382
# 4723
# 4805
# 5096
# 5191
# 5246
# 5310
# 5408
# 5427
# 5662
# 5671
# 5766
# 5883
# 6254
# 6529
# 6560
# 6576
# 6741
# 6749
# 6811
# 6873
# 6996
# 7068
# 7094
# 7280
# 7485
# 7528
# 7534
# 7681
# 7688
# 7712
# 7727
# 7805
# 7914
# 7937
# 7963
# 8046
# 8216
# 8238
# 8256
# 8265
# 8345
# 8374
# 8396
# 8592
# 8707
# 8731
# 8757
# 8759
# 8813
# 9016
# 9064
# 9074
# 9150
# 9169
# 9194
# 9284
# 9824
# 9924
# 9954
# 9972
# 10019
# 10086
# 10095
# 10124
# 10179
# 10222
# 10263
# 10277
# 10455
# 10510
# 10511
# 10563
# 10579
# 10602
# 10666
# 10794
# 10847
# 10908
# 10926
# 10970
# 11002
# 11019
# 11057
# 11141
# 11210
# 11256
# 11261
# 11305
# 11309
# 11311
# 11318
# 11367
# 11444
# 11455
# 11471
# 11667
# 11678
# 11735
# 11757
# 11799
# 11877
# 11905
# 12027
# 12084
# 12100
# 12115
# 12154
# 12191
# 12381
# 12440
# 12483
# 12552
# 12667
# 12707
# 12755
# 12756
# 12844
# 12919
# 12965
# 13076
# 13137
# 13172
# 13191
# 13196
# 13229
# 13301
# 13395
# 13442
# 13482
# 13506
# 13553
# 13555
# 13614
# 13616
# 13655
# 13677
# 13779
# 13810
# 13881
# 13897
# 13965
# 14084
# 14245
# 14319
# 14321
# 14327
# 14364
# 14383
# 14550
# 135687
# 136169
# 136533
# 137469
# 137537
# 137636
# 137863
# 138804
# 139096
# 139621
# 139674
# 139764
# 140420
# 141272
# 141366
# 142100
# 143701
# 145906
# 146285
# 147112
# 147634
# 148018
# 148085
# 149997
# 150044
# 151676
# 152081
# 152511
# CPU times: user 8min 36s, sys: 2min 47s, total: 11min 23s
# Wall time: 11min 7s

# %%
all_data = pd.concat(results, ignore_index=True)

# %%
del results

# %% [markdown]
# ### Crossstab

# %%
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')

# %%
cluster_mapping
# Out:
#      1  2  3   4   5   6
# 7
# 1    1  1  1   1   1   1
# 2    1  1  1   1   1   1
# 3    1  1  1   1   1   2
# 4    1  1  1   1   1   2
# 5    1  1  1   1   2   3
# ..  .. .. ..  ..  ..  ..
# 104  2  4  8  16  31  59
# 105  2  4  8  16  31  59
# 106  2  4  8  16  32  60
# 107  2  4  8  16  32  60
# 108  2  4  8  16  32  61
#
# [108 rows x 6 columns]

# %%
all_data['map_label'] = all_data['final_without_noise'].map(cluster_mapping[4].to_dict())

# %%
lcz_names = {
    "1": "Compact high-rise",
    "2": "Compact mid-rise",
    "3": "Compact low-rise",
    "4": "Open high-rise",
    "5": "Open mid-rise",
    "6": "Open low-rise",
    "7": "Lightweight low-rise",
    "8": "Large low-rise",
    "9": "Sparsely built",
    "10": "Heavy industry",
    "11": "Dense trees",
    "12": "Scattered trees",
    "13": "Bush, scrub",
    "14": "Low plants",
    "15": "Bare rock or paved",
    "16": "Bare soil or sand",
    "17": "Water"
}

lcz_names = {float(k):v for k,v in lcz_names.items()}

# %%
all_data.lcz.value_counts() / all_data.shape[0]
# Out:
# lcz
# 6.0     4.703750e-01
# 9.0     2.774260e-01
# 14.0    1.024760e-01
# 12.0    5.933093e-02
# 11.0    3.232364e-02
# 5.0     3.119549e-02
# 8.0     1.802161e-02
# 2.0     5.205505e-03
# 4.0     1.362793e-03
# 3.0     1.245510e-03
# 10.0    3.347574e-04
# 1.0     2.384158e-04
# 17.0    1.937229e-04
# 15.0    1.333361e-04
# 16.0    3.132588e-05
# 7.0     1.633748e-06
# 13.0    7.673665e-07
# Name: count, dtype: float64

# %%
himoc_lcz_tab = pd.crosstab(all_data.map_label, all_data.lcz, normalize='index')
himoc_lcz_tab.index = himoc_lcz_tab.index.map(cluster_4_names).values
himoc_lcz_tab.columns = himoc_lcz_tab.columns.map(lcz_names).values

# %%
himoc_lcz_tab.columns
# Out:
# Index(['Compact high-rise', 'Compact mid-rise', 'Compact low-rise',
#        'Open high-rise', 'Open mid-rise', 'Open low-rise',
#        'Lightweight low-rise', 'Large low-rise', 'Sparsely built',
#        'Heavy industry', 'Dense trees', 'Scattered trees', 'Bush, scrub',
#        'Low plants', 'Bare rock or paved', 'Bare soil or sand', 'Water'],
#       dtype='object')

# %%
selected_cols = ['Compact high-rise', 'Compact mid-rise',
       'Open mid-rise', 'Open low-rise',
       'Large low-rise', 'Sparsely built',
       'Heavy industry', 'Dense trees', 'Scattered trees',
       'Low plants']

# %%
{
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dae6d_row0_col7, #T_dae6d_row7_col4, #T_dae6d_row9_col13, #T_dae6d_row12_col7, #T_dae6d_row15_col10 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_dae6d_row0_col8, #T_dae6d_row6_col11, #T_dae6d_row9_col5 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_dae6d_row1_col0, #T_dae6d_row4_col13, #T_dae6d_row5_col13, #T_dae6d_row8_col7, #T_dae6d_row12_col4, #T_dae6d_row13_col7, #T_dae6d_row14_col9 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_dae6d_row1_col1 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_dae6d_row1_col2, #T_dae6d_row1_col3, #T_dae6d_row11_col10 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_dae6d_row1_col4 {
#   background-color: #3fab72;
#   color: #f1f1f1;
# }
# #T_dae6d_row1_col7, #T_dae6d_row6_col13 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_dae6d_row1_col8, #T_dae6d_row6_col10, #T_dae6d_row7_col10, #T_dae6d_row15_col13 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_dae6d_row2_col0 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_dae6d_row2_col5, #T_dae6d_row5_col8, #T_dae6d_row14_col13 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_dae6d_row2_col9 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_dae6d_row3_col0 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_dae6d_row3_col1, #T_dae6d_row5_col4, #T_dae6d_row7_col7 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_dae6d_row4_col4, #T_dae6d_row10_col5 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_dae6d_row4_col8 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_dae6d_row6_col8 {
#   background-color: #43af78;
#   color: #f1f1f1;
# }
# #T_dae6d_row7_col11 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_dae6d_row7_col13 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_dae6d_row8_col5, #T_dae6d_row9_col8, #T_dae6d_row15_col11 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_dae6d_row8_col8 {
#   background-color: #44af79;
#   color: #f1f1f1;
# }
# #T_dae6d_row8_col10 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_dae6d_row8_col11 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_dae6d_row9_col9 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_dae6d_row10_col10, #T_dae6d_row14_col10 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_dae6d_row10_col13 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_dae6d_row11_col11, #T_dae6d_row12_col10 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_dae6d_row11_col13 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_dae6d_row12_col5 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_dae6d_row12_col11 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_dae6d_row12_col13 {
#   background-color: #62c09f;
#   color: #000000;
# }
# #T_dae6d_row13_col5 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_dae6d_row13_col11 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_dae6d_row13_col13 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_dae6d_row14_col4 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_dae6d_row14_col5 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_dae6d_row14_col8 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_dae6d_row14_col11 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_dae6d_row15_col4 {
#   background-color: #a7ddd1;
#   color: #000000;
# }
# #T_dae6d_row15_col7 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# </style>
# <table id="T_dae6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dae6d_level0_

# %% [markdown]
# 1.  Interesting that we have so many plants and trees, since we only classify buildings. this shows the advatages of higher resolution.
# 2.  similarly to others larger interconnected and dense connected follow the same patterns as in the others, the other clusters as well.
#
#
# the biggest differences are that we find structures of developments and characteristics of streets.

# %% [markdown]
# in all cases more than 70% of the buildings are assigned to 1 or 2 classes, whereas with our clusters its at most ~30% assigned to the 2 most common clusters. we can go futher down the hierarchy.

# %%
await dfi.export_async(styled_df, '../data/lcz.png', dpi=300)

# %%
all_data.map_label.value_counts() / all_data.shape[0]
# Out:
# map_label
# 8     0.158218
# 1     0.141798
# 6     0.138443
# 13    0.136718
# 7     0.109360
# 14    0.107942
# 5     0.077025
# 9     0.045666
# 12    0.032665
# 15    0.015308
# 2     0.015307
# 16    0.010819
# 11    0.010673
# 10    0.000041
# 3     0.000009
# 4     0.000009
# Name: count, dtype: float64

# %%
# building_utm.iloc[160_000: 190_000].explore(column='lcz', categorical=True, prefer_canvas=True, tiles='cartodb positron')

# %% [markdown]
# ## Figures

# %% [markdown]
# ### Taxonometric tree overview

# %% [markdown]
# ### Taxonomy across settlement hierarchy examples

# %%
def get_cluster_names(mapping_level):

    if mapping_level == 1:
        cluster_names = {
        '1': 'Dense Street Network',
        '2': 'Utilitarian Street Network',
        
        }

    elif mapping_level == 2:
        cluster_names = {
        '1': 'Central Urban Developments',
        '2': 'Dense Urban Street network',
        '3': 'Linear & Rural Development',
        '4': 'Utalitarian Street network'
        }

    
    elif mapping_level == 3:
        cluster_names = {
        '1': 'Central Urban Developments',
        '2': 'Large Scale Outliers',
         '3': 'Dense Urban Developments',
         '4': 'Street-aligned Developments',
         '5': 'Sparse Rural Development',
         '6': 'Linear Road Network Developments',
         '7': 'Sparse Road Network Developments',
         '8': 'Large Scale Developments'
        }

    else:
        # # assign outliers to the industrial cluster
        cluster_names = {'1': 'Dense Connected Developments',
         '2': 'Large Interconnected Blocks',
         '3': 'Extensive Courtyard Complexes',
         '4': 'Massive Connected Aggregations',
         '5': 'Dense Standalone Buildings',
         '6': 'Compact Development',
         '7': 'Cul-de-Sac Layout',
         '8': 'Aligned Winding Streets',
         '9': 'Sparse Rural Development',
         '10': 'Large Wide-Spaced Complexes',
         '11': 'Dispersed Linear Development',
         '12': 'Linear Development',
         '13': 'Sparse Open Layout',
         '14': 'Sparse Road-Linked Development',
         '15': 'Large Utilitarian Development',
         '16': 'Extensive Wide-Spaced Developments'}

        

    return cluster_names

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import contextily as cx
from matplotlib_scalebar.scalebar import ScaleBar
from matplotlib.colors import to_hex
from matplotlib import colormaps
import matplotlib.patches as mpatches
import shapely

region_hulls = gpd.read_parquet("/data/uscuni-ulce/regions/cadastre_regions_hull.parquet")

v = 'v3'
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')

# %%
# 74378 - Milevsko, Czechia
# 35141 - Insbruck, Austria
# 107131 - Krakow, Poland
# 55763 - Berlin, Germany

centres_df = pd.DataFrame(((49.45118, 14.36031), (47.26446 , 11.40490), (50.06084, 19.93810), (52.49891 , 13.39149)), columns=['y', 'x'])
centres_df = gpd.GeoSeries(gpd.points_from_xy(centres_df['x'], centres_df['y'], crs='epsg:4236')).to_crs(epsg=3035)

# %%
# %%time

milevsko = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_74378_{v}.pq', columns=['final_without_noise', 'geometry'])
milevsko = milevsko[milevsko.within(centres_df.iloc[0].buffer(1_000))]
insbruck = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_35141_{v}.pq', columns=['final_without_noise', 'geometry'])
insbruck = insbruck[insbruck.within(centres_df.iloc[1].buffer(2_000))]
krakow = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_107131_{v}.pq', columns=['final_without_noise', 'geometry'])
krakow = krakow[krakow.within(centres_df.iloc[2].buffer(3_000))]
berlin = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_55763_{v}.pq', columns=['final_without_noise', 'geometry']) 
berlin = berlin[berlin.within(centres_df.iloc[3].buffer(4_000))]
# Out:
# CPU times: user 4.24 s, sys: 601 ms, total: 4.84 s
# Wall time: 4.56 s

# %%
# Latitude: 49.45118 Longitude: 14.36031
# Latitude: 47.26446 Longitude: 11.40490
# Latitude: 50.06084 Longitude: 19.93810
# Latitude: 52.49891 Longitude: 13.39149

# %%
datalist = [milevsko, insbruck, krakow, berlin]

# %%
# %%time

cmap = [to_hex(c) for c in colormaps.get_cmap('tab20').colors]

fig, ax = plt.subplots(4,5, figsize=(8.3, 7), dpi=300)
for level, row_ax in enumerate(ax):
    
    clusters = [data.final_without_noise.map(cluster_mapping[level + 1].to_dict()) for data in datalist]
    unique_clusters = pd.concat(clusters, ignore_index=True).unique()
        
    for i, (data, col_ax) in enumerate(zip(datalist, row_ax[:-1])):
    
        for cluster in unique_clusters:
            data[clusters[i] == cluster].plot(ax=col_ax, color=cmap[cluster])
        
        cx.add_basemap(col_ax, crs=data.crs, source=cx.providers.CartoDB.Positron.build_url(scale_factor="@2x",), attribution='')
        axis_box = shapely.box(col_ax.get_xlim()[0], col_ax.get_ylim()[0], col_ax.get_xlim()[1], col_ax.get_ylim()[1])
        axis_waste = axis_box.difference(centres_df.iloc[i].buffer((i + 1) * 1_000))
        gpd.GeoSeries([axis_waste], crs=data.crs).plot(ax=col_ax, color='w')

        if level == 0:
            col_ax.add_artist(ScaleBar(1, location="upper right", frameon=False, font_properties={"size": 6}))
    
    legend_patches = [mpatches.Patch(color=cmap[cluster], label=get_cluster_names(level + 1)[str(cluster)]) for cluster in unique_clusters]
    row_ax[-1].legend(handles=legend_patches, loc='upper left', frameon=False, fontsize='xx-small')

ax[0][0].set_ylabel('Level 1')
ax[1][0].set_ylabel('Level 2')
ax[2][0].set_ylabel('Level 3')
ax[3][0].set_ylabel('Level 4')

ax[0][0].set_xlabel('Milevsko, CZ')
ax[0][0].xaxis.set_label_position('top') 
ax[0][1].set_xlabel('Innsbruck, AT')
ax[0][1].xaxis.set_label_position('top') 
ax[0][2].set_xlabel('Krakow, PL')
ax[0][2].xaxis.set_label_position('top') 
ax[0][3].set_xlabel('Berlin, DE')
ax[0][3].xaxis.set_label_position('top')

for paxis in ax.flatten():
    paxis.set_yticks([])
    paxis.set_xticks([])
    paxis.set_frame_on(False)

fig.subplots_adjust(wspace = 0.00, hspace=0.00)
fig.savefig('../data/examples.png')

# %% [markdown]
# ### Taxonomy level examples

# %%
from core.cluster_validation import get_color

# %%
centres_df = pd.DataFrame(((50.08873, 14.41810), ), columns=['y', 'x'])
centres_df = gpd.GeoSeries(gpd.points_from_xy(centres_df['x'], centres_df['y'], crs='epsg:4236')).to_crs(epsg=3035)

# %%
prague = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_69333_{v}.pq', columns=['final_without_noise', 'geometry'])
prague = prague[prague.within(centres_df.buffer(3_500).iloc[0])]

# %%
# %%time

cmap = [to_hex(c) for c in colormaps.get_cmap('tab20').colors]

fig, ax = plt.subplots(1,3, figsize=(6, 2), dpi=300)

for level, col_ax in zip([3, 5, 7], ax):

    if level < 7:
        clusters = prague.final_without_noise.map(cluster_mapping[level].to_dict())
    else:
        clusters = prague.final_without_noise

    unique_clusters = clusters.unique()
    
    if level <= 4:
        cmap = [to_hex(c) for c in colormaps.get_cmap('tab20').colors]
    else:
        cmap = ['#%02x%02x%02x' % (c[0], c[1], c[2]) for c in get_color(np.arange(0, max(unique_clusters) + 1))]
    
    for cluster in unique_clusters:
        prague[clusters == cluster].plot(ax=col_ax, color=cmap[cluster])
        
    cx.add_basemap(col_ax, crs=prague.crs, source=cx.providers.CartoDB.Positron.build_url(scale_factor="@2x",), attribution='')
    axis_box = shapely.box(col_ax.get_xlim()[0], col_ax.get_ylim()[0], col_ax.get_xlim()[1], col_ax.get_ylim()[1])
    axis_waste = axis_box.difference(centres_df.iloc[0].buffer(3_500))
    gpd.GeoSeries([axis_waste], crs=prague.crs).plot(ax=col_ax, color='w')
    col_ax.add_artist(ScaleBar(1, location="upper right", frameon=False, font_properties={"size": 6}))

ax[0].set_ylabel('Prague, CZ')

ax[0].set_xlabel('Level 3')
ax[0].xaxis.set_label_position('top') 
ax[1].set_xlabel('Level 5')
ax[1].xaxis.set_label_position('top') 
ax[2].set_xlabel('Level 7')
ax[2].xaxis.set_label_position('top')

for paxis in ax.flatten():
    paxis.set_yticks([])
    paxis.set_xticks([])
    paxis.set_frame_on(False)

fig.subplots_adjust(wspace = 0.00, hspace=0.00)
fig.savefig('../data/prague_taxonomy.png')
# Out:
# CPU times: user 15.1 s, sys: 11.9 ms, total: 15.1 s
# Wall time: 9.19 s

# %% [markdown]
# ### Country breakdown - counts

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
## download countries
# !wget https://gisco-services.ec.europa.eu/distribution/v2/countries/geojson/CNTR_RG_01M_2024_3035.geojson

# %%
country_names = ['Germany', 'Poland', 'Czechia', 'Slovakia', 'Austria', 'Lithuania']
countries = gpd.read_file('../data/CNTR_RG_01M_2024_3035.geojson').to_crs(epsg=3035)
country_polygons = countries[countries['NAME_ENGL'].isin(country_names)]

region_hulls = gpd.read_parquet("/data/uscuni-ulce/regions/cadastre_regions_hull.parquet")

v = 'v3'
cluster_mapping = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/cluster_mapping_{v}.pq')

# %%
region_idxs, country_idxs = country_polygons.sindex.query(region_hulls.geometry, predicate='intersects')
intersections = region_hulls.iloc[region_idxs].intersection(country_polygons.iloc[country_idxs], align=False).area
intersection_df = gpd.GeoDataFrame(
    {
    'region_id': region_hulls.index[region_idxs].values,
    'country': country_polygons.iloc[country_idxs, 2].values,
    'intersection_area': intersections.values,
    'geometry': region_hulls.iloc[region_idxs, 0].values
    },
    crs=region_hulls.crs
                                   
                                  
)

intersection_df = intersection_df.sort_values('intersection_area', ascending=False)

# %%
intersection_df.sort_values('region_id')
# Out:
#      region_id    country  intersection_area  \
# 0            4    Germany       3.946676e+10
# 1           10    Germany       1.495455e+09
# 2          132    Germany       1.727289e+08
# 3          134    Germany       5.064500e+07
# 4          286    Germany       5.871000e+07
# ..         ...        ...                ...
# 921     149997  Lithuania       1.884045e+09
# 922     150044  Lithuania       2.080685e+09
# 923     151676  Lithuania       5.997051e+09
# 924     152081  Lithuania       8.335309e+09
# 925     152511  Lithuania       3.360046e+09
#
#                                               geometry
# 0    POLYGON ((4122200 3045600, 4121500 3045900, 40...
# 1    POLYGON ((4068900 3057300, 4051000 3064300, 40...
# 2    POLYGON ((4053100 3049800, 4050900 3053000, 40...
# 3    POLYGON ((4052500 3093600, 4052200 3093700, 40...
# 4    POLYGON ((4060600 3103900, 4057000 3104200, 40...
# ..                                                 ...
# 921  POLYGON ((5253200 3642300, 5245600 3647000, 52...
# 922  POLYGON ((5265700 3578300, 5263400 3578400, 52...
# 923  POLYGON ((5285400 3549200, 5284800 3549900, 52...
# 924  POLYGON ((5269700 3664900, 5269300 3665300, 52...
# 925  POLYGON ((5298200 3650100, 5279200 3651600, 52...
#
# [926 rows x 4 columns]

# %%
# %%time

results = []

for country, group in intersection_df.groupby('country')['region_id']:

    print(country)
    
    country_polygon = countries[countries['NAME_ENGL'] == country].geometry.iloc[0]
    cluster_data = pd.concat(
    [
        gpd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{rid}_{v}.pq', columns=['final_without_noise', 'geometry']) 
        for rid in group.values
    ], ignore_index=True
    )

    counts = cluster_data.iloc[cluster_data.sindex.query(country_polygon, predicate='contains')]['final_without_noise'].value_counts()
    counts.name = country
    results.append(counts)

total_counts = pd.concat(results, axis=1).fillna(0).sort_index()
# Out:
# Austria
# Czechia
# Germany
# Lithuania
# Poland
# Slovakia
# CPU times: user 2min 29s, sys: 17.5 s, total: 2min 47s
# Wall time: 2min 46s

# %%
level4_counts = total_counts.groupby(total_counts.index.map(cluster_mapping[4].to_dict()).values).sum()
level4_counts.index = level4_counts.index.map(cluster_4_names)

level3_counts = total_counts.groupby(total_counts.index.map(cluster_mapping[3].to_dict()).values).sum()

# %%
r1 = (level4_counts / 1_000).astype(int)
r2 = (level4_counts / level4_counts.sum(axis=0))

r3 = r1.copy().astype(str)
for i in range(r3.shape[0]):
    for j in range(r3.shape[1]):
        r3.iloc[i,j] = '{:,d}'.format(r1.iloc[i,j]) + ' (' + '{:,.2f}'.format(r2.iloc[i, j]) + ')'

r3
# Out:
#                                          Austria       Czechia        Germany  \
# Dense Connected Developments          292 (0.07)    667 (0.16)   9,689 (0.19)
# Large Interconnected Blocks            97 (0.02)     52 (0.01)   1,025 (0.02)
# Extensive Courtyard Complexes           0 (0.00)      0 (0.00)       0 (0.00)
# Massive Connected Aggregations          0 (0.00)      0 (0.00)       0 (0.00)
# Dense Standalone Buildings            526 (0.12)    447 (0.11)   3,073 (0.06)
# Compact Development                    53 (0.01)     36 (0.01)  10,695 (0.21)
# Cul-de-Sac Layout                     518 (0.12)    264 (0.06)   6,912 (0.13)
# Aligned Winding Streets               407 (0.09)    279 (0.07)  10,751 (0.21)
# Sparse Rural Development              176 (0.04)    121 (0.03)     108 (0.00)
# Large Wide-Spaced Complexes             0 (0.00)      0 (0.00)       2 (0.00)
# Dispersed Linear Development            0 (0.00)      3 (0.00)      51 (0.00)
# Linear Development                      9 (0.00)     34 (0.01)     435 (0.01)
# Sparse Open Layout                  1,942 (0.45)  1,881 (0.46)   2,184 (0.04)
# Sparse Road-Linked Development        249 (0.06)    190 (0.05)   5,329 (0.10)
# Large Utilitarian Development          65 (0.01)     60 (0.01)     918 (0.02)
# Extensive Wide-Spaced Developments     24 (0.01)     91 (0.02)     251 (0.00)
#
#                                      Lithuania        Poland    Slovakia
# Dense Connected Developments          8 (0.00)    599 (0.04)  197 (0.06)
# Large Interconnected Blocks           1 (0.00)     41 (0.00)   18 (0.01)
# Extensive Courtyard Complexes         0 (0.00)      0 (0.00)    0 (0.00)
# Massive Connected Aggregations        0 (0.00)      0 (0.00)    0 (0.00)
# Dense Standalone Buildings          302 (0.15)  1,463 (0.10)  409 (0.12)
# Compact Development                   0 (0.00)    118 (0.01)  280 (0.08)
# Cul-de-Sac Layout                   121 (0.06)    426 (0.03)  589 (0.17)
# Aligned Winding Streets              14 (0.01)    554 (0.04)  773 (0.23)
# Sparse Rural Development            402 (0.20)  2,824 (0.18)   56 (0.02)
# Large Wide-Spaced Complexes           0 (0.00)      0 (0.00)    0 (0.00)
# Dispersed Linear Development         13 (0.01)    741 (0.05)   52 (0.02)
# Linear Development                  122 (0.06)  1,802 (0.12)  234 (0.07)
# Sparse Open Layout                  777 (0.38)  4,188 (0.27)   69 (0.02)
# Sparse Road-Linked Development      231 (0.11)  2,037 (0.13)  680 (0.20)
# Large Utilitarian Development        15 (0.01)    154 (0.01)   22 (0.01)
# Extensive Wide-Spaced Developments   39 (0.02)    416 (0.03)   50 (0.01)

# %%
(level4_counts.T / level4_counts.sum(axis=1)).T.style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_41150">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41150_level0_col0" class="col_heading level0 col0" >Austria</th>
#       <th id="T_41150_level0_col1" class="col_heading level0 col1" >Czechia</th>
#       <th id="T_41150_level0_col2" class="col_heading level0 col2" >Germany</th>
#       <th id="T_41150_level0_col3" class="col_heading level0 col3" >Lithuania</th>
#       <th id="T_41150_level0_col4" class="col_heading level0 col4" >Poland</th>
#       <th id="T_41150_level0_col5" class="col_heading level0 col5" >Slovakia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41150_level0_row0" class="row_heading level0 row0" >Dense Connected Developments</th>
#       <td id="T_41150_row0_col0" class="data row0 col0" >0.03</td>
#       <td id="T_41150_row0_col1" class="data row0 col1" >0.06</td>
#       <td id="T_41150_row0_col2" class="data row0 col2" >0.85</td>
#       <td id="T_41150_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_41150_row0_col4" class="data row0 col4" >0.05</td>
#       <td id="T_41150_row0_col5" class="data row0 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row1" class="row_heading level0 row1" >Large Interconnected Blocks</th>
#       <td id="T_41150_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_41150_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_41150_row1_col2" class="data row1 col2" >0.83</td>
#       <td id="T_41150_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_41150_row1_col4" class="data row1 col4" >0.03</td>
#       <td id="T_41150_row1_col5" class="data row1 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row2" class="row_heading level0 row2" >Extensive Courtyard Complexes</th>
#       <td id="T_41150_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_41150_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_41150_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_41150_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_41150_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_41150_row2_col5" class="data row2 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row3" class="row_heading level0 row3" >Massive Connected Aggregations</th>
#       <td id="T_41150_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_41150_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_41150_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_41150_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_41150_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_41150_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row4" class="row_heading level0 row4" >Dense Standalone Buildings</th>
#       <td id="T_41150_row4_col0" class="data row4 col0" >0.08</td>
#       <td id="T_41150_row4_col1" class="data row4 col1" >0.07</td>
#       <td id="T_41150_row4_col2" class="data row4 col2" >0.49</td>
#       <td id="T_41150_row4_col3" class="data row4 col3" >0.05</td>
#       <td id="T_41150_row4_col4" class="data row4 col4" >0.24</td>
#       <td id="T_41150_row4_col5" class="data row4 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row5" class="row_heading level0 row5" >Compact Development</th>
#       <td id="T_41150_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_41150_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_41150_row5_col2" class="data row5 col2" >0.96</td>
#       <td id="T_41150_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_41150_row5_col4" class="data row5 col4" >0.01</td>
#       <td id="T_41150_row5_col5" class="data row5 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row6" class="row_heading level0 row6" >Cul-de-Sac Layout</th>
#       <td id="T_41150_row6_col0" class="data row6 col0" >0.06</td>
#       <td id="T_41150_row6_col1" class="data row6 col1" >0.03</td>
#       <td id="T_41150_row6_col2" class="data row6 col2" >0.78</td>
#       <td id="T_41150_row6_col3" class="data row6 col3" >0.01</td>
#       <td id="T_41150_row6_col4" class="data row6 col4" >0.05</td>
#       <td id="T_41150_row6_col5" class="data row6 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row7" class="row_heading level0 row7" >Aligned Winding Streets</th>
#       <td id="T_41150_row7_col0" class="data row7 col0" >0.03</td>
#       <td id="T_41150_row7_col1" class="data row7 col1" >0.02</td>
#       <td id="T_41150_row7_col2" class="data row7 col2" >0.84</td>
#       <td id="T_41150_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_41150_row7_col4" class="data row7 col4" >0.04</td>
#       <td id="T_41150_row7_col5" class="data row7 col5" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row8" class="row_heading level0 row8" >Sparse Rural Development</th>
#       <td id="T_41150_row8_col0" class="data row8 col0" >0.05</td>
#       <td id="T_41150_row8_col1" class="data row8 col1" >0.03</td>
#       <td id="T_41150_row8_col2" class="data row8 col2" >0.03</td>
#       <td id="T_41150_row8_col3" class="data row8 col3" >0.11</td>
#       <td id="T_41150_row8_col4" class="data row8 col4" >0.77</td>
#       <td id="T_41150_row8_col5" class="data row8 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row9" class="row_heading level0 row9" >Large Wide-Spaced Complexes</th>
#       <td id="T_41150_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_41150_row9_col1" class="data row9 col1" >0.00</td>
#       <td id="T_41150_row9_col2" class="data row9 col2" >0.73</td>
#       <td id="T_41150_row9_col3" class="data row9 col3" >0.11</td>
#       <td id="T_41150_row9_col4" class="data row9 col4" >0.17</td>
#       <td id="T_41150_row9_col5" class="data row9 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row10" class="row_heading level0 row10" >Dispersed Linear Development</th>
#       <td id="T_41150_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_41150_row10_col1" class="data row10 col1" >0.00</td>
#       <td id="T_41150_row10_col2" class="data row10 col2" >0.06</td>
#       <td id="T_41150_row10_col3" class="data row10 col3" >0.02</td>
#       <td id="T_41150_row10_col4" class="data row10 col4" >0.86</td>
#       <td id="T_41150_row10_col5" class="data row10 col5" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row11" class="row_heading level0 row11" >Linear Development</th>
#       <td id="T_41150_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_41150_row11_col1" class="data row11 col1" >0.01</td>
#       <td id="T_41150_row11_col2" class="data row11 col2" >0.16</td>
#       <td id="T_41150_row11_col3" class="data row11 col3" >0.05</td>
#       <td id="T_41150_row11_col4" class="data row11 col4" >0.68</td>
#       <td id="T_41150_row11_col5" class="data row11 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row12" class="row_heading level0 row12" >Sparse Open Layout</th>
#       <td id="T_41150_row12_col0" class="data row12 col0" >0.18</td>
#       <td id="T_41150_row12_col1" class="data row12 col1" >0.17</td>
#       <td id="T_41150_row12_col2" class="data row12 col2" >0.20</td>
#       <td id="T_41150_row12_col3" class="data row12 col3" >0.07</td>
#       <td id="T_41150_row12_col4" class="data row12 col4" >0.38</td>
#       <td id="T_41150_row12_col5" class="data row12 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_41150_level0_row13" class="row_heading level0 row13" >Sparse Road-Linked Development</th>
#       <td id="T_41150_row13_col0" class="data row13 col0" >0.03</td>
#       <td id="T_41150_row13_col1" class="data row13 col1" >0.02</td>
#       <td id="T_41150_row13_col2" class="data row13 col2" >0.61</td>
#       <td id="T_41150_row13_col3" class="data row13 col3" >0.03</td>
#       <td id="T_41150_row13_col4" class="data row13 col4" >0.23</td>
#       <td id="T_41150_row13_col5" class="data row13 col5" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_41150_lev

# %% [markdown]
# ### Country breakdown - maps

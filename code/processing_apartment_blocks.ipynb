# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %% [markdown]
# ### Generate a GeoDataFrame that covers the socialist housing developments

# %%
# !ls /data/uscuni-ulce/additional_data/housing_estates_locations
# Out:
# HEs_delimitation.xlsx  ZSJ_2013.sbn	 ZSJ_2016.cpg  ZSJ_2016.shp
# prague		       ZSJ_2013.sbx	 ZSJ_2016.dbf  ZSJ_2016.shp.xml
# ZSJ_2013.cpg	       ZSJ_2013.shp	 ZSJ_2016.prj  ZSJ_2016.shx
# ZSJ_2013.dbf	       ZSJ_2013.shp.xml  ZSJ_2016.sbn
# ZSJ_2013.prj	       ZSJ_2013.shx	 ZSJ_2016.sbx

# %%
xcl = pd.read_excel('/data/uscuni-ulce/additional_data/housing_estates_locations/HEs_delimitation.xlsx')
xcl.columns
# Out:
# Index(['MUNICIPALITY CODE', 'MUNICIPALITY NAME', 'BSU CODE_2014',
#        'BSU CODE6_2014', 'BSU NAME_CURRENT', 'poznámky', 'SOC HE',
#        'SOC&POSTSOC HE', 'Unnamed: 8', 'BSU CODE_1974', 'BSU NAME_1974',
#        'DELIMITATION OK?', 'BSU CODE_1980', 'ZSJ1980', 'DELIMITATION OK?.1',
#        'BSU CODE_1992', 'BSU NAME_1992', 'DELIMITATION OK?.2', 'BSU CODE_2001',
#        'BSU NAME_2001', 'DELIMITATION OK?.3', 'BSU CODE_2014.1',
#        'BSU NAME_2014', 'DELIMITATION OK?.4'],
#       dtype='object')

# %%
xcl
# Out:
#      MUNICIPALITY CODE MUNICIPALITY NAME  BSU CODE_2014  BSU CODE6_2014  \
# 0               562335             Děčín          71610            7161
# 1               582786              Brno         101540           10154
# 2               582786              Brno         102190           10219
# 3               582786              Brno         103160           10316
# 4               582786              Brno        3039920          303992
# ..                 ...               ...            ...             ...
# 614             569810    Hradec Králové        3282510          328251
# 615             555134         Pardubice        3291260          329126
# 616             554791             Plzeň        3293210          329321
# 617             554782             Praha        3297460          329746
# 618             554782             Praha        3297710          329771
#
#        BSU NAME_CURRENT poznámky SOC HE SOC&POSTSOC HE  Unnamed: 8  \
# 0    Boletice nad Labem      NaN    yes            yes         NaN
# 1             Vsetínská      NaN    yes            yes         NaN
# 2            Neumannova      NaN    yes            yes         NaN
# 3     Kohoutovice-sever      NaN    yes            yes         NaN
# 4       Kohoutovice-jih      NaN     no            yes         NaN
# ..                  ...      ...    ...            ...         ...
# 614             Plachta      NaN     no            yes         NaN
# 615         Nová Trnová      NaN     no            yes         NaN
# 616              Květná      NaN     no            yes         NaN
# 617      Nové Pitkovice      NaN     no            yes         NaN
# 618      Slunečný Vršek      NaN     no            yes         NaN
#
#      BSU CODE_1974  ...                         DELIMITATION OK?.1  \
# 0            716.0  ...                                         ok
# 1           1015.0  ...                                         ok
# 2           1021.0  ...                                         ok
# 3           1031.0  ...    ok (merge with Kohoutovice-jih (303992)
# 4           1031.0  ...  ok (merge with Kohoutovice-sever (010316)
# ..             ...  ...                                        ...
# 614            NaN  ...                                        NaN
# 615            NaN  ...                                        NaN
# 616            NaN  ...                                        NaN
# 617            NaN  ...                                        NaN
# 618            NaN  ...                                        NaN
#
#     BSU CODE_1992       BSU NAME_1992  \
# 0         71610.0  Boletice nad Labem
# 1        101540.0           Vsetínská
# 2        102190.0          Neumannova
# 3        103160.0   Kohoutovice-sever
# 4       3039920.0     Kohoutovice-jih
# ..            ...                 ...
# 614           NaN                 NaN
# 615           NaN                 NaN
# 616           NaN                 NaN
# 617           NaN                 NaN
# 618           NaN                 NaN
#
#                             DELIMITATION OK?.2 BSU CODE_2001  \
# 0                                           ok       71610.0
# 1                                           ok      101540.0
# 2                                           ok      102190.0
# 3      ok (merge with Kohoutovice-jih (303992)      103160.0
# 4    ok (merge with Kohoutovice-sever (010316)     3039920.0
# ..                                         ...           ...
# 614                                        NaN           NaN
# 615                                        NaN           NaN
# 616                                        NaN           NaN
# 617                                        NaN           NaN
# 618                                        NaN           NaN
#
#           BSU NAME_2001                         DELIMITATION OK?.3  \
# 0    Boletice nad Labem                                         ok
# 1             Vsetínská                                         ok
# 2            Neumannova                                         ok
# 3     Kohoutovice-sever    ok (merge with Kohoutovice-jih (303992)
# 4       Kohoutovice-jih  ok (merge with Kohoutovice-sever (010316)
# ..                  ...                                        ...
# 614                 NaN                                        NaN
# 615                 NaN                                        NaN
# 616                 NaN                                        NaN
# 617                 NaN                                        NaN
# 618                 NaN                                        NaN
#
#     BSU CODE_2014.1       BSU NAME_2014  \
# 0             71610  Boletice nad Labem
# 1            101540           Vsetínská
# 2            102190          Neumannova
# 3            103160   Kohoutovice-sever
# 4           3039920     Kohoutovice-jih
# ..              ...                 ...
# 614         3282510             Plachta
# 615         3291260         Nová Trnová
# 616         3293210              Květná
# 617         3297460      Nové Pitkovice
# 618         3297710      Slunečný Vršek
#
#                             DELIMITATION OK?.4
# 0                                           ok
# 1                                           ok
# 2                                           ok
# 3      ok (merge with Kohoutovice-jih (303992)
# 4    ok (merge with Kohoutovice-sever (010316)
# ..                                         ...
# 614                                         ok
# 615                                         ok
# 616                                         ok
# 617                                         ok
# 618                                         ok
#
# [619 rows x 24 columns]

# %%
estates = gpd.read_file('/data/uscuni-ulce/additional_data/housing_estates_locations/ZSJ_2016.shp')
estates[['KOD_ZSJ', 'KOD_UTJ', 'KOD_KU', 'KOD_MOaMC','KOD_OBEC', 'KOD_ZUJ',
     'KOD_OKRES', 'KOD_LAU1',  'KOD_KRAJ', 'KOD_CZNUTS']]
# Out:
#       KOD_ZSJ KOD_UTJ  KOD_KU KOD_MOaMC KOD_OBEC KOD_ZUJ KOD_OKRES KOD_LAU1  \
# 0      000019  600016  600016      None   554979  554979     40436   CZ0412
# 1      000027  600024  600024      None   554979  554979     40436   CZ0412
# 2      000035  600032  600032      None   535826  535826     40282   CZ0311
# 3      000043  600041  600041      None   581291  581291     40703   CZ0641
# 4      000051  600059  600059      None   547786  547786     40584   CZ0523
# ...       ...     ...     ...       ...      ...     ...       ...      ...
# 22500  391883  991881  991881      None   592935  592935     40754   CZ0646
# 22501  391891  991899  991899      None   592935  592935     40754   CZ0646
# 22502  391905  991902  991902      None   592935  592935     40754   CZ0646
# 22503  392316  990833  990833      None   555177  555177     40436   CZ0412
# 22504  392391  992399  992399      None   555690  555690     40436   CZ0412
#
#       KOD_KRAJ KOD_CZNUTS
# 0         3051      CZ041
# 1         3051      CZ041
# 2         3034      CZ031
# 3         3115      CZ064
# 4         3085      CZ052
# ...        ...        ...
# 22500     3115      CZ064
# 22501     3115      CZ064
# 22502     3115      CZ064
# 22503     3051      CZ041
# 22504     3051      CZ041
#
# [22505 rows x 10 columns]

# %%
# estates = gpd.read_file('/data/uscuni-ulce/additional_data/housing_estates_locations/ZSJ_2013.shp')
# estates[['KOD_ZSJ', 'KOD_UTJ', 'KOD_KU']]

# %%
estates['merge'] = estates['KOD_ZSJ'].astype(np.int64)

# %%
xcl
# Out:
#      MUNICIPALITY CODE MUNICIPALITY NAME  BSU CODE_2014  BSU CODE6_2014  \
# 0               562335             Děčín          71610            7161
# 1               582786              Brno         101540           10154
# 2               582786              Brno         102190           10219
# 3               582786              Brno         103160           10316
# 4               582786              Brno        3039920          303992
# ..                 ...               ...            ...             ...
# 614             569810    Hradec Králové        3282510          328251
# 615             555134         Pardubice        3291260          329126
# 616             554791             Plzeň        3293210          329321
# 617             554782             Praha        3297460          329746
# 618             554782             Praha        3297710          329771
#
#        BSU NAME_CURRENT poznámky SOC HE SOC&POSTSOC HE  Unnamed: 8  \
# 0    Boletice nad Labem      NaN    yes            yes         NaN
# 1             Vsetínská      NaN    yes            yes         NaN
# 2            Neumannova      NaN    yes            yes         NaN
# 3     Kohoutovice-sever      NaN    yes            yes         NaN
# 4       Kohoutovice-jih      NaN     no            yes         NaN
# ..                  ...      ...    ...            ...         ...
# 614             Plachta      NaN     no            yes         NaN
# 615         Nová Trnová      NaN     no            yes         NaN
# 616              Květná      NaN     no            yes         NaN
# 617      Nové Pitkovice      NaN     no            yes         NaN
# 618      Slunečný Vršek      NaN     no            yes         NaN
#
#      BSU CODE_1974  ...                         DELIMITATION OK?.1  \
# 0            716.0  ...                                         ok
# 1           1015.0  ...                                         ok
# 2           1021.0  ...                                         ok
# 3           1031.0  ...    ok (merge with Kohoutovice-jih (303992)
# 4           1031.0  ...  ok (merge with Kohoutovice-sever (010316)
# ..             ...  ...                                        ...
# 614            NaN  ...                                        NaN
# 615            NaN  ...                                        NaN
# 616            NaN  ...                                        NaN
# 617            NaN  ...                                        NaN
# 618            NaN  ...                                        NaN
#
#     BSU CODE_1992       BSU NAME_1992  \
# 0         71610.0  Boletice nad Labem
# 1        101540.0           Vsetínská
# 2        102190.0          Neumannova
# 3        103160.0   Kohoutovice-sever
# 4       3039920.0     Kohoutovice-jih
# ..            ...                 ...
# 614           NaN                 NaN
# 615           NaN                 NaN
# 616           NaN                 NaN
# 617           NaN                 NaN
# 618           NaN                 NaN
#
#                             DELIMITATION OK?.2 BSU CODE_2001  \
# 0                                           ok       71610.0
# 1                                           ok      101540.0
# 2                                           ok      102190.0
# 3      ok (merge with Kohoutovice-jih (303992)      103160.0
# 4    ok (merge with Kohoutovice-sever (010316)     3039920.0
# ..                                         ...           ...
# 614                                        NaN           NaN
# 615                                        NaN           NaN
# 616                                        NaN           NaN
# 617                                        NaN           NaN
# 618                                        NaN           NaN
#
#           BSU NAME_2001                         DELIMITATION OK?.3  \
# 0    Boletice nad Labem                                         ok
# 1             Vsetínská                                         ok
# 2            Neumannova                                         ok
# 3     Kohoutovice-sever    ok (merge with Kohoutovice-jih (303992)
# 4       Kohoutovice-jih  ok (merge with Kohoutovice-sever (010316)
# ..                  ...                                        ...
# 614                 NaN                                        NaN
# 615                 NaN                                        NaN
# 616                 NaN                                        NaN
# 617                 NaN                                        NaN
# 618                 NaN                                        NaN
#
#     BSU CODE_2014.1       BSU NAME_2014  \
# 0             71610  Boletice nad Labem
# 1            101540           Vsetínská
# 2            102190          Neumannova
# 3            103160   Kohoutovice-sever
# 4           3039920     Kohoutovice-jih
# ..              ...                 ...
# 614         3282510             Plachta
# 615         3291260         Nová Trnová
# 616         3293210              Květná
# 617         3297460      Nové Pitkovice
# 618         3297710      Slunečný Vršek
#
#                             DELIMITATION OK?.4
# 0                                           ok
# 1                                           ok
# 2                                           ok
# 3      ok (merge with Kohoutovice-jih (303992)
# 4    ok (merge with Kohoutovice-sever (010316)
# ..                                         ...
# 614                                         ok
# 615                                         ok
# 616                                         ok
# 617                                         ok
# 618                                         ok
#
# [619 rows x 24 columns]

# %%
estates
# Out:
#        OBJECTID KOD_ZSJ           NAZ_ZSJ KOD_UTJ                     NAZ_UTJ  \
# 0             1  000019          Abertamy  600016                    Abertamy
# 1             2  000027          Hřebečná  600024                    Hřebečná
# 2             3  000035            Adamov  600032  Adamov u Českých Budějovic
# 3             4  000043      Adamov-střed  600041                      Adamov
# 4             5  000051    Dolní Adršpach  600059              Dolní Adršpach
# ...         ...     ...               ...     ...                         ...
# 22500     22501  391883             Osina  991881                       Osina
# 22501     22502  391891           Pulkava  991899                     Pulkava
# 22502     22503  391905            Žbánov  991902                      Žbánov
# 22503     22504  392316           Korunní  990833           Doupov u Hradiště
# 22504     22505  392391  Valeč u Hradiště  992399            Valeč u Hradiště
#
#        KOD_KU                      NAZ_KU KOD_MOaMC NAZ_MOaMC KOD_OBEC  ...  \
# 0      600016                    Abertamy      None      None   554979  ...
# 1      600024                    Hřebečná      None      None   554979  ...
# 2      600032  Adamov u Českých Budějovic      None      None   535826  ...
# 3      600041                      Adamov      None      None   581291  ...
# 4      600059              Dolní Adršpach      None      None   547786  ...
# ...       ...                         ...       ...       ...      ...  ...
# 22500  991881                       Osina      None      None   592935  ...
# 22501  991899                     Pulkava      None      None   592935  ...
# 22502  991902                      Žbánov      None      None   592935  ...
# 22503  990833           Doupov u Hradiště      None      None   555177  ...
# 22504  992399            Valeč u Hradiště      None      None   555690  ...
#
#                NAZ_LAU1 KOD_KRAJ KOD_CZNUTS            NAZ_CZNUTS  \
# 0          Karlovy Vary     3051      CZ041      Karlovarský kraj
# 1          Karlovy Vary     3051      CZ041      Karlovarský kraj
# 2      České Budějovice     3034      CZ031        Jihočeský kraj
# 3               Blansko     3115      CZ064     Jihomoravský kraj
# 4                Náchod     3085      CZ052  Královéhradecký kraj
# ...                 ...      ...        ...                   ...
# 22500            Vyškov     3115      CZ064     Jihomoravský kraj
# 22501            Vyškov     3115      CZ064     Jihomoravský kraj
# 22502            Vyškov     3115      CZ064     Jihomoravský kraj
# 22503      Karlovy Vary     3051      CZ041      Karlovarský kraj
# 22504      Karlovy Vary     3051      CZ041      Karlovarský kraj
#
#                   SX            SY    SHAPE_Leng    SHAPE_Area  \
# 0     -850723.020041 -9.954003e+05  14334.505928  4.495815e+06
# 1     -850086.144023 -9.931472e+05  10639.455512  4.201627e+06
# 2     -750632.681550 -1.163900e+06   3249.497744  2.943796e+05
# 3     -592727.262885 -1.149301e+06  11825.584393  9.482951e+05
# 4     -616037.764016 -9.994413e+05  17048.649760  1.165216e+07
# ...              ...           ...           ...           ...
# 22500 -569855.639995 -1.138168e+06  29532.667221  2.927643e+07
# 22501 -567270.195946 -1.142738e+06  17026.650968  8.257026e+06
# 22502 -572394.441436 -1.133052e+06  37913.661082  3.406010e+07
# 22503 -835904.676667 -1.005037e+06  45025.316365  2.488600e+07
# 22504 -824784.438378 -1.020060e+06  13191.510325  6.492396e+06
#
#                                                 geometry   merge
# 0      POLYGON ((-851110.2 -993590.8, -851110 -993633...      19
# 1      POLYGON ((-848530.42 -992326.69, -848568.45 -9...      27
# 2      POLYGON ((-750760.81 -1163589.91, -750753.95 -...      35
# 3      POLYGON ((-592245.55 -1148394.97, -592201.4 -1...      43
# 4      POLYGON ((-616230.79 -996898.41, -616231.9 -99...      51
# ...                                                  ...     ...
# 22500  POLYGON ((-567707.44 -1134907.03, -567706.36 -...  391883
# 22501  POLYGON ((-565924.44 -1141141.34, -565925.89 -...  391891
# 22502  POLYGON ((-571572.12 -1130286.25, -571552.07 -...  391905
# 22503  POLYGON ((-832343.5 -999779.72, -832330.57 -99...  392316
# 22504  POLYGON ((-823913.15 -1019071.79, -823782.5 -1...  392391
#
# [22505 rows x 25 columns]

# %%
merged = pd.merge(estates, xcl[['BSU CODE6_2014', 'SOC HE', 'SOC&POSTSOC HE' ]], left_on='merge', right_on='BSU CODE6_2014')

# %%
merged[merged['SOC HE'] == 'yes'].shape
# Out:
# (428, 28)

# %%
merged = merged[merged['SOC&POSTSOC HE'] == 'yes']

# %%
merged.shape
# Out:
# (576, 28)

# %%
cz_soc_housing = merged.to_crs(epsg=3035)

# %% [markdown]
# ### Process all buildings, in all regions that have socialist housing

# %%
from libpysal.graph import Graph
regions_datadir = "/data/uscuni-ulce/"
simplfied_buildings_dir = '/data/uscuni-ulce/processed_data/simplified_buildings/'
buildings_dir = '/data/uscuni-ulce/processed_data/buildings/'

# %%
region_hulls = gpd.read_parquet(
        regions_datadir + "regions/" + "cadastre_regions_hull.parquet"
    )
inp, _ = cz_soc_housing.sindex.query(region_hulls.geometry, predicate='intersects')
czech_regions = region_hulls.iloc[np.unique(inp)]

# %%
czech_regions.index.values
# Out:
# array([ 55835,  61183,  61187,  63756,  64463,  66593,  67156,  67803,
#         69333,  72507,  73735,  75472,  75642,  83538,  84297,  84962,
#         93167,  97978, 100210, 102127, 103882, 105090, 107131])

# %%
# %%time
for region_id,_ in czech_regions.iterrows():
    
    ## read region building polygons
    buildings = gpd.read_parquet(simplfied_buildings_dir + f"buildings_{region_id}.parquet")
    buildings['area'] = buildings.area
    buildings['perimeter'] = buildings.length

    ### mark buildings in socialist housing
    _, blg_ix = buildings.sindex.query(cz_soc_housing.geometry, predicate="intersects")
    relevant = pd.Series(0, index=buildings.index, dtype=bool)
    relevant.iloc[np.unique(blg_ix)] = True

    # create a contiguity graph for the  buildings in socialist housing polygons
    contig = Graph.build_fuzzy_contiguity(buildings[relevant], buffer=1e-3)

    # get potetial socialist housing buildings
    min_area = 180
    min_perimeter = 55
    mask = (buildings['area'] > min_area) & (buildings['perimeter'] > min_perimeter) & relevant
    masked = buildings[mask].copy()

    ## merge potential socialist housing buildings, based on buffered graph contiguity
    masked.geometry = masked.buffer(1e-3)
    subgraph = contig.subgraph(masked.index)
    merged = masked.dissolve(subgraph.component_labels).explode()

    # add the rest of the data to the merged subset and save
    fixed = pd.concat([buildings[~relevant], merged], ignore_index=True)
    assert not fixed.index.duplicated().any()
    fixed.drop(columns=['area', 'perimeter']).to_parquet(buildings_dir + f"buildings_{region_id}.parquet")
# Out:
# CPU times: user 14.6 s, sys: 1.81 s, total: 16.4 s
# Wall time: 16.1 s

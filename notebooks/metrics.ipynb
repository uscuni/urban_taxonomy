# %%
# %%time

import glob

import geopandas as gpd
import matplotlib.pyplot as plt
import numba
import numpy as np
import pandas as pd
from libpysal.graph import read_parquet
from sklearn.preprocessing import PowerTransformer, RobustScaler, StandardScaler

from fast_hdbscan.numba_kdtree import kdtree_to_numba
from fast_hdbscan.numba_kdtree import parallel_tree_query
from sklearn.neighbors import KDTree
# Out:
# CPU times: user 11.1 s, sys: 383 ms, total: 11.5 s
# Wall time: 9.08 s

# %%
region_id = 69300

tessellations_dir = '/data/uscuni-ulce/processed_data/tessellations/'
chars_dir = "/data/uscuni-ulce/processed_data/chars/"
graph_dir = "/data/uscuni-ulce/processed_data/neigh_graphs/"

# %%
# region_id = 'freiburg'
# buildings_dir = streets_dir = enclosures_dir = tessellations_dir = graph_dir = '../data/freiburg/'
# chars_dir = '../data/freiburg/chars/'

# %%
graph = read_parquet(graph_dir + f"tessellation_graph_{region_id}_knn1.parquet")

# %%
graph.cardinalities.describe()
# Out:
# count    304554.000000
# mean          6.751085
# std           2.060782
# min           1.000000
# 25%           6.000000
# 50%           7.000000
# 75%           8.000000
# max          82.000000
# Name: cardinalities, dtype: float64

# %%
from core.cluster_validation import print_distance, generate_neigbhourhood_groups, generate_detailed_clusters

# %%
tessellation = gpd.read_parquet(
        tessellations_dir + f"tessellation_{region_id}.parquet"
)

# %%
X_train = pd.read_parquet(chars_dir + f'primary_chars_{region_id}.parquet')



X_train = X_train[X_train.index >= 0]



spatial_lag = 1


# lag = pd.read_parquet(f'/data/uscuni-ulce/processed_data/context_data/context_chars_{region_id}_lag_{spatial_lag}.parquet')

lag = pd.read_parquet(f'/data/uscuni-ulce/processed_data/context_data/unprocessed_context_chars_{region_id}_lag_{spatial_lag}.parquet')



X_train = X_train.join(lag[[c for c in lag.columns if '_median' in c]], how='inner')

# X_train = X_train.join(lag, how='inner')

# %%
# for c in X_train.columns:
#     X_train[c] = X_train[c].clip(*np.percentile(X_train[c], [5, 95]))

# %%
to_drop = ['stcSAl',
 'ltkOri',
 'stbOri',
 'stcOri',
 'stbCeA',

#not in barcelona
 'ltcBuA', 'midRea', 'midAre', 'likWBB'
]


all_drop = []
for c in to_drop:
    all_drop += X_train.columns[X_train.columns.str.contains(c)].tolist()


X_train = X_train.drop(all_drop, axis=1)

# %%
vals = StandardScaler().fit_transform(X_train)
X_train = pd.DataFrame(vals, columns=X_train.columns, index=X_train.index)

vals = np.nan_to_num(X_train)
X_train = pd.DataFrame(vals, columns=X_train.columns, index=X_train.index)

# %%
# t1 = X_train[[c for c in X_train.columns if '_' not in c]]
# t2 = X_train[[c for c in X_train.columns if '_median' in c]]

# X_train = t1.join(t2)
# X_train.shape

# %%
X_train = X_train[[c for c in X_train.columns if '_median' in c]]

# %%
# X_train = X_train.drop(stats.columns[stats.loc['std'] == 0], axis=1)

# %%
X_train.shape
# Out:
# (299064, 54)

# %%
tess_groups = generate_detailed_clusters(tessellation,
                                         include_random_sample=False)
tess_groups = tess_groups[tess_groups.index.isin(X_train.index)]
tess_groups_ilocs = (
    pd.Series(np.arange(len(X_train)), index=X_train.index)
    .loc[tess_groups.index]
    .values
)

from sklearn.metrics import davies_bouldin_score
def check_score(data, example_clusters):
    groups = example_clusters[example_clusters.index.isin(data.index)]
    groups_ilocs = (
        pd.Series(np.arange(len(data)), index=data.index).loc[groups.index].values
    )
    return davies_bouldin_score(data.iloc[groups_ilocs], groups.values)

check_score(X_train, tess_groups)
# Out:
# 3.0651731848710613

# %%
# tessellation.loc[tess_groups.index].explore()

# %%
from core.cluster_validation import print_distance
print_distance( pd.DataFrame(X_train.loc[tess_groups.index]).groupby(tess_groups.values).mean(), metric='euclidean')
# Out:
# <style type="text/css">
# #T_f6f48_row0_col0, #T_f6f48_row1_col1, #T_f6f48_row2_col2, #T_f6f48_row3_col3, #T_f6f48_row4_col4, #T_f6f48_row5_col5, #T_f6f48_row6_col6, #T_f6f48_row7_col7, #T_f6f48_row8_col8, #T_f6f48_row9_col9, #T_f6f48_row10_col10, #T_f6f48_row11_col11, #T_f6f48_row12_col12, #T_f6f48_row13_col13, #T_f6f48_row14_col14, #T_f6f48_row15_col15, #T_f6f48_row16_col16, #T_f6f48_row17_col17, #T_f6f48_row18_col18, #T_f6f48_row19_col19 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_f6f48_row0_col1, #T_f6f48_row11_col6, #T_f6f48_row15_col7 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_f6f48_row0_col2, #T_f6f48_row3_col4, #T_f6f48_row5_col16 {
#   background-color: #5dbd99;
#   color: #000000;
# }
# #T_f6f48_row0_col3 {
#   background-color: #82ceb8;
#   color: #000000;
# }
# #T_f6f48_row0_col4, #T_f6f48_row3_col11, #T_f6f48_row19_col0 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_f6f48_row0_col5, #T_f6f48_row1_col8, #T_f6f48_row2_col5, #T_f6f48_row6_col7, #T_f6f48_row11_col14 {
#   background-color: #2c9553;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col6, #T_f6f48_row7_col18 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_f6f48_row0_col7, #T_f6f48_row8_col12, #T_f6f48_row9_col10, #T_f6f48_row16_col0, #T_f6f48_row17_col12 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col8 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col9, #T_f6f48_row3_col19, #T_f6f48_row6_col9, #T_f6f48_row17_col9 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_f6f48_row0_col10, #T_f6f48_row1_col16, #T_f6f48_row2_col8, #T_f6f48_row3_col10, #T_f6f48_row4_col10, #T_f6f48_row5_col8, #T_f6f48_row6_col10, #T_f6f48_row7_col8, #T_f6f48_row8_col16, #T_f6f48_row9_col8, #T_f6f48_row10_col8, #T_f6f48_row11_col16, #T_f6f48_row12_col14, #T_f6f48_row13_col10, #T_f6f48_row14_col10, #T_f6f48_row15_col8, #T_f6f48_row16_col8, #T_f6f48_row17_col10, #T_f6f48_row18_col8, #T_f6f48_row19_col10 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col11, #T_f6f48_row14_col9, #T_f6f48_row15_col3, #T_f6f48_row16_col9 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col12, #T_f6f48_row8_col9, #T_f6f48_row8_col15 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col13, #T_f6f48_row4_col14, #T_f6f48_row7_col3, #T_f6f48_row12_col15, #T_f6f48_row13_col1, #T_f6f48_row13_col3 {
#   background-color: #38a367;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col14, #T_f6f48_row4_col7, #T_f6f48_row6_col8, #T_f6f48_row7_col1, #T_f6f48_row15_col10 {
#   background-color: #28914d;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col15, #T_f6f48_row11_col8, #T_f6f48_row11_col9, #T_f6f48_row16_col18, #T_f6f48_row18_col0, #T_f6f48_row18_col14 {
#   background-color: #3aa66a;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col16, #T_f6f48_row13_col8 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col17 {
#   background-color: #7fcdb6;
#   color: #000000;
# }
# #T_f6f48_row0_col18, #T_f6f48_row6_col14, #T_f6f48_row7_col0, #T_f6f48_row17_col14, #T_f6f48_row18_col11 {
#   background-color: #27904c;
#   color: #f1f1f1;
# }
# #T_f6f48_row0_col19, #T_f6f48_row1_col17 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_f6f48_row1_col0, #T_f6f48_row4_col2, #T_f6f48_row9_col5 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_f6f48_row1_col2, #T_f6f48_row2_col6, #T_f6f48_row9_col13 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col3, #T_f6f48_row7_col15 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_f6f48_row1_col4, #T_f6f48_row2_col11, #T_f6f48_row6_col2, #T_f6f48_row8_col6, #T_f6f48_row13_col0, #T_f6f48_row18_col17 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col5, #T_f6f48_row8_col4 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col6, #T_f6f48_row3_col17 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_f6f48_row1_col7, #T_f6f48_row5_col11, #T_f6f48_row10_col2, #T_f6f48_row10_col17, #T_f6f48_row10_col18 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col9, #T_f6f48_row4_col11 {
#   background-color: #44af79;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col10, #T_f6f48_row2_col10, #T_f6f48_row8_col10 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col11, #T_f6f48_row3_col0, #T_f6f48_row15_col19, #T_f6f48_row19_col15, #T_f6f48_row19_col18 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_f6f48_row1_col12 {
#   background-color: #2b9452;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col13, #T_f6f48_row3_col5, #T_f6f48_row7_col11 {
#   background-color: #29924f;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col14, #T_f6f48_row2_col18, #T_f6f48_row12_col6 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col15, #T_f6f48_row3_col12, #T_f6f48_row14_col7, #T_f6f48_row17_col18, #T_f6f48_row18_col1 {
#   background-color: #309b5b;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col18, #T_f6f48_row5_col1, #T_f6f48_row16_col4, #T_f6f48_row16_col17 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_f6f48_row1_col19, #T_f6f48_row11_col19, #T_f6f48_row19_col5 {
#   background-color: #53b88c;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col0, #T_f6f48_row5_col7, #T_f6f48_row11_col2, #T_f6f48_row15_col6 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col1, #T_f6f48_row13_col2, #T_f6f48_row14_col2 {
#   background-color: #3eaa70;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col3, #T_f6f48_row8_col11, #T_f6f48_row17_col1 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col4 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_f6f48_row2_col7, #T_f6f48_row12_col18, #T_f6f48_row14_col12 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col9, #T_f6f48_row3_col9, #T_f6f48_row4_col1, #T_f6f48_row8_col1, #T_f6f48_row12_col7, #T_f6f48_row13_col18 {
#   background-color: #4ab381;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col12, #T_f6f48_row6_col12, #T_f6f48_row8_col2, #T_f6f48_row11_col18 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col13 {
#   background-color: #248c47;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col14, #T_f6f48_row3_col18, #T_f6f48_row8_col19, #T_f6f48_row11_col7, #T_f6f48_row12_col11, #T_f6f48_row18_col12 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col15, #T_f6f48_row6_col13, #T_f6f48_row9_col11, #T_f6f48_row10_col9, #T_f6f48_row17_col5 {
#   background-color: #35a063;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col16, #T_f6f48_row10_col14 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_f6f48_row2_col17 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_f6f48_row2_col19, #T_f6f48_row11_col3, #T_f6f48_row18_col5 {
#   background-color: #7ccbb4;
#   color: #000000;
# }
# #T_f6f48_row3_col1, #T_f6f48_row3_col6 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_f6f48_row3_col2, #T_f6f48_row13_col17, #T_f6f48_row17_col15, #T_f6f48_row19_col11 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col7 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col8, #T_f6f48_row11_col12, #T_f6f48_row13_col5 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col13 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col14 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col15, #T_f6f48_row7_col19, #T_f6f48_row12_col3, #T_f6f48_row13_col11, #T_f6f48_row18_col3 {
#   background-color: #3fab72;
#   color: #f1f1f1;
# }
# #T_f6f48_row3_col16 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_f6f48_row4_col0, #T_f6f48_row10_col7, #T_f6f48_row12_col10 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_f6f48_row4_col3 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_f6f48_row4_col5, #T_f6f48_row8_col3 {
#   background-color: #54b88e;
#   color: #f1f1f1;
# }
# #T_f6f48_row4_col6, #T_f6f48_row6_col0, #T_f6f48_row11_col1, #T_f6f48_row16_col12, #T_f6f48_row17_col0 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_f6f48_row4_col8, #T_f6f48_row17_col16 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_f6f48_row4_col9, #T_f6f48_row9_col4, #T_f6f48_row10_col12, #T_f6f48_row11_col17 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_f6f48_row4_col12, #

# %%
from scipy.spatial.distance import pdist, cdist
for i, g in X_train.loc[tess_groups.index].groupby(tess_groups.values):
    print(i, np.mean(pdist(g)))
# Out:
# commie blocks vn 6.3207648031311185
# fancy commie blocks 6.935119126701156
# holyne 7.308764573381597
# housing blocks 7.883704219913125
# housing houses 5.135322727983048
# josefov 6.356178230906789
# karlin IT offices 7.155537239802385
# karlin old 8.050946434491378
# karlin river offices 12.169244436929116
# karlin square 6.938723552989892
# mala strana 14.218476603531737
# malesice 11.329911185540475
# prague castle 16.388396204045836
# row houses1 6.2293092467141635
# row houses2 5.239432591678582
# smickov 7.552513700331859
# stare mesto 10.996734667724422
# vinohrady blocks 5.918274571028474
# vinohrady squares 4.868591841477332
# vinohrady villas 5.068479625510638

# %%
# tessellation.loc[tess_groups.index].explore(column=tess_groups.values, categorical=True)

# %%
np.min(cdist(X_train.loc[tess_groups[tess_groups == 'josefov'].index], 
             X_train.loc[tess_groups[tess_groups == 'stare mesto'].index]))
# Out:
# 1.4722669131095896

# %%
mean_clusters = pd.DataFrame(X_train.loc[tess_groups.index]).groupby(tess_groups.values).mean()

# %%
(mean_clusters.loc['josefov'] - mean_clusters.loc['stare mesto']).abs().sort_values(ascending=False).iloc[:10]
# Out:
# libNCo_median    4.900441
# ssbERI_median    1.881506
# ldbPWL_median    1.836020
# lcnClo_median    1.223214
# sscERI_median    1.189771
# ssbCCo_median    1.164828
# ssbCCD_median    1.081226
# linPDE_median    1.058301
# linP3W_median    0.966330
# lcdMes_median    0.888653
# dtype: float64

# %%
from core.utils import used_keys
used_keys['lcnClo']
# Out:
# 'local closeness of street network'

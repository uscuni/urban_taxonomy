# %%
import geopandas as gpd
import numpy as np
import pandas as pd

# %%
final_clusters = pd.read_parquet('/data/uscuni-ulce/processed_data/clusters/clusters_v1.pq')[0]
from core.cluster_validation import get_color
final_colors = pd.DataFrame(get_color(final_clusters.values), final_clusters.values).drop_duplicates()
final_colors.loc[-1] = [255,255,255]

# %%
# region_id = 139196

# region_id = 69333  # prague
# region_id = 8707 # frankfurt / mainz
# region_id = 5883 # freiburtg
# region_id = 86873 # vienna
# region_id = 38679 # munich
# region_id = 55763 # berlin
# region_id = 107131 # krakow
# region_id = 99886 # bratislava

# region_id = 151676 # vilnius

# region_id= 66593 # nad uhno

# %%
etcs = gpd.read_parquet(f"/data/uscuni-ulce/processed_data/clusters/{region_id}_clusters.pq")

# %%
import lonboard
layer = lonboard.SolidPolygonLayer.from_geopandas(etcs, opacity=.7)

from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
with sc:
    display(m)
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/lonboard/_geoarrow/ops/reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")

# %%
from core.cluster_validation import get_color
layer.get_fill_color = final_colors.loc[etcs.final_without_noise].values.astype('uint8')

# %%
etcs.final.nunique()
# Out:
# 27

# %%
# layer.get_fill_color = get_color(etcs.morph.factorize()[0])

# %%
cdata= pd.read_parquet('/data/uscuni-ulce/processed_data/clusters/cdata_v1.pq')

# %%
cdata.loc[[4, 9, 1, 27]].style.background_gradient(axis=0, cmap="BuGn")
# Out:
# <style type="text/css">
# #T_4701d_row0_col0, #T_4701d_row0_col1, #T_4701d_row0_col2, #T_4701d_row0_col4, #T_4701d_row0_col5, #T_4701d_row0_col9, #T_4701d_row0_col17, #T_4701d_row0_col25, #T_4701d_row0_col26, #T_4701d_row0_col28, #T_4701d_row0_col34, #T_4701d_row0_col41, #T_4701d_row0_col42, #T_4701d_row0_col57, #T_4701d_row0_col58, #T_4701d_row1_col2, #T_4701d_row1_col8, #T_4701d_row1_col9, #T_4701d_row1_col10, #T_4701d_row1_col19, #T_4701d_row1_col20, #T_4701d_row1_col25, #T_4701d_row1_col27, #T_4701d_row1_col30, #T_4701d_row1_col34, #T_4701d_row1_col37, #T_4701d_row1_col38, #T_4701d_row1_col43, #T_4701d_row1_col45, #T_4701d_row1_col46, #T_4701d_row1_col48, #T_4701d_row1_col49, #T_4701d_row1_col50, #T_4701d_row1_col54, #T_4701d_row1_col55, #T_4701d_row1_col56, #T_4701d_row2_col2, #T_4701d_row2_col3, #T_4701d_row2_col4, #T_4701d_row2_col7, #T_4701d_row2_col9, #T_4701d_row2_col11, #T_4701d_row2_col13, #T_4701d_row2_col14, #T_4701d_row2_col22, #T_4701d_row2_col23, #T_4701d_row2_col25, #T_4701d_row2_col31, #T_4701d_row2_col32, #T_4701d_row2_col39, #T_4701d_row2_col40, #T_4701d_row2_col44, #T_4701d_row2_col52, #T_4701d_row2_col53, #T_4701d_row3_col2, #T_4701d_row3_col6, #T_4701d_row3_col9, #T_4701d_row3_col12, #T_4701d_row3_col15, #T_4701d_row3_col16, #T_4701d_row3_col18, #T_4701d_row3_col21, #T_4701d_row3_col24, #T_4701d_row3_col25, #T_4701d_row3_col29, #T_4701d_row3_col33, #T_4701d_row3_col35, #T_4701d_row3_col36, #T_4701d_row3_col47, #T_4701d_row3_col51 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_4701d_row0_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col6, #T_4701d_row0_col15, #T_4701d_row0_col16, #T_4701d_row0_col27, #T_4701d_row0_col29, #T_4701d_row0_col35, #T_4701d_row0_col47, #T_4701d_row1_col3, #T_4701d_row1_col4, #T_4701d_row1_col7, #T_4701d_row1_col11, #T_4701d_row1_col13, #T_4701d_row1_col14, #T_4701d_row1_col22, #T_4701d_row1_col23, #T_4701d_row1_col39, #T_4701d_row1_col40, #T_4701d_row1_col42, #T_4701d_row1_col51, #T_4701d_row1_col52, #T_4701d_row1_col53, #T_4701d_row2_col5, #T_4701d_row2_col8, #T_4701d_row2_col10, #T_4701d_row2_col12, #T_4701d_row2_col18, #T_4701d_row2_col19, #T_4701d_row2_col20, #T_4701d_row2_col21, #T_4701d_row2_col24, #T_4701d_row2_col33, #T_4701d_row2_col36, #T_4701d_row2_col37, #T_4701d_row2_col38, #T_4701d_row2_col43, #T_4701d_row2_col45, #T_4701d_row2_col46, #T_4701d_row2_col48, #T_4701d_row2_col49, #T_4701d_row2_col50, #T_4701d_row2_col54, #T_4701d_row3_col0, #T_4701d_row3_col1, #T_4701d_row3_col4, #T_4701d_row3_col17, #T_4701d_row3_col26, #T_4701d_row3_col28, #T_4701d_row3_col30, #T_4701d_row3_col31, #T_4701d_row3_col32, #T_4701d_row3_col34, #T_4701d_row3_col41, #T_4701d_row3_col44, #T_4701d_row3_col55, #T_4701d_row3_col56, #T_4701d_row3_col57, #T_4701d_row3_col58 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col7 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col8 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_4701d_row0_col10, #T_4701d_row3_col20 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_4701d_row0_col11 {
#   background-color: #2a9350;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col12 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_4701d_row0_col13 {
#   background-color: #3fac74;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col14 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col18, #T_4701d_row3_col23 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col19, #T_4701d_row2_col17 {
#   background-color: #bfe7de;
#   color: #000000;
# }
# #T_4701d_row0_col20 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_4701d_row0_col21, #T_4701d_row1_col24 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_4701d_row0_col22 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col23, #T_4701d_row0_col24 {
#   background-color: #37a266;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col30 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_4701d_row0_col31, #T_4701d_row0_col43 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_4701d_row0_col32, #T_4701d_row2_col0 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_4701d_row0_col33 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col36 {
#   background-color: #329d5e;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col37, #T_4701d_row3_col48 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_4701d_row0_col38, #T_4701d_row3_col19 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_4701d_row0_col39 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col40 {
#   background-color: #78cab1;
#   color: #000000;
# }
# #T_4701d_row0_col44 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_4701d_row0_col45, #T_4701d_row1_col6, #T_4701d_row2_col51 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_4701d_row0_col46 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_4701d_row0_col48 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_4701d_row0_col49 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_4701d_row0_col50, #T_4701d_row1_col57 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_4701d_row0_col51, #T_4701d_row3_col42 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col52, #T_4701d_row1_col29 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col53 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_4701d_row0_col54 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_4701d_row0_col55, #T_4701d_row0_col56 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_4701d_row1_col0, #T_4701d_row1_col16 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_4701d_row1_col1 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_4701d_row1_col5 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_4701d_row1_col12 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_4701d_row1_col15 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_4701d_row1_col17 {
#   background-color: #268f4a;
#   color: #f1f1f1;
# }
# #T_4701d_row1_col18 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_4701d_row1_col21 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_4701d_row1_col26, #T_4701d_row2_col57 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_4701d_row1_col28 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_4701d_row1_col31 {
#   background-color: #27904c;
#   color: #f1f1f1;
# }
# #T_4701d_row1_col32 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_4701d_row1_col33, #T_4701d_row2_col35 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_4701d_row1_col35 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_4701d_row1_col36 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_4701d_row1_col41, #T_4701d_row3_col39 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_4701d_row1_col44, #T_4701d_row2_col41 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_4701d_row1_col47 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# #T_4701d_row1_col58 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_4701d_row2_col1 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_4701d_row2_col6 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col15 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col16 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col26 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_4701d_row2_col27 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_4701d_row2_col28 {
#   background-color: #d9f1f0;
#   color: #000000;
# }
# #T_4701d_row2_col29 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col30 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col34 {
#   background-color: #339e60;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col42 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_4701d_row2_col47 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col55, #T_4701d_row2_col56 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_4701d_row2_col58 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_4701d_row3_col3 {
#   background-color: #b4e2d

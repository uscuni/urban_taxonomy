# %%
import momepy as mm
import numpy as np
import numba
import geopandas as gpd
import pandas as pd
import shapely
from sklearn.preprocessing import StandardScaler
from collections import namedtuple
from core.cluster_validation import get_linkage_matrix
from libpysal.graph import read_parquet, Graph
from core.generate_context import spatially_weighted_partial_lag
from core.generate_clusters import preprocess_clustering_data
from sklearn.cluster import AgglomerativeClustering
from core.cluster_validation import get_linkage_matrix
from scipy.cluster.hierarchy import fcluster
from core.utils import used_keys

# %%
regions_datadir = "/data/uscuni-ulce/"
morphotopes_dir = '/data/uscuni-ulce/processed_data/morphotopes/'
model_params = '_75_0_None_None_False'
clip = None
to_drop = [
        'stcSAl','stbOri','stcOri','stbCeA',
        'ldkAre', 'ldkPer', 'lskCCo', 'lskERI','lskCWA', 'ltkOri', 'ltkWNB', 'likWBB', 'likWCe',
          'licBAD', 'misBAD',
    'ssbCCM','ssbCCD'    
]


linkage = 'complete'
metric = 'euclidean'

morphotope_stat_columns = ['percentile_25', 'percentile_75', 'mean', 'std']

# %%
def preprocess_data(data, scalar, drop_columns=morphotope_stat_columns):
    component_data = data.drop(columns=drop_columns, level=1)
    component_data = component_data.drop(columns=to_drop, level=0)
    component_data.columns =  component_data.columns.get_level_values(0)
    
    component_data = component_data[component_data.index.str[-2:] != '-1']
    
    vals = scalar.fit_transform(component_data)
    component_data = pd.DataFrame(vals, columns=component_data.columns, index=component_data.index)
    component_data = component_data.drop(component_data.columns[component_data.std() == 0], axis=1)
    
    # component_data = component_data[component_data.index >= 0]
    vals = np.nan_to_num(component_data)
    component_data = pd.DataFrame(vals, columns=component_data.columns, index=component_data.index)
    return component_data

def read_region_morphotope_data(region_id, scalar, read_extra=False):
    print('processing' , region_id)
    data = pd.read_parquet(f'{morphotopes_dir}data_morphotopes_{region_id}{model_params}.pq')
    
    data.index = str(region_id) + '_' + data.index
    data = data.iloc[:, :-1]
    component_data = preprocess_data(data, scalar)


    if read_extra:
        extra_chars = pd.read_parquet(f'{morphotopes_dir}morph_chars_{region_id}.pq')
        vals = scalar.fit_transform(extra_chars)
        extra_chars = pd.DataFrame(vals, columns=extra_chars.columns, index=extra_chars.index).fillna(0)
        extra_chars = extra_chars.drop(component_data.columns[component_data.std() == 0], axis=1)
        extra_chars = extra_chars[['limLPS']]
        extra_chars['limLPS2'] = extra_chars['limLPS']

        merged_data = pd.merge(component_data, extra_chars, how='inner', left_index=True, right_index=True)
        pd.testing.assert_index_equal(merged_data.index, component_data.index)
        component_data = merged_data
    
    return component_data

def get_morphotope_linkage(region_data):
    
    clusterer = AgglomerativeClustering(linkage=linkage,
                                        metric=metric,
                                        compute_full_tree=True,
                                        compute_distances=True)
    model = clusterer.fit(region_data)
    linkage_matrix = get_linkage_matrix(model)
    return linkage_matrix


def get_all_clusters(cutoff):
    
    all_clusters = []
    
    for region_id, _ in region_hulls.iterrows():
        data = read_region_morphotope_data(region_id, scalar=StandardScaler())
        region_index = data.index
        linkage_matrix = np.load(f'/data/uscuni-ulce/processed_data/morphotope_linkage/{linkage}_{metric}_{region_id}.npy')
        clusters = fcluster(linkage_matrix, t=cutoff, criterion='distance')
        clusters = pd.Series(clusters, region_index).astype(str)
        clusters = str(region_id) + '_' +clusters
        all_clusters.append(clusters)
    
    all_clusters = pd.concat(all_clusters)
    
    return all_clusters


def read_morphotopes_data(model_params):
    
    data = []
    for region_id, _ in region_hulls.iterrows():
        region_morphotope_data = pd.read_parquet(f'{morphotopes_dir}data_morphotopes_{region_id}{model_params}.pq')
        region_morphotope_data.index = str(region_id) + '_' + region_morphotope_data.index.str[:]
        data.append(region_morphotope_data)
    
    data = pd.concat(data)
    return data

def read_morphotopes_chars():
    
    data = []
    for region_id, _ in region_hulls.iterrows():
        extra_chars = pd.read_parquet(f'{morphotopes_dir}morph_chars_{region_id}.pq')
        data.append(extra_chars)
    
    data = pd.concat(data)
    return data 

def morphotopes_to_etcs(region_id, etcs=True, model_params='_100_0_None_None_False'):


    if etcs:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/tessellations/tessellation_{region_id}.parquet')

    else:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/buildings/buildings_{region_id}.parquet')
        
    etcs['label'] = -1
    
    morphotopes = pd.read_parquet(f'/data/uscuni-ulce/processed_data/morphotopes/tessellation_labels_morphotopes_{region_id}{model_params}.pq')
    morphotopes.loc[:, 'morphotope_label'] =  morphotopes.values[:, 0]

    morph_dict = pd.Series(np.arange(np.unique(morphotopes.values).shape[0]),
                       np.unique(morphotopes.values))
    etcs.loc[morphotopes.index, 'label'] = morphotopes.map(lambda x: morph_dict.loc[x]).values
    etcs['morph'] = str(region_id) + '_' + '-1'
    etcs.loc[morphotopes.index, 'morph'] = str(region_id) + '_' + morphotopes.values
    return etcs

# %%
regions_datadir = "/data/uscuni-ulce/"
region_hulls = gpd.read_parquet(
        regions_datadir + "regions/" + "cadastre_regions_hull.parquet"
)

# %%
from sklearn.preprocessing import StandardScaler, QuantileTransformer
scalar = QuantileTransformer(subsample=None, output_distribution='uniform')

# %%
# # %%time

# ## generate and save linkage matricies for each region
# for region_id, _ in region_hulls.iterrows():
#     data = read_region_morphotope_data(region_id, scalar, read_extra=True)
#     linkage_matrix = get_morphotope_linkage(data)
#     np.save(f'/data/uscuni-ulce/processed_data/morphotope_linkage/{linkage}_{metric}_{region_id}', linkage_matrix)

# %% [markdown]
# ### Setup regional cutoff to merge regional morphotopes

# %%
regional_cutoff = 2.5

# %%
regional_clusters = get_all_clusters(cutoff=regional_cutoff)
# Out:
# processing 4
# processing 10
# processing 132
# processing 134
# processing 286
# processing 313
# processing 400
# processing 523
# processing 765
# processing 801
# processing 832
# processing 913
# processing 960
# processing 1124
# processing 1154
# processing 1387
# processing 1478
# processing 1515
# processing 1605
# processing 1718
# processing 1736
# processing 1782
# processing 1970
# processing 1981
# processing 2096
# processing 2322
# processing 2350
# processing 2478
# processing 2514
# processing 2625
# processing 2728
# processing 2975
# processing 3039
# processing 3109
# processing 3150
# processing 3221
# processing 3250
# processing 3526
# processing 3610
# processing 3612
# processing 3701
# processing 3705
# processing 3752
# processing 3759
# processing 3981
# processing 4070
# processing 103561
# processing 103713
# processing 103852
# processing 103882
# processing 103928
# processing 104018
# processing 104066
# processing 104568
# processing 105038
# processing 105090
# processing 105385
# processing 105388
# processing 105426
# processing 105457
# processing 105589
# processing 106034
# processing 106124
# processing 106363
# processing 106370
# processing 106384
# processing 106559
# processing 107131
# processing 107442
# processing 108050
# processing 108101
# processing 108127
# processing 108129
# processing 108263
# processing 108748
# processing 108755
# processing 108884
# processing 109404
# processing 109488
# processing 109491
# processing 109636
# processing 109727
# processing 109756
# processing 110016
# processing 110179
# processing 110237
# processing 110657
# processing 110691
# processing 110906
# processing 110908
# processing 111555
# processing 111689
# processing 111911
# processing 112253
# processing 112437
# processing 112696
# processing 112843
# processing 112949
# processing 113068
# processing 113301
# processing 114014
# processing 114180
# processing 114311
# processing 114591
# processing 114680
# processing 114822
# processing 115151
# processing 115595
# processing 115950
# processing 116316
# processing 116523
# processing 116801
# processing 116866
# processing 117182
# processing 117638
# processing 117720
# processing 118096
# processing 118747
# processing 119562
# processing 119609
# processing 120057
# processing 120193
# processing 120545
# processing 120961
# processing 120982
# processing 121071
# processing 121143
# processing 123228
# processing 123690
# processing 123904
# processing 123941
# processing 124160
# processing 124904
# processing 125016
# processing 125141
# processing 125667
# processing 126588
# processing 127101
# processing 127183
# processing 127626
# processing 128286
# processing 129032
# processing 129104
# processing 129395
# processing 129730
# processing 130341
# processing 130658
# processing 131130
# processing 131395
# processing 131786
# processing 131824
# processing 132225
# processing 133057
# processing 133100
# processing 133948
# processing 134023
# processing 134189
# processing 134454
# processing 134755
# processing 134905
# processing 135687
# processing 136169
# processing 136533
# processing 137469
# processing 137537
# processing 137636
# processing 137863
# processing 138804
# processing 139096
# processing 139621
# processing 139674
# processing 139764
# processing 140420
# processing 141272
# processing 141366
# processing 142100
# processing 143701
# processing 145906
# processing 146285
# processing 147112
# processing 147634
# processing 148018
# processing 148085
# processing 149997
# processing 150044
# processing 151676
# processing 152081
# processing 152511

# %%
np.unique(regional_clusters).shape
# Out:
# (66494,)

# %%
# why are these different  -

# %%
# %%time
morphotopes_data = read_morphotopes_data(model_params)
morphotopes_data = morphotopes_data.loc[regional_clusters.index]
morphotopes_data = morphotopes_data.iloc[:, :-1]

# %%
component_data = morphotopes_data.drop(columns=morphotope_stat_columns, level=1)
component_data = component_data.drop(columns=to_drop, level=0)
component_data.columns = component_data.columns.get_level_values(0)
# component_data['sdbCoA'] = morphotopes_data.loc[:, 'sdbCoA']['mean']

# %%
# %%time
morph_chars_data = read_morphotopes_chars()
morph_chars_data = morph_chars_data[['limLPS']]

merged_data = pd.merge(component_data, morph_chars_data, how='inner', left_index=True, right_index=True)
pd.testing.assert_index_equal(merged_data.index, component_data.index)
component_data = merged_data
# Out:
# CPU times: user 1.03 s, sys: 114 ms, total: 1.14 s
# Wall time: 1.03 s

# %%
component_data.loc[['93167_1802_0' , '91011_895_0']]
# Out:
#                   sdbAre     sdbPer  sdbCoA    ssbCCo  ssbCor    ssbSqu  \
# 93167_1802_0  125.845496  47.872983     0.0  0.537625     6.0  0.372616
# 91011_895_0   146.647818  54.164526     0.0  0.515053     4.0  0.578495
#
#                 ssbERI    ssbElo  mtbSWR  libNCo  ...     mibLen    mibElo  \
# 93167_1802_0  0.974698  0.663602     0.0     0.0  ...  50.821931  0.681935
# 91011_895_0   0.998408  0.629821     0.0     0.0  ...  55.410041  0.621665
#
#                 mibERI    mibCCo     mibLAL     mibFR    mibSCo      micBAD  \
# 93167_1802_0  0.963679  0.540910  17.738801  2.728918  2.728918   77.438724
# 91011_895_0   1.001599  0.523915  20.582737  2.793874  2.793874  147.467742
#
#                   midBAD  limLPS
# 93167_1802_0   88.052753     1.0
# 91011_895_0   150.848301     1.0
#
# [2 rows x 60 columns]

# %%
grouped_data = component_data.groupby(regional_clusters).agg('median').fillna(0)
grouped_data = grouped_data.drop(grouped_data.columns[grouped_data.std() == 0], axis=1)

# %%
grouped_data.loc[['93167_159' , '91011_76']]
# Out:
#                sdbAre     sdbPer  sdbCoA    ssbCCo  ssbCor    ssbSqu  \
# 93167_159  110.909878  45.151081     0.0  0.550615     6.0  0.630241
# 91011_76   136.005849  51.920073     0.0  0.509174     4.0  0.821341
#
#              ssbERI    ssbElo  mtbSWR  libNCo  ...     mibLen    mibElo  \
# 93167_159  0.970515  0.738956     0.0     0.0  ...  49.125985  0.728091
# 91011_76   0.995693  0.663834     0.0     0.0  ...  55.618098  0.642422
#
#              mibERI    mibCCo     mibLAL     mibFR    mibSCo      micBAD  \
# 93167_159  0.965074  0.548232  17.640081  2.641372  2.641372   57.185507
# 91011_76   0.996976  0.498945  20.342171  2.776168  2.776168  100.048444
#
#                midBAD  limLPS
# 93167_159   58.356939     1.0
# 91011_76   102.965102     1.0
#
# [2 rows x 60 columns]

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
vals = scalar.fit_transform(grouped_data)
regional_ward_morphotopes_data = pd.DataFrame(vals, index=grouped_data.index, columns=grouped_data.columns)

regional_ward_morphotopes_data.loc[grouped_data['limLPS'] == 1, 'limLPS'] = 2

# %%
regional_ward_morphotopes_data.loc[['93167_159' , '91011_76', '69333_179']]
# Out:
#              sdbAre    sdbPer    sdbCoA    ssbCCo    ssbCor    ssbSqu  \
# 93167_159  0.576278  0.678162 -0.003878  0.126992  1.457527  0.066072
# 91011_76   1.099949  1.350454 -0.003878 -1.080935 -0.544985  0.157445
# 69333_179  9.864410  7.339213 -0.003878 -3.692230  0.456271  0.045745
#
#              ssbERI    ssbElo    mtbSWR    libNCo  ...    mibLen    mibElo  \
# 93167_159 -1.477216  0.830937 -0.930174 -0.073819  ... -0.181517  0.829667
# 91011_76   0.183399 -0.155199 -0.930174 -0.073819  ... -0.146166  0.022774
# 69333_179 -3.131234 -1.988120 -0.930174 -0.073819  ...  0.259991 -1.152848
#
#              mibERI    mibCCo    mibLAL     mibFR    mibSCo    micBAD  \
# 93167_159  0.554162  0.889968 -0.342951 -0.244149 -0.244149 -0.136021
# 91011_76   0.830887  0.296214 -0.233768 -0.080452 -0.080452  0.019046
# 69333_179  0.230155 -0.642648  0.889081  2.434666  2.434666  1.958408
#
#              midBAD  limLPS
# 93167_159 -0.247615     2.0
# 91011_76  -0.064579     2.0
# 69333_179  0.729306     2.0
#
# [3 rows x 60 columns]

# %%
from scipy.spatial.distance import pdist
pdist(regional_ward_morphotopes_data.loc[['93167_159' , '91011_76', '69333_179']])
# Out:
# array([ 4.3566632 , 16.36468837, 15.52493095])

# %%
import umap
reducer = umap.UMAP(n_neighbors=25, n_components=20, 
                    min_dist=0,
                    metric='euclidean', verbose=True, random_state=1)
embedding = reducer.fit_transform(regional_ward_morphotopes_data)
embedding = pd.DataFrame(embedding, index=regional_ward_morphotopes_data.index)
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(min_dist=0, n_components=20, n_jobs=1, n_neighbors=25, random_state=1, verbose=True)
# Mon Jan 27 09:36:31 2025 Construct fuzzy simplicial set
# Mon Jan 27 09:36:31 2025 Finding Nearest Neighbors
# Mon Jan 27 09:36:31 2025 Building RP forest with 18 trees
# Mon Jan 27 09:36:33 2025 NN descent for 16 iterations
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	Stopping threshold met -- exiting after 3 iterations
# Mon Jan 27 09:36:41 2025 Finished Nearest Neighbor Search
# Mon Jan 27 09:36:42 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Jan 27 09:37:35 2025 Finished embedding

# %%
from scipy.spatial.distance import pdist
pdist(embedding.loc[['93167_159' , '91011_76', '69333_179']])
# Out:
# array([5.44217344, 3.10787919, 2.95447539])

# %% [markdown]
# ### Final ward clustering

# %%
linkage = 'average'
metric = 'euclidean'

# %%
# %%time
linkage_matrix = get_morphotope_linkage(embedding)
# Out:
# CPU times: user 1min 55s, sys: 6.08 s, total: 2min 1s
# Wall time: 2min

# %%
## final dendrogram
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram
fig,ax = plt.subplots(figsize=(10,10))
_ = dendrogram(linkage_matrix,ax=ax, no_labels=True)

# %%
np.save(f'/data/uscuni-ulce/processed_data/morphotope_linkage/{linkage}_{metric}_full.npy', linkage_matrix)

# %%
grouped_data.to_parquet(f'/data/uscuni-ulce/processed_data/morphotope_linkage/regional_clusters_{regional_cutoff}_data.pq')

# %%
embedding.to_parquet(f'/data/uscuni-ulce/processed_data/morphotope_linkage/regional_clusters_{regional_cutoff}_embedding.pq')

# %%
regional_ward_morphotopes_data.to_parquet(f'/data/uscuni-ulce/processed_data/morphotope_linkage/regional_clusters_{regional_cutoff}_embedding_input.pq')

# %%
f'regional_clusters_{regional_cutoff}.csv'
# Out:
# 'regional_clusters_2.5.csv'

# %%
regional_clusters.name='regional_cluster'
regional_clusters.to_frame().to_parquet(f'/data/uscuni-ulce/processed_data/morphotope_linkage/regional_clusters_{regional_cutoff}.pq')

# %%
regional_clusters
# Out:
# 4_0_0               4_164
# 4_0_1               4_712
# 4_0_10              4_734
# 4_0_100             4_903
# 4_0_101            4_1837
#                   ...
# 152511_809_0    152511_10
# 152511_8_0      152511_20
# 152511_8_1      152511_39
# 152511_8_2      152511_20
# 152511_901_0    152511_31
# Length: 523595, dtype: object

# %%
final_cutoff = .8

# %%
clusters = fcluster(linkage_matrix, t=final_cutoff, criterion='distance')
final_clusters = pd.Series(clusters, regional_ward_morphotopes_data.index)
# clusters_description = regional_ward_morphotopes_data.groupby(final_clusters).mean()
# clusters_description = grouped_data.groupby(final_clusters).mean()
final_clusters.value_counts()
# Out:
# 13     2752
# 2      2010
# 130    1948
# 62     1719
# 151    1574
#        ...
# 16        1
# 133       1
# 132       1
# 88        1
# 29        1
# Name: count, Length: 151, dtype: int64

# %%
means = regional_ward_morphotopes_data.groupby(final_clusters).mean()

# %%
means.style.background_gradient(axis=0, cmap="BuGn")
# Out:
# <style type="text/css">
# #T_c935c_row0_col0, #T_c935c_row3_col1, #T_c935c_row6_col6, #T_c935c_row9_col45, #T_c935c_row14_col15, #T_c935c_row14_col39, #T_c935c_row15_col0, #T_c935c_row18_col0, #T_c935c_row24_col24, #T_c935c_row25_col18, #T_c935c_row25_col37, #T_c935c_row40_col46, #T_c935c_row41_col45, #T_c935c_row50_col12, #T_c935c_row52_col39, #T_c935c_row53_col21, #T_c935c_row54_col32, #T_c935c_row64_col39, #T_c935c_row71_col18, #T_c935c_row72_col54, #T_c935c_row73_col35, #T_c935c_row74_col21, #T_c935c_row77_col12, #T_c935c_row77_col14, #T_c935c_row77_col15, #T_c935c_row81_col13, #T_c935c_row82_col1, #T_c935c_row83_col13, #T_c935c_row83_col15, #T_c935c_row84_col36, #T_c935c_row88_col39, #T_c935c_row90_col39, #T_c935c_row97_col45, #T_c935c_row102_col44, #T_c935c_row103_col36, #T_c935c_row103_col39, #T_c935c_row103_col47, #T_c935c_row105_col44, #T_c935c_row105_col45, #T_c935c_row107_col47, #T_c935c_row115_col37, #T_c935c_row124_col37, #T_c935c_row125_col28, #T_c935c_row129_col53, #T_c935c_row130_col54, #T_c935c_row131_col3, #T_c935c_row134_col24, #T_c935c_row137_col24, #T_c935c_row142_col22, #T_c935c_row143_col15, #T_c935c_row146_col10, #T_c935c_row150_col21 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_c935c_row0_col1, #T_c935c_row4_col44, #T_c935c_row6_col46, #T_c935c_row11_col0, #T_c935c_row13_col39, #T_c935c_row17_col6, #T_c935c_row23_col0, #T_c935c_row31_col15, #T_c935c_row32_col7, #T_c935c_row36_col46, #T_c935c_row39_col31, #T_c935c_row44_col36, #T_c935c_row49_col1, #T_c935c_row51_col34, #T_c935c_row54_col34, #T_c935c_row55_col46, #T_c935c_row57_col34, #T_c935c_row74_col19, #T_c935c_row77_col8, #T_c935c_row83_col37, #T_c935c_row86_col13, #T_c935c_row90_col13, #T_c935c_row92_col12, #T_c935c_row93_col46, #T_c935c_row95_col34, #T_c935c_row96_col39, #T_c935c_row99_col1, #T_c935c_row103_col1, #T_c935c_row104_col0, #T_c935c_row106_col14, #T_c935c_row116_col33, #T_c935c_row116_col46, #T_c935c_row121_col19, #T_c935c_row124_col1, #T_c935c_row129_col15, #T_c935c_row138_col3, #T_c935c_row146_col37, #T_c935c_row148_col1, #T_c935c_row150_col43 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_c935c_row0_col2, #T_c935c_row0_col5, #T_c935c_row0_col9, #T_c935c_row0_col17, #T_c935c_row0_col26, #T_c935c_row0_col27, #T_c935c_row0_col28, #T_c935c_row0_col29, #T_c935c_row0_col30, #T_c935c_row0_col34, #T_c935c_row1_col2, #T_c935c_row1_col5, #T_c935c_row1_col9, #T_c935c_row1_col25, #T_c935c_row1_col34, #T_c935c_row2_col2, #T_c935c_row2_col5, #T_c935c_row2_col9, #T_c935c_row2_col15, #T_c935c_row2_col34, #T_c935c_row2_col41, #T_c935c_row3_col2, #T_c935c_row3_col5, #T_c935c_row3_col9, #T_c935c_row3_col34, #T_c935c_row3_col38, #T_c935c_row4_col2, #T_c935c_row4_col9, #T_c935c_row4_col48, #T_c935c_row5_col2, #T_c935c_row5_col9, #T_c935c_row5_col48, #T_c935c_row6_col2, #T_c935c_row6_col5, #T_c935c_row6_col9, #T_c935c_row7_col2, #T_c935c_row7_col5, #T_c935c_row7_col8, #T_c935c_row7_col9, #T_c935c_row7_col48, #T_c935c_row8_col2, #T_c935c_row8_col9, #T_c935c_row9_col2, #T_c935c_row9_col9, #T_c935c_row10_col2, #T_c935c_row10_col9, #T_c935c_row11_col2, #T_c935c_row11_col9, #T_c935c_row12_col2, #T_c935c_row12_col5, #T_c935c_row12_col9, #T_c935c_row13_col2, #T_c935c_row13_col9, #T_c935c_row14_col2, #T_c935c_row14_col5, #T_c935c_row14_col9, #T_c935c_row15_col2, #T_c935c_row15_col5, #T_c935c_row15_col9, #T_c935c_row15_col18, #T_c935c_row15_col19, #T_c935c_row15_col20, #T_c935c_row15_col24, #T_c935c_row15_col36, #T_c935c_row16_col2, #T_c935c_row16_col9, #T_c935c_row17_col2, #T_c935c_row17_col5, #T_c935c_row17_col9, #T_c935c_row18_col2, #T_c935c_row18_col13, #T_c935c_row18_col22, #T_c935c_row18_col23, #T_c935c_row18_col44, #T_c935c_row19_col2, #T_c935c_row20_col2, #T_c935c_row20_col9, #T_c935c_row21_col2, #T_c935c_row21_col6, #T_c935c_row22_col2, #T_c935c_row22_col9, #T_c935c_row23_col2, #T_c935c_row23_col9, #T_c935c_row24_col2, #T_c935c_row24_col5, #T_c935c_row24_col9, #T_c935c_row25_col2, #T_c935c_row25_col5, #T_c935c_row25_col9, #T_c935c_row26_col2, #T_c935c_row26_col5, #T_c935c_row26_col9, #T_c935c_row27_col2, #T_c935c_row27_col5, #T_c935c_row27_col9, #T_c935c_row28_col2, #T_c935c_row28_col5, #T_c935c_row28_col9, #T_c935c_row29_col2, #T_c935c_row29_col9, #T_c935c_row30_col2, #T_c935c_row30_col3, #T_c935c_row30_col7, #T_c935c_row30_col9, #T_c935c_row31_col2, #T_c935c_row31_col5, #T_c935c_row31_col9, #T_c935c_row32_col2, #T_c935c_row32_col5, #T_c935c_row32_col9, #T_c935c_row32_col31, #T_c935c_row32_col32, #T_c935c_row33_col2, #T_c935c_row33_col5, #T_c935c_row33_col9, #T_c935c_row34_col2, #T_c935c_row34_col5, #T_c935c_row34_col9, #T_c935c_row34_col43, #T_c935c_row34_col45, #T_c935c_row34_col46, #T_c935c_row34_col48, #T_c935c_row35_col2, #T_c935c_row35_col5, #T_c935c_row35_col9, #T_c935c_row35_col46, #T_c935c_row35_col48, #T_c935c_row36_col2, #T_c935c_row36_col9, #T_c935c_row37_col2, #T_c935c_row37_col5, #T_c935c_row37_col9, #T_c935c_row38_col2, #T_c935c_row38_col9, #T_c935c_row38_col48, #T_c935c_row38_col49, #T_c935c_row39_col2, #T_c935c_row39_col5, #T_c935c_row39_col9, #T_c935c_row40_col2, #T_c935c_row40_col5, #T_c935c_row40_col9, #T_c935c_row41_col2, #T_c935c_row41_col5, #T_c935c_row41_col8, #T_c935c_row41_col9, #T_c935c_row41_col48, #T_c935c_row42_col2, #T_c935c_row42_col5, #T_c935c_row42_col9, #T_c935c_row43_col2, #T_c935c_row43_col5, #T_c935c_row43_col9, #T_c935c_row44_col2, #T_c935c_row44_col5, #T_c935c_row44_col9, #T_c935c_row44_col21, #T_c935c_row45_col2, #T_c935c_row45_col5, #T_c935c_row45_col9, #T_c935c_row45_col48, #T_c935c_row46_col2, #T_c935c_row46_col5, #T_c935c_row46_col9, #T_c935c_row47_col2, #T_c935c_row47_col5, #T_c935c_row47_col9, #T_c935c_row47_col48, #T_c935c_row47_col49, #T_c935c_row48_col2, #T_c935c_row48_col5, #T_c935c_row48_col9, #T_c935c_row49_col2, #T_c935c_row49_col5, #T_c935c_row49_col9, #T_c935c_row50_col2, #T_c935c_row50_col5, #T_c935c_row50_col9, #T_c935c_row51_col2, #T_c935c_row51_col9, #T_c935c_row52_col2, #T_c935c_row52_col5, #T_c935c_row52_col9, #T_c935c_row53_col2, #T_c935c_row53_col5, #T_c935c_row53_col9, #T_c935c_row54_col2, #T_c935c_row54_col5, #T_c935c_row54_col9, #T_c935c_row55_col2, #T_c935c_row5 ...

# %% [markdown]
# ### Plotting

# %%
from core.cluster_validation import get_color
final_colors = pd.DataFrame(get_color(final_clusters.values), final_clusters.values).drop_duplicates()
final_colors.loc[-1] = [255,255,255]

# %%
region_id = 69333 

# region_id = 99886 # bratislava

# region_id = 151676 # vilnius

# region_id = 8707 # mainz/frankfurt
# region_id = 5883 #  freiburg
# region_id = 38679 #munich
# region_id = 55763 # berlin

# region_id = 86873 # vienna

# region_id = 107131 # krakow


# region_id= 66593

# region_id = 91011

# %%
# etcs=False to read buildings, etcs=True for tessellation cells.


# etcs = morphotopes_to_etcs(region_id, etcs=False, model_params=model_params)

# %%
etcs = morphotopes_to_etcs(69333, etcs=False, model_params=model_params)
etcs2 = morphotopes_to_etcs(91011, etcs=False, model_params=model_params)
etcs3 = morphotopes_to_etcs(93167, etcs=False, model_params=model_params)

etcs = pd.concat((etcs, etcs2, etcs3), ignore_index=True)

# %%
## relabel
### regional_clusters = morphotopes -> regional_clusters
### final_clusters = regional_clusters -> final_clusters
etcs['final'] = etcs['morph'].map(lambda x: final_clusters.loc[regional_clusters.loc[x]] if x in regional_clusters else -1)
etcs['regional'] = etcs['morph'].map(lambda x: regional_clusters.loc[x] if x in regional_clusters else "-1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # direct kmeans
# ----> 2 etcs['final'] = etcs['morph'].map(lambda x: final_clusters.loc[x] if x in morphotopes_data.index else -1)
#       3 etcs['regional'] = etcs['morph']
#
# NameError: name 'etcs' is not defined

# %%
# ## can run this to change colors on an exisitng layer
# layer.get_fill_color = get_color(etcs.final)

# %%
etcs['geometry'] = etcs.simplify(1).to_crs(epsg=4326).make_valid()
etcs = etcs[etcs['geometry'].geom_type == 'Polygon']

# %%
# %%time
import lonboard
# plotting = tessellation[tessellation.index.isin(X_train.index)].copy()
layer = lonboard.SolidPolygonLayer.from_geopandas(etcs, opacity=.7)
# Out:
# CPU times: user 2.04 s, sys: 310 ms, total: 2.35 s
# Wall time: 2.35 s

# %%
from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters - {final_cutoff}')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
with sc:
    display(m)

# %%
from core.cluster_validation import get_color
layer.get_fill_color = final_colors.loc[etcs.final].values.astype('uint8')

# %%
colorcodes = etcs['regional'].map(merged_clusters.to_dict()).fillna(-1)
layer.get_fill_color = merged_colors.loc[colorcodes].values.astype('uint8')
colorcodes.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 colorcodes = etcs['regional'].map(merged_clusters.to_dict()).fillna(-1)
# ----> 2 layer.get_fill_color = merged_colors.loc[colorcodes].values.astype('uint8')
#       3 colorcodes.nunique()
#
# NameError: name 'merged_colors' is not defined

# %%
etcs.final.value_counts().shape
# Out:
# (17,)

# %% [markdown]
# ### Interactive dendro

# %%
linkage_matrix = linkage_matrix

# %%
from core import interactive_dendrogram
import jscatter
import ipywidgets

scatter_df = interactive_dendrogram.get_dendrogram_scatter_data(linkage_matrix)
n = linkage_matrix.shape[0] + 1

def get_subcluster_children(focus):
    child, parent = linkage_matrix[focus - n, 0].astype(int), linkage_matrix[focus - n, 1].astype(int)
    children_ids = interactive_dendrogram.get_children(linkage_matrix, child, parent)
    children_morphotopes = regional_ward_morphotopes_data.iloc[children_ids].index
    return children_morphotopes

click_history = dict()
click_history_descriptions = dict()

# %%
scatter = jscatter.Scatter(data=scatter_df, x='x', y='y', height=640, width=1280)
scatter.axes(grid=True)
scatter.connect(by='group1', order='order1')
scatter.options({ 'pointConnectionTolerance': 1 })

# output = ipywidgets.Output()

# @output.capture(clear_output=True)
# def selection_change_handler(change):
#     display(scatter_df.loc[change.new].style.hide(axis='index'))
            
# scatter.widget.observe(selection_change_handler, names=["selection"])

# ipywidgets.HBox([scatter.show(), output])

# %%
scatter.show()
# Out:
# HBox(children=(VBox(children=(Button(button_style='primary', icon='arrows', layout=Layout(width='36px'), style…

# %%
selected_node = scatter.selection()[0]


left = scatter_df.loc[selected_node, 'child'].astype(int)
right = scatter_df.loc[selected_node, 'parent'].astype(int)

left_children = get_subcluster_children(left)
right_children = get_subcluster_children(right)

cluster_colors = np.full((etcs.shape[0], 3), 0) # everything black
cluster_colors[etcs.regional.isin(left_children)] = [141,211,199] # left blue - 1
cluster_colors[etcs.regional.isin(right_children)] = [255,255,179] # right yellow - 2
layer.get_fill_color = cluster_colors.astype('uint8')

# %%
left_data = regional_ward_morphotopes_data.loc[left_children].mean()
right_data = regional_ward_morphotopes_data.loc[right_children].mean()
# assert np.isclose(pd.DataFrame({1:left_data, 2: right_data}).T.values, clusters_description.values).all()

diffs = (left_data - right_data)
diffs = diffs[(diffs ** 2).sort_values(ascending=False).index].head(20)
diffs
# Out:
# mtdDeg   -2.008590
# linWID    1.620166
# sdsSPO   -1.578583
# mtbSWR    1.463171
# ltcBuA   -1.353060
# mtbNDi   -1.281014
# mtbAli   -1.066860
# sdsSPW   -1.039289
# sdcAre   -1.037840
# sdcLAL   -1.035507
# sscERI   -1.034659
# ldsAre   -1.024181
# ldsMSL   -1.022198
# midAre   -1.019047
# mibERI   -0.906347
# mdcAre   -0.904416
# sscCCo   -0.851772
# lddNDe    0.830976
# mtcWNe    0.828024
# midRea   -0.819065
# dtype: float64

# %%
selected_node
# Out:
# np.uint32(132985)

# %%
used_keys['ldsRea']
# Out:
# 'reached ETCs by local street network'

# %%
## save for cutting...
click_history[selected_node] = diffs

# %%
click_history_descriptions[selected_node] = f'{region_id} seperate smaller blocks and villages'

# %%
click_history_descriptions
# Out:
# {np.uint32(31798): 'seperate rowhouses and vinohrady',
#  np.uint32(29569): 'seperate smaller structures and vinohrady',
#  np.uint32(124136): 'seperate smaller blocks and smaller industry',
#  np.uint32(39767): '55763 seperate smaller blocks and smaller industry in germany',
#  np.uint32(115401): '69333 seperate smaller blocks and villages',
#  np.uint32(46460): '66593 seperate smaller blocks and villages',
#  np.uint32(125887): '151676 seperate smaller blocks and villages'}

# %%
click_history_descriptions = {np.uint32(31798): 'seperate rowhouses and vinohrady',
 np.uint32(29569): 'seperate smaller structures and vinohrady',
 np.uint32(124136): 'seperate smaller blocks and smaller industry',
 np.uint32(39767): '55763 seperate smaller blocks and smaller industry in germany',
 np.uint32(115401): '69333 seperate smaller blocks and villages',
 np.uint32(46460): '66593 seperate smaller blocks and villages',
 np.uint32(125887): '151676 seperate smaller blocks and villages'}

# %%
## assign clusters

# %%
clusters = fcluster(linkage_matrix, t=final_cutoff, criterion='distance')
final_clusters = pd.Series(clusters, regional_ward_morphotopes_data.index)

grouping = pd.DataFrame()
grouping[final_cutoff] = final_clusters.astype(str)

# %%
# for selected_node in [6421, 6887, 28557, 15017, 35908]: - hierarchy without lithuania


for selected_node in click_history_descriptions.keys():
    left = scatter_df.loc[selected_node, 'child'].astype(int)
    right = scatter_df.loc[selected_node, 'parent'].astype(int)
    
    left_children = get_subcluster_children(left)
    right_children = get_subcluster_children(right)
    
    grouping.loc[left_children, round(scatter_df.loc[selected_node, 'dist'], 2)] = str(selected_node) + '1'
    grouping.loc[right_children, round(scatter_df.loc[selected_node, 'dist'], 2)] = str(selected_node) + '2'

# %%
ordered_columns = grouping.columns.sort_values()
grouping = grouping[ordered_columns]

# forward cluster breakdowns to higher levels
for i, col in enumerate(ordered_columns[:-1]):
    grouping.iloc[grouping[col].notna().values, i + 1] = grouping.loc[grouping[col].notna(), col]

# %%
merged_clusters = grouping[final_cutoff]
merged_clusters.factorize()
# Out:
# (array([ 0,  1,  2, ..., 22,  7,  7]),
#  Index(['13', '14', '7', '6', '11', '317982', '24', '3', '2', '8', '5', '17',
#         '21', '25', '1258872', '23', '464601', '1154012', '1241362', '16',
#         '295691', '1', '295692', '4', '18', '1241361', '15', '10', '1258871',
#         '464602', '9', '20', '397672', '397671'],
#        dtype='object'))

# %%
merged_clusters = pd.Series(merged_clusters.factorize()[0], merged_clusters.index)

# %%
merged_colors = pd.DataFrame(get_color(merged_clusters.values), merged_clusters.values).drop_duplicates()
merged_colors.loc[-1] = [255,255,255]

# %%
colorcodes = etcs['regional'].map(merged_clusters.to_dict()).fillna(-1)
layer.get_fill_color = merged_colors.loc[colorcodes].values.astype('uint8')

# %%
click_history_descriptions
# Out:
# {np.uint32(31798): 'seperate rowhouses and vinohrady',
#  np.uint32(29569): 'seperate smaller structures and vinohrady',
#  np.uint32(124136): 'seperate smaller blocks and smaller industry',
#  np.uint32(39767): '55763 seperate smaller blocks and smaller industry in germany',
#  np.uint32(115401): '69333 seperate smaller blocks and villages',
#  np.uint32(46460): '66593 seperate smaller blocks and villages',
#  np.uint32(125887): '151676 seperate smaller blocks and villages'}

# %%
scatter_df.loc[click_history_descriptions.keys()]
# Out:
#            child    parent      dist    size             x         y   group1  \
# 31798   132691.0  132918.0  1.819189  2692.0  5.975272e+05  1.819189  66443.0
# 29569   132013.0  132641.0  0.946188   463.0  5.866530e+05  0.946188  66443.0
# 124136  132544.0  132880.0  1.797646   965.0  1.141552e+06  1.797646  66477.0
# 39767   132211.0  132332.0  0.857903   557.0  7.885529e+05  0.857903  66116.0
# 115401  132879.0  132939.0  1.887804  3016.0  9.359880e+05  1.887804  66474.0
# 46460   132727.0  132833.0  1.370760   568.0  9.230535e+05  1.370760  66449.0
# 125887  132758.0  132815.0  1.600071  1058.0  1.175755e+06  1.600071  66438.0
#
#         order1
# 31798        2
# 29569        3
# 124136       3
# 39767        2
# 115401       1
# 46460        3
# 125887       1

# %%
merged_clusters.value_counts().sort_index()
# Out:
# 0     2304
# 1     4443
# 2     3036
# 3     1437
# 4     3061
# 5     2229
# 6     3280
# 7     2568
# 8     1067
# 9     3655
# 10    2705
# 11    2713
# 12    5131
# 13    2270
# 14     560
# 15    2237
# 16     351
# 17    2448
# 18     665
# 19     850
# 20     262
# 21     836
# 22     201
# 23    3291
# 24    2646
# 25     300
# 26     580
# 27    3142
# 28     498
# 29     217
# 30    4314
# 31    2640
# 32     354
# 33     203
# Name: count, dtype: int64

# %%
v = 'v2'

# %%
pd.Series(click_history_descriptions).to_csv(f'/data/uscuni-ulce/processed_data/clusters/manual_cuts_{v}.csv')

# %%
merged_clusters.to_frame().to_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{v}.pq')

# %%
final_clusters = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{v}.pq')[0]
cdata = grouped_data.groupby(final_clusters).median().fillna(0)
cdata.to_parquet(f'/data/uscuni-ulce/processed_data/clusters/cdata_{v}.pq')
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/pandas/io/parquet.py:480: UserWarning: The DataFrame has non-str index name `[np.int64(0)]` which will be converted to string and not roundtrip correctly.
#   impl.write(

# %% [markdown]
# ### hierarchy of final clusters

# %%
fdata = grouped_data.groupby(merged_clusters).median().fillna(0)

# %%
fdata.to_parquet('../data/cluster_data.pq')

# %%
fdata = grouped_data.groupby(merged_clusters).median().fillna(0)
scalar = StandardScaler()
vals = scalar.fit_transform(fdata)
fdata = pd.DataFrame(vals, index=fdata.index, columns=fdata.columns)

# %%
linkage = 'complete'
metric = 'euclidean'
linkage_matrix = get_morphotope_linkage(fdata)

# %%
## final dendrogram
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram
fig,ax = plt.subplots(figsize=(10,10))
_ = dendrogram(linkage_matrix,ax=ax)

# %%
etcs[etcs.final == 28].explore(prefer_canvas=True, tiles='cartodb.positron')

# %%
final_cutoff = 8
clusters = fcluster(linkage_matrix, t=final_cutoff, criterion='distance')
final_clusters = pd.Series(clusters, fdata.index)
final_clusters.value_counts()
# Out:
# 5    7
# 4    6
# 8    6
# 3    4
# 6    4
# 1    3
# 7    2
# 2    1
# 9    1
# Name: count, dtype: int64

# %% [markdown]
# ### assign to etcs

# %%
from core.cluster_validation import get_color
merged_colors = pd.DataFrame(get_color(merged_clusters.values), merged_clusters.values).drop_duplicates()
merged_colors.loc[-1] = [255,255,255]

# %%
region_id = 151676

# %%
# etcs=False to read buildings, etcs=True for tessellation cells.
etcs = morphotopes_to_etcs(region_id, etcs=False, model_params=model_params)
etcs.shape
# Out:
# (321417, 16)

# %%
# region_hulls.explore()

# %%
## relabel
### regional_clusters = morphotopes -> regional_clusters
### final_clusters = regional_clusters -> final_clusters
etcs['final'] = etcs['morph'].map(lambda x: merged_clusters.loc[regional_clusters.loc[x]] if x in regional_clusters else -1)
etcs['regional'] = etcs['morph'].map(lambda x: regional_clusters.loc[x] if x in regional_clusters else "-1")

# %%
# etcs['final'] = etcs.final.map(final_clusters).values

# %%
region_hulls
# Out:
#                                               convex_hull
# labels
# 4       POLYGON ((4122200 3045600, 4121500 3045900, 40...
# 10      POLYGON ((4068900 3057300, 4051000 3064300, 40...
# 132     POLYGON ((4053100 3049800, 4050900 3053000, 40...
# 134     POLYGON ((4052500 3093600, 4052200 3093700, 40...
# 286     POLYGON ((4060600 3103900, 4057000 3104200, 40...
# ...                                                   ...
# 149997  POLYGON ((5253200 3642300, 5245600 3647000, 52...
# 150044  POLYGON ((5265700 3578300, 5263400 3578400, 52...
# 151676  POLYGON ((5285400 3549200, 5284800 3549900, 52...
# 152081  POLYGON ((5269700 3664900, 5269300 3665300, 52...
# 152511  POLYGON ((5298200 3650100, 5279200 3651600, 52...
#
# [847 rows x 1 columns]

# %%
# %%time
import lonboard
# plotting = tessellation[tessellation.index.isin(X_train.index)].copy()
layer = lonboard.SolidPolygonLayer.from_geopandas(etcs, opacity=.7)

from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
with sc:
    display(m)

from core.cluster_validation import get_color
layer.get_fill_color = merged_colors.loc[etcs.final].values.astype('uint8')
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/lonboard/_geoarrow/ops/reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# CPU times: user 1.63 s, sys: 199 ms, total: 1.83 s
# Wall time: 1.81 s

# %%
# layer.get_fill_color = get_color(etcs.final.map(final_clusters).values.astype(int))

# %%
etcs.final.nunique()
# Out:
# 17

# %%
etcs.to_parquet(f'/data/uscuni-ulce/processed_data/clusters/{region_id}_clusters.pq')

# %%
merged_colors.shape
# Out:
# (33, 3)

# %% [markdown]
# ## Assign all regions

# %%
v = 'v2'
merged_clusters = pd.read_parquet(f'/data/uscuni-ulce/processed_data/clusters/clusters_{v}.pq')[0]
merged_clusters.nunique()
# Out:
# 34

# %%
# %%time
for region_id, _ in region_hulls.iterrows():
    print(region_id)
    etcs = morphotopes_to_etcs(region_id, etcs=False, model_params=model_params)
    etcs['final'] = etcs['morph'].map(lambda x: merged_clusters.loc[regional_clusters.loc[x]] if x in regional_clusters else -1)
    etcs['regional'] = etcs['morph'].map(lambda x: regional_clusters.loc[x] if x in regional_clusters else "-1")
    etcs.to_parquet(f'/data/uscuni-ulce/processed_data/clusters/{region_id}_clusters.pq')
# Out:
# 4
# 10
# 132
# 134
# 286
# 313
# 400
# 523
# 765
# 801
# 832
# 913
# 960
# 1124
# 1154
# 1387
# 1478
# 1515
# 1605
# 1718
# 1736
# 1782
# 1970
# 1981
# 2096
# 2322
# 2350
# 2478
# 2514
# 2625
# 2728
# 2975
# 3039
# 3109
# 3150
# 3221
# 3250
# 3526
# 3610
# 3612
# 3701
# 3705
# 3752
# 3759
# 3981
# 4070
# 4214
# 4215
# 4235
# 4284
# 4356
# 4382
# 4723
# 4805
# 5096
# 5191
# 5246
# 5310
# 5408
# 5427
# 5662
# 5671
# 5766
# 5883
# 6254
# 6529
# 6560
# 6576
# 6741
# 6749
# 6811
# 6873
# 6996
# 7068
# 7094
# 7280
# 7485
# 7528
# 7534
# 7681
# 7688
# 7712
# 7727
# 7805
# 7914
# 7937
# 7963
# 8046
# 8216
# 8238
# 8256
# 8265
# 8345
# 8374
# 8396
# 8592
# 8707
# 8731
# 8757
# 8759
# 8813
# 9016
# 9064
# 9074
# 9150
# 9169
# 9194
# 9284
# 9824
# 9924
# 9954
# 9972
# 10019
# 10086
# 10095
# 10124
# 10179
# 10222
# 10263
# 10277
# 10455
# 10510
# 10511
# 10563
# 10579
# 10602
# 10666
# 10794
# 10847
# 10908
# 10926
# 10970
# 11002
# 11019
# 11057
# 11141
# 11210
# 11256
# 11261
# 11305
# 11309
# 11311
# 11318
# 11367
# 11444
# 11455
# 11471
# 11667
# 11678
# 11735
# 11757
# 11799
# 11877
# 11905
# 12027
# 12084
# 12100
# 12115
# 12154
# 12191
# 12381
# 12440
# 12483
# 12552
# 12667
# 12707
# 12755
# 12756
# 12844
# 12919
# 12965
# 13076
# 13137
# 13172
# 13191
# 13196
# 13229
# 13301
# 13395
# 13442
# 13482
# 13506
# 13553
# 13555
# 13614
# 13616
# 13655
# 13677
# 129730
# 130341
# 130658
# 131130
# 131395
# 131786
# 131824
# 132225
# 133057
# 133100
# 133948
# 134023
# 134189
# 134454
# 134755
# 134905
# 135687
# 136169
# 136533
# 137469
# 137537
# 137636
# 137863
# 138804
# 139096
# 139621
# 139674
# 139764
# 140420
# 141272
# 141366
# 142100
# 143701
# 145906
# 146285
# 147112
# 147634
# 148018
# 148085
# 149997
# 150044
# 151676
# 152081
# 152511
# CPU times: user 16min 1s, sys: 26.4 s, total: 16min 28s
# Wall time: 16min 23s

# %% [markdown]
# ### Tree comparisons

# %%
from sklearn.neighbors import KDTree

# %%
tree = KDTree(regional_ward_morphotopes_data.values)

# %%
dists, idxs = tree.query(regional_ward_morphotopes_data.loc[['69333_66']], k=100)

# %%
regional_ward_morphotopes_data.iloc[idxs[0]].index
# Out:
# Index(['69333_66', '62954_18', '114311_66', '35141_1', '97745_5', '78792_11',
#        '1154_19', '109491_60', '105385_4', '107131_445', '97745_3',
#        '105090_15', '78938_32', '93793_17', '72396_10', '61183_2', '116866_31',
#        '107131_447', '86873_39', '67156_11', '62954_16', '83538_29',
#        '80404_68', '18557_91', '51289_3', '130658_17', '64220_42', '75642_5',
#        '62193_4', '90196_6', '87947_3', '93167_16', '73611_9', '107131_441',
#        '114311_65', '84554_38', '108884_27', '1154_18', '61187_17',
#        '109491_63', '110908_2', '103561_13', '107131_456', '90770_55',
#        '67803_4', '93504_7', '82514_3', '120961_8', '114311_64', '78938_31',
#        '53525_2', '86863_4', '116866_32', '97745_6', '90075_1', '93793_10',
#        '103713_6', '88950_2', '96465_1', '97978_10', '84962_7', '128286_16',
#        '93167_15', '109491_59', '80313_11', '102814_9', '84420_6', '55763_24',
#        '85156_4', '89921_2', '72507_21', '76038_20', '129730_34', '82773_14',
#        '96727_11', '75472_39', '68265_18', '89586_12', '91011_11', '67279_3',
#        '90196_7', '64220_7', '93167_14', '93793_45', '87947_4', '69333_64',
#        '56184_8', '55763_23', '109491_62', '102801_8', '87615_8', '86863_5',
#        '63756_2', '93793_18', '105385_2', '64463_13', '131824_5', '98716_2',
#        '4_895', '102262_42'],
#       dtype='object')

# %%
# etcs[etcs.regional == '69333_64'].explore()

# %% [markdown]
# ## BRNO comparisons

# %%
regions = [91011, 88950, 84297,85104,83538,86568,93167,97978,96895,100210,98107]
etcs = pd.concat([gpd.read_parquet(f"/data/uscuni-ulce/processed_data/clusters/{region_id}_clusters.pq") for region_id in regions])

# %%
etcs= etcs.merge(embedding, how="left", left_on="regional", right_index=True)

# %%
etcs
# Out:
#       currentUse buildingNature  heightAboveGround       iid  \
# 0           None           None                NaN  80687654
# 1           None           None                NaN  80724885
# 2           None           None                NaN  80724886
# 3           None           None                NaN  80724887
# 4           None           None                NaN  80724888
# ...          ...            ...                ...       ...
# 91464       None           None                NaN  84876273
# 91465       None           None                NaN  84876290
# 91466       None           None                NaN  84876346
# 91467       None           None                NaN  84876422
# 91468       None           None                NaN  84876436
#
#                                                 geometry  label  \
# 0      POLYGON ((4764127.215 3003366.261, 4764134.755...      0
# 1      POLYGON ((4779189.412 2981469.524, 4779193.147...    214
# 2      POLYGON ((4779132.331 2981292.364, 4779148.597...    214
# 3      POLYGON ((4779561.295 2981425.951, 4779563.643...    215
# 4      POLYGON ((4778592.213 2981125.266, 4778612.884...    214
# ...                                                  ...    ...
# 91464  POLYGON ((4843315.24 3028458.881, 4843315.494 ...     73
# 91465  POLYGON ((4837503.796 3024621.797, 4837510.316...     77
# 91466  POLYGON ((4841431.281 3030256.391, 4841433.122...     78
# 91467  POLYGON ((4839103.222 3027954.066, 4839106.231...     79
# 91468  POLYGON ((4839960.691 3024893.607, 4839963.526...     68
#
#                morph  final  regional  final_without_noise  ...        10  \
# 0         91011_0_-1     -1        -1                   26  ...       NaN
# 1          91011_1_0     26  91011_28                   26  ...  4.391919
# 2          91011_1_0     26  91011_28                   26  ...  4.391919
# 3          91011_1_1     26  91011_28                   26  ...  4.391919
# 4          91011_1_0     26  91011_28                   26  ...  4.391919
# ...              ...    ...       ...                  ...  ...       ...
# 91464  98107_1058_-1     -1        -1                    6  ...       NaN
# 91465  98107_1060_-1     -1        -1                    6  ...       NaN
# 91466  98107_1061_-1     -1        -1                    6  ...       NaN
# 91467  98107_1062_-1     -1        -1                    6  ...       NaN
# 91468  98107_1053_-1     -1        -1                   13  ...       NaN
#
#              11        12        13       14        15        16        17  \
# 0           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1      5.434757  6.202294  4.747689  4.97861  3.641655  4.727001  5.708712
# 2      5.434757  6.202294  4.747689  4.97861  3.641655  4.727001  5.708712
# 3      5.434757  6.202294  4.747689  4.97861  3.641655  4.727001  5.708712
# 4      5.434757  6.202294  4.747689  4.97861  3.641655  4.727001  5.708712
# ...         ...       ...       ...      ...       ...       ...       ...
# 91464       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 91465       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 91466       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 91467       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 91468       NaN       NaN       NaN      NaN       NaN       NaN       NaN
#
#              18       19
# 0           NaN      NaN
# 1      6.774211  4.25083
# 2      6.774211  4.25083
# 3      6.774211  4.25083
# 4      6.774211  4.25083
# ...         ...      ...
# 91464       NaN      NaN
# 91465       NaN      NaN
# 91466       NaN      NaN
# 91467       NaN      NaN
# 91468       NaN      NaN
#
# [1097349 rows x 30 columns]

# %%
no_noise = etcs[etcs.final >-1]

# %%
import lonboard
layer = lonboard.SolidPolygonLayer.from_geopandas(no_noise)

from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.Positron)
with sc:
    display(m)
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/lonboard/_geoarrow/geopandas_interop.py:20: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = pa.Table.from_pandas(df_attr, preserve_index=preserve_index)
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/lonboard/_geoarrow/ops/reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")

# %%
from lonboard.colormap import apply_continuous_cmap
from palettable.matplotlib import Viridis_20

i = 3
col_vals = (no_noise[i] - no_noise[i].min()) / (no_noise[i].max() - no_noise[i].min())

layer.get_fill_color = apply_continuous_cmap(
    col_vals, Viridis_20
)

# %%
etcs[i].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
etcs

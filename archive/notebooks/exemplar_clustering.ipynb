# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Clustering

# %%
embedding = pd.read_parquet('../data/morphotope_embedding_no_isolates.pq')

# %%
MIN_SAMPLES = 15
data = embedding.values

# %%
from fast_hdbscan.numba_kdtree import kdtree_to_numba
from fast_hdbscan.boruvka import parallel_boruvka
from fast_hdbscan.cluster_trees import (
    mst_to_linkage_tree, condense_tree, 
cluster_tree_from_condensed_tree, extract_eom_clusters, extract_leaves,
get_cluster_label_vector, get_point_membership_strength_vector
)
from sklearn.neighbors import KDTree


def compute_minimum_spanning_tree(data, min_samples=10, sample_weights=None):
    
    edges, neighbors, core_distances = parallel_boruvka(
        numba_tree, min_samples=min_samples, sample_weights=sample_weights
    )
    return edges, neighbors, core_distances
# Out:
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/krasen/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# %%time
sklearn_tree = KDTree(data)
numba_tree = kdtree_to_numba(sklearn_tree)
mst = parallel_boruvka(
        numba_tree, min_samples=MIN_SAMPLES, sample_weights=None
)
n_points = mst.shape[0] + 1
sorted_mst = mst[np.lexsort((mst.T[1], mst.T[0], mst.T[2]))]

linkage_tree = mst_to_linkage_tree(sorted_mst)
# Out:
# CPU times: user 8.21 s, sys: 42.6 ms, total: 8.25 s
# Wall time: 876 ms

# %%
MIN_SAMPLES = 100

cluster_selection_method = 'eom'

# %%
condensed_tree = condense_tree(
    linkage_tree, min_cluster_size=MIN_SAMPLES, sample_weights=None
)
cluster_tree = cluster_tree_from_condensed_tree(condensed_tree)

if cluster_selection_method == "eom":
    selected_clusters = extract_eom_clusters(
                condensed_tree,
                cluster_tree,
                allow_single_cluster=False,
    )
else:
    selected_clusters = extract_leaves(condensed_tree, False)

# %%
clusters = get_cluster_label_vector(
    condensed_tree,
    selected_clusters,
    0.0,
    n_samples=n_points
)
membership_strengths = get_point_membership_strength_vector(
    condensed_tree, selected_clusters, clusters
)

# %%
pd.Series(clusters).value_counts()
# Out:
#  22    321941
#  15     36302
#  34     24750
#  7      20449
#  3      13714
#  27     10918
#  28      9338
#  35      9128
#  0       6329
#  26      5744
#  5       3297
#  10      3037
# -1       2839
#  13      1999
#  32      1856
#  30      1830
#  23      1573
#  33      1537
#  25      1016
#  1        973
#  31       799
#  18       786
#  4        543
#  12       485
#  9        479
#  29       325
#  11       321
#  14       245
#  21       238
#  16       235
#  6        206
#  8        162
#  17       156
#  24       140
#  2        126
#  19       116
#  20       105
# Name: count, dtype: int64

# %%
final_clusters = pd.Series(clusters, index=embedding.index)

# %%
dists, nns = sklearn_tree.query(embedding.loc[['69333_849_74']].values, k=25)

# %%
clusters[nns]
# Out:
# array([[4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 4]])

# %%
clusters[clusters == 4]
# Out:
# array([4, 4, 4, ..., 4, 4, 4])

# %%
from core.cluster_validation import get_color
final_colors = pd.DataFrame(get_color(final_clusters.values), final_clusters.values).drop_duplicates()
final_colors.loc[-1] = [0,0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 2
#       1 from core.cluster_validation import get_color
# ----> 2 final_colors = pd.DataFrame(get_color(final_clusters.values), final_clusters.values).drop_duplicates()
#       3 final_colors.loc[-1] = [0,0,0]
#
# NameError: name 'final_clusters' is not defined

# %% [markdown]
# ## Plotting and morphotopes

# %%
region_id = 69333 

# region_id = 99886 # bratislava

# region_id = 151676 # vilnius

# region_id = 8707 # mainz/frankfurt
# region_id = 5883 #  freiburg
# region_id = 38679 #munich
# region_id = 55763 # berlin

# region_id = 86873 # vienna

# region_id = 107131 # krakow


# region_id= 66593

# region_id = 91011

# %%
# etcs=False to read buildings, etcs=True for tessellation cells.
model_params = '_post_processing_v1'
import geopandas as gpd

def morphotopes_to_etcs(region_id, etcs=True, model_params='_100_0_None_None_False'):


    if etcs:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/tessellations/tessellation_{region_id}.parquet')

    else:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/buildings/buildings_{region_id}.parquet')
        
    etcs['label'] = -1
    
    morphotopes = pd.read_parquet(f'/data/uscuni-ulce/processed_data/morphotopes/tessellation_labels_morphotopes_{region_id}{model_params}.pq')
    morphotopes.loc[:, 'morphotope_label'] =  morphotopes.values[:, 0]

    morph_dict = pd.Series(np.arange(np.unique(morphotopes.values).shape[0]),
                       np.unique(morphotopes.values))
    etcs.loc[morphotopes.index, 'label'] = morphotopes.map(lambda x: morph_dict.loc[x]).values
    etcs['morph'] = str(region_id) + '_' + '-1'
    etcs.loc[morphotopes.index, 'morph'] = str(region_id) + '_' + morphotopes.values
    return etcs

# %%
etcs = morphotopes_to_etcs(region_id, etcs=False, model_params=model_params)

# %%
# etcs1 = morphotopes_to_etcs(69333, etcs=False, model_params=model_params)
# etcs2 = morphotopes_to_etcs(74378, etcs=False, model_params=model_params)

# etcs = pd.concat((etcs1, etcs2), ignore_index=True)

# %%
# # direct kmeans
# etcs['final'] = etcs['morph'].map(lambda x: final_clusters.loc[x] if x in embedding.index else -1)
# etcs['regional'] = etcs['morph']

# %%
etcs['problem'] = ((etcs.morph.isin(problem_morphs)) | (etcs.morph.str[-2:] == '-1')).astype(int)

# %%
# ## can run this to change colors on an exisitng layer
# layer.get_fill_color = get_color(etcs.final)

# %%
etcs['geometry'] = etcs.simplify(1).to_crs(epsg=4326).make_valid()
etcs = etcs[etcs['geometry'].geom_type == 'Polygon']

# %%
# %%time
import lonboard
# plotting = tessellation[tessellation.index.isin(X_train.index)].copy()
layer = lonboard.SolidPolygonLayer.from_geopandas(etcs, opacity=.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:3
#
# NameError: name 'etcs' is not defined

# %%
from sidecar import Sidecar
sc = Sidecar(title=f'Final Clusters')
m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
with sc:
    display(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from sidecar import Sidecar
#       2 sc = Sidecar(title=f'Final Clusters')
# ----> 3 m = lonboard.Map(layer, basemap_style=lonboard.basemap.CartoBasemap.DarkMatter)
#       4 with sc:
#       5     display(m)
#
# NameError: name 'layer' is not defined

# %%
from core.cluster_validation import get_color
final_colors = pd.DataFrame(get_color(np.arange(3)))
final_colors.loc[-1] = [0,0,0]

is_noise = etcs.morph.str[-2:] == '-1'
etcs['problem'] = (etcs.morph.isin(problem_morphs) | is_noise).astype(int)
etcs.loc[is_noise, 'problem'] = -1

layer.get_fill_color = final_colors.loc[etcs.problem].values.astype('uint8')

# %%
from core.cluster_validation import get_color
layer.get_fill_color = final_colors.loc[etcs.final].values.astype('uint8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658339/2278329203.py in ?()
#       1 from core.cluster_validation import get_color
# ----> 2 layer.get_fill_color = final_colors.loc[etcs.final].values.astype('uint8')
#
# ~/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'final'

# %% [markdown]
# ## Morphotopes

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
def morphotopes_to_etcs(region_id, etcs=True, model_params='_100_0_None_None_False'):


    if etcs:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/tessellations/tessellation_{region_id}.parquet')

    else:
        etcs = gpd.read_parquet(f'/data/uscuni-ulce/processed_data/buildings/buildings_{region_id}.parquet')
        
    etcs['label'] = -1
    
    morphotopes = pd.read_parquet(f'/data/uscuni-ulce/processed_data/morphotopes/tessellation_labels_morphotopes_{region_id}{model_params}.pq')
    morphotopes.loc[:, 'morphotope_label'] =  morphotopes.values[:, 0]

    morph_dict = pd.Series(np.arange(np.unique(morphotopes.values).shape[0]),
                       np.unique(morphotopes.values))
    etcs.loc[morphotopes.index, 'label'] = morphotopes.map(lambda x: morph_dict.loc[x]).values
    etcs['morph'] = str(region_id) + '_' + '-1'
    etcs.loc[morphotopes.index, 'morph'] = str(region_id) + '_' + morphotopes.values
    return etcs

# %%
region_id = 69333
region_id = 99886

# %%
etcs = morphotopes_to_etcs(region_id, etcs=False, model_params=model_params)

# %%
modernist_morph = '69333_849_364'
industrial_morph = '69333_1354_5'

# %%
modernist_etcs = etcs[etcs.morph == modernist_morph]
industrial_etcs = etcs[etcs.morph == industrial_morph]

# %%
from libpysal.graph import read_parquet, Graph
graph_dir = '/data/uscuni-ulce/processed_data/neigh_graphs/'
buildings_q1 = read_parquet(graph_dir + f"building_graph_{region_id}.parquet")

# %%
def connect_buildings(group):
    group_graph = buildings_q1.subgraph(group.index)
    connected_buildings = group.dissolve(group_graph.component_labels)
    return connected_buildings

# %%
connected_modernist = connect_buildings(modernist_etcs)
connected_industrial = connect_buildings(industrial_etcs)

# %%
# %%time
# problem_morphs = []
# ok_morphs = []

# for morph in etcs.morph.unique():
    
#     if morph[-2:] == '-1': continue

#     morph_etcs = etcs[etcs.morph == morph]
#     cb = connect_buildings(morph_etcs)
    
#     if cb.shape[0] < 3:
#         problem_morphs.append(morph)
#         continue

#     tri = Graph.build_triangulation(cb.representative_point(), method='relative_neighborhood', kernel='identity')
#     res = tri._adjacency / cb.length.median()
    
#     if res.max() > 2:
#         problem_morphs.append(morph)
#     else:
#         ok_morphs.append(morph)

# %%
len(problem_morphs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 len(problem_morphs)
#
# NameError: name 'problem_morphs' is not defined

# %%
morph = '99886_436_372'

# %%
morph_etcs = etcs[etcs.morph == morph]

# %%
focal, neighbor = morph_etcs.sindex.query(morph_etcs.geometry, predicate='dwithin', distance=100)
geom_graph = Graph.from_adjacency(pd.DataFrame({'focal': focal, 'neighbor':neighbor, 'weight': 1}))

# %%
geom_graph.component_labels.value_counts()
# Out:
# component labels
# 0    121
# Name: count, dtype: int64

# %%
morph_etcs.explore(column=geom_graph.component_labels.values, categorical=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73e908eb52f54d171fbed55bec1d63b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend &#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;0&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73e908eb52f54d171fbed55bec1d63b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73e908eb52f54d171fbed55bec1d63b1 = L.map(
#                 &quot;map_73e908eb52f54d171fbed55bec1d63b1&quot;,
#                 {
#                     center: [48.20756758040294, 17.1615304755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_73e908eb52f54d171fbed55bec1d63b1);
#
#
#
#
#
#             var tile_layer_2393fe6f359b2f428c4574adb6f48476 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2393fe6f359b2f428c4574adb6f48476.addTo(map_73e908eb52f54d171fbed55bec1d63b1);
#
#
#             map_73e908eb52f54d171fbed55bec1d63b1.fitBounds(
#                 [[48.202462777401415, 17.15756523099998], [48.21267238340445, 17.165495720000024]],
#                 {}
#             );
#
#
#         function geo_json_6f01e473939a2caa7d6bbd4ad38f32b4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6f01e473939a2caa7d6bbd4ad38f32b4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6f01e473939a2caa7d6bbd4ad38f32b4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6f01e473939a2caa7d6bbd4ad38f32b4_styler(feature)
#             Object.assig

# %%
from scipy import spatial

# %%
dt = spatial.Delaunay(coords)

# %%
morph_etcs = etcs[etcs.morph == morph]
cb = connect_buildings(morph_etcs)
tri = Graph.build_triangulation(gpd.GeoSeries(points(coords)), method='gabriel', kernel='identity')

# cut = tri._adjacency.sort_values().values[int(.15*len(tri._adjacency)):int(.85*len(tri._adjacency))]
# pd.Series(cut).describe()

tri._adjacency.describe()
# Out:
# ---------------------------------------------------------------------------
# CoplanarError                             Traceback (most recent call last)
# Cell In[136], line 3
#       1 morph_etcs = etcs[etcs.morph == morph]
#       2 cb = connect_buildings(morph_etcs)
# ----> 3 tri = Graph.build_triangulation(gpd.GeoSeries(points(coords)), method='gabriel', kernel='identity')
#       5 # cut = tri._adjacency.sort_values().values[int(.15*len(tri._adjacency)):int(.85*len(tri._adjacency))]
#       6 # pd.Series(cut).describe()
#       8 tri._adjacency.describe()
#
# File ~/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/libpysal/graph/base.py:1375, in Graph.build_triangulation(cls, data, method, bandwidth, kernel, clip, rook, coplanar)
#    1371     head, tail, weights = _delaunay(
#    1372         data, ids=ids, bandwidth=bandwidth, kernel=kernel, coplanar=coplanar
#    1373     )
#    1374 elif method == "gabriel":
# -> 1375     head, tail, weights = _gabriel(
#    1376         data, ids=ids, bandwidth=bandwidth, kernel=kernel, coplanar=coplanar
#    1377     )
#    1378 elif method == "relative_neighborhood":
#    1379     head, tail, weights = _relative_neighborhood(
#    1380         data, ids=ids, bandwidth=bandwidth, kernel=kernel, coplanar=coplanar
#    1381     )
#
# File ~/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/libpysal/graph/_triangulation.py:69, in _validate_coplanar.<locals>.tri_with_validation(coordinates, ids, coplanar, kernel, bandwidth, seed, **kwargs)
#      66     coordinates = _jitter_geoms(coordinates, seed=seed)
#      68 # generate triangulation (triangulator is the wrapped function)
# ---> 69 heads_ix, tails_ix, coplanar_loopkup = triangulator(
#      70     coordinates, coplanar, **kwargs
#      71 )
#      73 # process weights
#      74 if kernel is None:
#
# File ~/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/libpysal/graph/_triangulation.py:260, in _gabriel(coordinates, coplanar)
#     252 if not HAS_NUMBA:
#     253     warnings.warn(
#     254         "The numba package is used extensively in this module"
#     255         " to accelerate the computation of graphs. Without numba,"
#     256         " these computations may become unduly slow on large data.",
#     257         stacklevel=3,
#     258     )
# --> 260 edges, points, coplanar = _voronoi_edges(coordinates, coplanar)
#     261 droplist = _filter_gabriel(
#     262     edges,
#     263     points,
#     264 )
#     265 edges = numpy.row_stack(list(set(map(tuple, edges)).difference(set(droplist))))
#
# File ~/urban_taxonomy/.pixi/envs/default/lib/python3.12/site-packages/libpysal/graph/_triangulation.py:543, in _voronoi_edges(coordinates, coplanar)
#     540 dt = spatial.Delaunay(coordinates)
#     542 if dt.coplanar.shape[0] > 0 and coplanar == "raise":
# --> 543     raise CoplanarError(
#     544         f"There are {len(coordinates) - len(dt.coplanar)} unique locations in "
#     545         f"the dataset, but {len(coordinates)} observations. This means there "
#     546         "are multiple points in the same location, which is undefined "
#     547         "for this graph type. To address this issue, consider setting "
#     548         "`coplanar='clique'` or consult the documentation about "
#     549         "coplanar points."
#     550     )
#     552 edges = _edges_from_simplices(dt.simplices)
#     553 edges = (
#     554     pandas.DataFrame(numpy.asarray(list(edges)))
#     555     .sort_values([0, 1])
#     556     .drop_duplicates()
#     557     .values
#     558 )
#
# CoplanarError: There are 3824 unique locations in the dataset, but 67548 observations. This means there are multiple points in the same location, which is undefined for this graph type. To address this issue, consider setting `coplanar='clique'` or consult the documentation about coplanar points.

# %%
cb.length.median()
# Out:
# np.float64(110.62013596617794)

# %%
m = tri.explore(cb)
cb.explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aed19a01653250036e9ad9f1b0e17d67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aed19a01653250036e9ad9f1b0e17d67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aed19a01653250036e9ad9f1b0e17d67 = L.map(
#                 &quot;map_aed19a01653250036e9ad9f1b0e17d67&quot;,
#                 {
#                     center: [50.102124396587456, 14.458084396171422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aed19a01653250036e9ad9f1b0e17d67);
#
#
#
#
#
#             var tile_layer_a55a8372452bb30d1fa65775b3e7edad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a55a8372452bb30d1fa65775b3e7edad.addTo(map_aed19a01653250036e9ad9f1b0e17d67);
#
#
#             map_aed19a01653250036e9ad9f1b0e17d67.fitBounds(
#                 [[50.09134129232873, 14.439670708229274], [50.112907500846184, 14.47649808411357]],
#                 {}
#             );
#
#
#         function geo_json_57282dc657125c535f8ca9aea06b8ca2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_57282dc657125c535f8ca9aea06b8ca2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_57282dc657125c535f8ca9aea06b8ca2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_57282dc657125c535f8ca9aea06b8ca2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_57282dc657125c535f8ca9aea06b8ca2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_57282dc657125c535f8ca9aea06b8ca2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_57282dc657125c535f8ca9aea06b8ca2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_57282dc657125c535f8ca9aea06b8ca2 = L.geoJson(null, {
#                 onEachFeature: geo_json_57282dc657125c535f8ca9aea06b8ca2_onEachFeature,

# %%
tri2 = Graph.from_adjacency(tri._adjacency[(tri._adjacency < tri._adjacency.median() + (2 * tri._adjacency.std())).values].reset_index())
m = tri2.explore(cb)
cb.explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_feab988e0ef37bac91ea80434e1b64f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_feab988e0ef37bac91ea80434e1b64f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_feab988e0ef37bac91ea80434e1b64f5 = L.map(
#                 &quot;map_feab988e0ef37bac91ea80434e1b64f5&quot;,
#                 {
#                     center: [50.102124396587456, 14.458084396171422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_feab988e0ef37bac91ea80434e1b64f5);
#
#
#
#
#
#             var tile_layer_307b30a70302753543c53cca9fff11ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_307b30a70302753543c53cca9fff11ec.addTo(map_feab988e0ef37bac91ea80434e1b64f5);
#
#
#             map_feab988e0ef37bac91ea80434e1b64f5.fitBounds(
#                 [[50.09134129232873, 14.439670708229274], [50.112907500846184, 14.47649808411357]],
#                 {}
#             );
#
#
#         function geo_json_bf6e76d5c24315c514f4ec1a978765e8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bf6e76d5c24315c514f4ec1a978765e8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bf6e76d5c24315c514f4ec1a978765e8_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bf6e76d5c24315c514f4ec1a978765e8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bf6e76d5c24315c514f4ec1a978765e8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_bf6e76d5c24315c514f4ec1a978765e8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bf6e76d5c24315c514f4ec1a978765e8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bf6e76d5c24315c514f4ec1a978765e8 = L.geoJson(null, {
#                 onEachFeature: geo_json_bf6e76d5c24315c514f4ec1a978765e8_onEachFeature,

# %%
tri = Graph.build_triangulation(connected_industrial.representative_point(), method='relative_neighborhood', kernel='identity')

# cut = tri._adjacency.sort_values().values[int(.15*len(tri._adjacency)):int(.85*len(tri._adjacency))]
# pd.Series(cut).describe()

tri._adjacency.describe()
# Out:
# count    334.000000
# mean      73.176054
# std       39.900737
# min        7.867718
# 25%       46.564948
# 50%       64.367869
# 75%       90.965714
# max      221.032582
# Name: weight, dtype: float64

# %%
tri._adjacency.describe()['std'] / connected_industrial.length.median()
# Out:
# np.float64(0.35862188590235045)

# %%
# m = tri.explore(connected_industrial)
# connected_industrial.explore(m=m)
